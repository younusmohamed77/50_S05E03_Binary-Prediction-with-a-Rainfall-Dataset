# %% [markdown]
# ## Cell 0: Check for GPU Availability
#
# Ensure that TensorFlow detects one or more GPUs. Run this cell in a GPU-enabled environment (e.g., Kaggle Kernels with GPU).
# .

# %%
# Check GPU availability
import tensorflow as tf
print("GPUs Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ## Import Libraries
#
# We import necessary libraries including scikeras for wrapping our Keras model, and also import SimpleImputer (for missing value imputation). GPU-enabled training will be used if available.

# %%
# !pip install scikeras --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 87.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.6.1 which is incompatible.

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, time

from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# Install scikeras if needed
# !pip install scikeras --quiet
from scikeras.wrappers import KerasClassifier

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ## Memory Optimization Function
#
# This function attempts to reduce memory usage by downcasting numeric columns to smaller data types (e.g., float64 -> float32, int64 -> int32.

# %%
# Define memory optimization function
def reduce_memory_usage(df, verbose=True):
    """Downcasts numeric columns to reduce memory usage."""
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type == 'float64':
            df[col] = pd.to_numeric(df[col], downcast='float')
        elif col_type == 'int64':
            df[col] = pd.to_numeric(df[col], downcast='integer')
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print(f"Memory usage reduced from {start_mem:.2f} MB to {end_mem:.2f} MB "
              f"({100 * (start_mem - end_mem) / start_mem:.1f}% reduction)")
    return df

# %% [markdown]
# ## Load and Optimize Data
#
# We load our train/test data, apply the memory optimization function, and separate features/target. Adjust file names as needed for your environmen.

# %%
# Load and optimize data
train = pd.read_csv('/kaggle/input/playground-series-s5e3/train.csv')
test = pd.read_csv('/kaggle/input/playground-series-s5e3/test.csv')

print("Before memory optimization:")
print("Train shape:", train.shape)
print("Test shape:", test.shape)

train = reduce_memory_usage(train)
test = reduce_memory_usage(test)

# Separate features and target from training data
X = train.drop(columns=['id', 'rainfall'])
y = train['rainfall']

# For test data, drop the id column and save the IDs for submission
X_test = test.drop(columns=['id'])
test_ids = test['id']

print("After optimization:")
print("X shape:", X.shape)
print("X_test shape:", X_test.shape)
# Out:
# Before memory optimization:
# Train shape: (2190, 13)
# Test shape: (730, 12)
# Memory usage reduced from 0.22 MB to 0.09 MB (56.7% reduction)
# Memory usage reduced from 0.07 MB to 0.03 MB (54.1% reduction)
# After optimization:
# X shape: (2190, 11)
# X_test shape: (730, 11)

# %% [markdown]
# ## Define Preprocessing Pipelines
#
# We create a dictionary of scalers to compare (none, standard, minmax, robust). If you prefer, you can remove or add more pipeline.

# %%
# Define preprocessing pipelines
preprocessors = {
    # 'standard': StandardScaler(),
    # 'minmax': MinMaxScaler(),
    'robust': RobustScaler()
    #'raw': None
}

# %% [markdown]
# ## Define Keras Model Function
#
# We define a function that builds a DNN model. This will be used by the `KerasClassifier` wrapper. We'll allow hyperparameters like `optimizer`, `dropout_rate`, and `learning_rate` to be tune.

# %%
# Define the Keras model function
def create_dnn_model(optimizer='adam', dropout_rate=0.2, learning_rate=0.001):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    
    # Build optimizer with the specified learning rate
    if optimizer == 'adam':
        opt = Adam(learning_rate=learning_rate)
    else:
        opt = Adam(learning_rate=learning_rate)
    
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['AUC'])
    return model

# %% [markdown]
# ## Define KerasClassifier and Hyperparameter Grid
#
# We use the `KerasClassifier` wrapper from scikeras, which integrates with scikit-learn. We set up a parameter grid (or distribution) for random search. Adjust the ranges to fit your problem constraint
# We wrap our model with scikeras’ KerasClassifier. **Note:** For hyperparameters of the model-building function, we must use the prefix `model__` (and because the pipeline step is named `'dnn'`, we use `'dnn__model__'`)..

# %%
# Wrap the Keras model and define hyperparameter grid
dnn_wrapper = KerasClassifier(
    model=create_dnn_model,
    epochs=20,           # Default epochs; will be tuned
    batch_size=32,       # Default batch size; will be tuned
    verbose=1
)

# Hyperparameter grid using correct prefix "dnn__model__" for parameters passed to create_dnn_model.
param_dist = {
    'dnn__model__optimizer': ['adam', 'rmsprop'],
    'dnn__model__dropout_rate': [0.2, 0.3],
    'dnn__model__learning_rate': [1e-3, 1e-4],
    'dnn__epochs': [20, 30],
    'dnn__batch_size': [32, 64]
}

# %% [markdown]
# ## Hyperparameter Tuning and Submission Generation (Robust Scaling Only)
#
# We build a pipeline that first imputes missing values (using median strategy), then applies RobustScaler (our only option), and finally trains the DNN. We run RandomizedSearchCV (using a threading backend) for thorough tuning, re‑fit the best estimator, and generate test predictions. A submission file is saved.

# %%
# Run hyperparameter tuning and generate submission for Robust scaling only
from joblib import parallel_backend

results = []  # List to store tuning results
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Create a directory for submission files
os.makedirs("submissions", exist_ok=True)

# Since we're only using Robust scaling:
for prep_name, scaler in preprocessors.items():
    if prep_name != 'robust':  # Skip other keys; we only want robust
        continue
    print(f"\n--- Preprocessing: {prep_name} ---")
    
    # Build pipeline: imputer -> RobustScaler -> DNN
    steps = []
    steps.append(('imputer', SimpleImputer(strategy="median")))
    if scaler is not None:
        steps.append((prep_name, scaler))
    steps.append(('dnn', dnn_wrapper))
    pipeline = Pipeline(steps)
    
    # Use threading backend to avoid pickling issues.
    with parallel_backend('threading', n_jobs=-1):
        search = RandomizedSearchCV(
            estimator=pipeline,
            param_distributions=param_dist,
            n_iter=50,
            scoring='roc_auc',
            cv=cv,
            verbose=1,
            random_state=42,
            n_jobs=-1
        )
        search.fit(X, y)
    
    best_score = search.best_score_
    best_params = search.best_params_
    
    print(f"Best CV ROC AUC for {prep_name}: {best_score:.4f}")
    print("Best parameters:", best_params)
    
    # Re-fit the best estimator on the full training data to ensure it is fitted.
    best_pipe = search.best_estimator_
    best_pipe.fit(X, y)
    
    # Instead of calling predict_proba on the entire pipeline (which causes __sklearn_tags__ error),
    # manually transform X_test using all steps except the final one:
    X_test_transformed = best_pipe[:-1].transform(X_test)
    # Then call predict_proba on the DNN step:
    test_preds = best_pipe.named_steps['dnn'].predict_proba(X_test_transformed)[:, 1]
    
    # Save the submission file for Robust scaling
    sub_filename = f"submissions/{prep_name}_dnn_submission.csv"
    sub_df = pd.DataFrame({'id': test_ids, 'rainfall': test_preds})
    sub_df.to_csv(sub_filename, index=False)
    print(f"Submission file saved: {sub_filename}\n")
    
    # Record results for later comparison.
    results.append({
        'preprocessing': prep_name,
        'best_auc': best_score,
        'best_params': best_params,
        'submission_file': sub_filename
    })
# Out:
# --- Preprocessing: robust ---
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - AUC: 0.4553 - loss: 0.6159
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - AUC: 0.5083 - loss: 0.6257
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - AUC: 0.4261 - loss: 0.6088
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - AUC: 0.7415 - loss: 0.6154
# Epoch 2/20
# Epoch 2/20
# Epoch 2/20
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8495 - loss: 0.4079
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8681 - loss: 0.4154
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8545 - loss: 0.4176
# Epoch 3/20
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8661 - loss: 0.4075
# Epoch 3/20
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8668 - loss: 0.3885
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8950 - loss: 0.3454
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8826 - loss: 0.3615
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8708 - loss: 0.3732
# Epoch 4/20
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8768 - loss: 0.3561
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9009 - loss: 0.3281Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8948 - loss: 0.3273
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9047 - loss: 0.3247
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8991 - loss: 0.3302
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8671 - loss: 0.3775
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8900 - loss: 0.3363
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8790 - loss: 0.3523
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9042 - loss: 0.3089
# Epoch 6/20
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8667 - loss: 0.3652
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9006 - loss: 0.3217Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9004 - loss: 0.3220
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9004 - loss: 0.3248
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8819 - loss: 0.3568
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.9010 - loss: 0.2801Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8664 - loss: 0.3708
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8984 - loss: 0.3255
# Epoch 8/20
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8768 - loss: 0.3574
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9049 - loss: 0.3114
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8824 - loss: 0.3417
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8977 - loss: 0.3208
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8800 - loss: 0.3398
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9089 - loss: 0.3022
# Epoch 9/20
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9104 - loss: 0.3141
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8936 - loss: 0.3282
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8905 - loss: 0.3339Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8904 - loss: 0.3340
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.3575
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8941 - loss: 0.3421
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8951 - loss: 0.3376Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9037 - loss: 0.3281
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8944 - loss: 0.3381
# Epoch 11/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9029 - loss: 0.3193
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8908 - loss: 0.3434
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8671 - loss: 0.3717
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.7161 - loss: 0.5587Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8921 - loss: 0.3375
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8805 - loss: 0.3586
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8805 - loss: 0.3563
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8783 - loss: 0.3507
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8786 - loss: 0.3489Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8790 - loss: 0.3485
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9018 - loss: 0.3067
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.9770 - loss: 0.1587Epoch 13/20
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8993 - loss: 0.3299
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8983 - loss: 0.3205Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8894 - loss: 0.3257
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8995 - loss: 0.3210
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8861 - loss: 0.3332
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8893 - loss: 0.3285
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9062 - loss: 0.3124
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8950 - loss: 0.3322
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8952 - loss: 0.3248
# Epoch 15/20
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8933 - loss: 0.3435
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9060 - loss: 0.3223
# Epoch 16/20
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9064 - loss: 0.3126
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8903 - loss: 0.3449
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8824 - loss: 0.3506
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9092 - loss: 0.3239
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9104 - loss: 0.3077
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8981 - loss: 0.3157
# Epoch 17/20
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.8279 - loss: 0.5360Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8827 - loss: 0.3417
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8973 - loss: 0.3523Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8974 - loss: 0.3513
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9224 - loss: 0.2782Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9216 - loss: 0.2801
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8925 - loss: 0.3362
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8881 - loss: 0.3354
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9071 - loss: 0.3129
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9100 - loss: 0.3168
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8946 - loss: 0.3255
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9136 - loss: 0.3043
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9021 - loss: 0.3233
# Epoch 20/20
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8895 - loss: 0.3423
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8899 - loss: 0.3351
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - AUC: 0.7296 - loss: 0.3776Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8915 - loss: 0.3298
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9039 - loss: 0.3219
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9135 - loss: 0.3100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8930 - loss: 0.3247
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - AUC: 0.5243 - loss: 0.5988
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8687 - loss: 0.3883
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - AUC: 0.7306 - loss: 0.6045
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8793 - loss: 0.3464
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8698 - loss: 0.3951
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.9727 - loss: 0.2661Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - AUC: 0.6265 - loss: 0.6326
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - AUC: 0.6726 - loss: 0.5694
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8996 - loss: 0.3292
# 45/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8704 - loss: 0.3732Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8742 - loss: 0.3674
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8517 - loss: 0.3882
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8956 - loss: 0.3418Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8923 - loss: 0.3425
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8993 - loss: 0.3326
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8730 - loss: 0.3671
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8982 - loss: 0.3191
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8914 - loss: 0.3238
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8833 - loss: 0.3540
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8863 - loss: 0.3418
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8999 - loss: 0.3358
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8781 - loss: 0.3618
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8985 - loss: 0.3246Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8936 - loss: 0.3307
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - AUC: 0.9103 - loss: 0.2875Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9000 - loss: 0.3232
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8784 - loss: 0.3568
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9144 - loss: 0.3069
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8969 - loss: 0.3298
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8785 - loss: 0.3569
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8970 - loss: 0.3207Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8940 - loss: 0.3359
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8967 - loss: 0.3229
# Epoch 11/20
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8833 - loss: 0.3441
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9095 - loss: 0.3180
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8763 - loss: 0.3608
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9028 - loss: 0.3280
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9143 - loss: 0.3041
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9186 - loss: 0.2909
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8950 - loss: 0.3417
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9198 - loss: 0.3003Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9148 - loss: 0.3066
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9001 - loss: 0.3335
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8685 - loss: 0.3751
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8972 - loss: 0.3258
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9124 - loss: 0.3135
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8856 - loss: 0.3494
# 36/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8944 - loss: 0.3305Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8962 - loss: 0.3294
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8992 - loss: 0.3399Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8995 - loss: 0.3389
# 21/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9077 - loss: 0.3363 Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8956 - loss: 0.3450
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8938 - loss: 0.3261
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9101 - loss: 0.3105
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8852 - loss: 0.3428
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8926 - loss: 0.3368
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8960 - loss: 0.3228
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9024 - loss: 0.3312
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8882 - loss: 0.3236
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9051 - loss: 0.3193
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8953 - loss: 0.3324
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9010 - loss: 0.3297Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9039 - loss: 0.3175
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9017 - loss: 0.3263
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8925 - loss: 0.3375
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8910 - loss: 0.3322
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9044 - loss: 0.3213
# Epoch 20/20
# 12/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9339 - loss: 0.2675 Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8782 - loss: 0.3564
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.9202 - loss: 0.2942
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8824 - loss: 0.3461Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8844 - loss: 0.3434
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.8835 - loss: 0.3529
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8655 - loss: 0.3954Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - AUC: 0.8654 - loss: 0.3952
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - AUC: 0.8874 - loss: 0.3390
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8743 - loss: 0.3406
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8876 - loss: 0.3523
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8850 - loss: 0.3574
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8894 - loss: 0.3459
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8835 - loss: 0.3351
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8884 - loss: 0.3492
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8821 - loss: 0.3633
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8850 - loss: 0.3527
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8968 - loss: 0.3349
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8691 - loss: 0.3514
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8872 - loss: 0.3281
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8842 - loss: 0.3529
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8920 - loss: 0.3406
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8979 - loss: 0.3319
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9016 - loss: 0.3127
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9152 - loss: 0.3106
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9007 - loss: 0.3312
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - AUC: 0.5836 - loss: 0.6491
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8534 - loss: 0.4204
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - AUC: 0.6714 - loss: 0.6228
# 24/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8622 - loss: 0.3820Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8641 - loss: 0.3767
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - AUC: 0.6676 - loss: 0.6256
# 36/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8204 - loss: 0.4432Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8317 - loss: 0.4266
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8604 - loss: 0.3822
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.7330 - loss: 0.5897
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8754 - loss: 0.3566
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8871 - loss: 0.3433
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7267 - loss: 0.5625Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7318 - loss: 0.5613
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - AUC: 0.7701 - loss: 0.2417Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8777 - loss: 0.3563
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8728 - loss: 0.3384
# 31/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9002 - loss: 0.3241Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7838 - loss: 0.5299
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8980 - loss: 0.3283
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8827 - loss: 0.3177
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8255 - loss: 0.4969
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8856 - loss: 0.3499
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8880 - loss: 0.3349
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8390 - loss: 0.4688
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8845 - loss: 0.3525
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8803 - loss: 0.3416
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8342 - loss: 0.4684
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8838 - loss: 0.3623Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8852 - loss: 0.3575
# 16/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8834 - loss: 0.3460 Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8850 - loss: 0.3409
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8191 - loss: 0.4534
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8896 - loss: 0.3340
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8866 - loss: 0.3376
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8558 - loss: 0.4247
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8957 - loss: 0.3251
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9065 - loss: 0.3126
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8277 - loss: 0.4246Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8301 - loss: 0.4239
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8983 - loss: 0.3216Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8972 - loss: 0.3239
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.7375 - loss: 0.5472Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8899 - loss: 0.3301
# 34/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8969 - loss: 0.3397Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8418 - loss: 0.4236
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8956 - loss: 0.3371
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8980 - loss: 0.3174
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6633 - loss: 0.7452Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8435 - loss: 0.4066
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8959 - loss: 0.3333
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9017 - loss: 0.3214
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8537 - loss: 0.3883
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9053 - loss: 0.3154
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8907 - loss: 0.3226
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8500 - loss: 0.4067
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9104 - loss: 0.3099
# 14/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9049 - loss: 0.2751 Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9009 - loss: 0.3074
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8569 - loss: 0.3901
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8904 - loss: 0.3401
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9024 - loss: 0.3157
# 31/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8960 - loss: 0.3163Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8618 - loss: 0.3845
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8948 - loss: 0.3255
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8829 - loss: 0.3362
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8609 - loss: 0.3852
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8819 - loss: 0.3416
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8957 - loss: 0.3239
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9001 - loss: 0.3251
# 34/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8718 - loss: 0.3727Epoch 20/20
# 11/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9255 - loss: 0.2966 Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8711 - loss: 0.3702
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - AUC: 0.6629 - loss: 0.7415
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.9106 - loss: 0.3110
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8751 - loss: 0.3693
# 36/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7099 - loss: 0.6970Epoch 20/20
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.7130 - loss: 0.6958Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.7204 - loss: 0.6918
# 24/55 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8536 - loss: 0.3891Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - AUC: 0.8601 - loss: 0.3806
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7846 - loss: 0.6495Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - AUC: 0.7862 - loss: 0.6486
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.8083 - loss: 0.6117
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8502 - loss: 0.5722
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8657 - loss: 0.5342
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8845 - loss: 0.5029
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8597 - loss: 0.4871
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8559 - loss: 0.4533
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8801 - loss: 0.4375
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8743 - loss: 0.4192
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8839 - loss: 0.3967
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8984 - loss: 0.3668
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9007 - loss: 0.3622
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8708 - loss: 0.3873
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9104 - loss: 0.3331
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8880 - loss: 0.3588
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8712 - loss: 0.3708
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8804 - loss: 0.3509
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8836 - loss: 0.3477
# 13/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6068 - loss: 0.7562 Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - AUC: 0.5865 - loss: 0.6716
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.6092 - loss: 0.6419
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - AUC: 0.4638 - loss: 0.6831
# 36/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.6709 - loss: 0.6155Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.6815 - loss: 0.6115
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5300 - loss: 0.6426
# 34/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7416 - loss: 0.5906Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7422 - loss: 0.5876
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6458 - loss: 0.5932
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - AUC: 0.6562 - loss: 0.7401Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - AUC: 0.6566 - loss: 0.7398
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7408 - loss: 0.5655
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7003 - loss: 0.6874
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7161 - loss: 0.5615
# Epoch 3/20
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8089 - loss: 0.5341Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8081 - loss: 0.5340
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.7773 - loss: 0.5421Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7605 - loss: 0.6388
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7319 - loss: 0.5364
# Epoch 4/20
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8291 - loss: 0.5126
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7878 - loss: 0.5974
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7852 - loss: 0.5067
# Epoch 5/20
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8356 - loss: 0.5018
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8210 - loss: 0.4763
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8060 - loss: 0.5668
# Epoch 8/20
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8487 - loss: 0.4690
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8298 - loss: 0.5351
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8021 - loss: 0.4795
# Epoch 9/20
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8534 - loss: 0.4484
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8303 - loss: 0.4561
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8607 - loss: 0.4332
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8437 - loss: 0.5007
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8397 - loss: 0.4339
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8406 - loss: 0.4888
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8582 - loss: 0.4194
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8211 - loss: 0.4738
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8027 - loss: 0.4398Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8677 - loss: 0.4033
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8134 - loss: 0.4341
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8840 - loss: 0.3890
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8676 - loss: 0.3920Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8625 - loss: 0.3957
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8656 - loss: 0.3942
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8509 - loss: 0.4131
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - AUC: 0.8532 - loss: 0.4412
# Epoch 14/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8741 - loss: 0.3792
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8745 - loss: 0.3770
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8880 - loss: 0.3596
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8205 - loss: 0.4089Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8311 - loss: 0.4024
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - AUC: 0.8384 - loss: 0.4355
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8713 - loss: 0.3715
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8421 - loss: 0.4055
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8492 - loss: 0.4210
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8648 - loss: 0.4083
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - AUC: 0.8817 - loss: 0.3573
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8527 - loss: 0.3989
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8808 - loss: 0.3633Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - AUC: 0.8805 - loss: 0.3635
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8842 - loss: 0.3510
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8773 - loss: 0.3801
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8596 - loss: 0.3694
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - AUC: 0.5532 - loss: 0.6972Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - AUC: 0.5535 - loss: 0.6970
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.9667 - loss: 0.3819Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8655 - loss: 0.3792
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8540 - loss: 0.3951
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 1.0000 - loss: 0.2122Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8733 - loss: 0.3629
#  8/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.6862 - loss: 0.6595   Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8670 - loss: 0.3707
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8904 - loss: 0.3508Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.6405 - loss: 0.6573
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8863 - loss: 0.3536Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8847 - loss: 0.3548
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.6880 - loss: 0.6252
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8519 - loss: 0.3733Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.8548 - loss: 0.3722
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.7183 - loss: 0.5943
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8538 - loss: 0.3762
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7644 - loss: 0.5652Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.7652 - loss: 0.5646
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8029 - loss: 0.5330
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8289 - loss: 0.5146
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - AUC: 0.8150 - loss: 0.4965
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8457 - loss: 0.4704
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8422 - loss: 0.4437
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8320 - loss: 0.4501
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8427 - loss: 0.4257
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8538 - loss: 0.4149
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8557 - loss: 0.4034
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8454 - loss: 0.4095
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8502 - loss: 0.3882
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - AUC: 0.4900 - loss: 0.6938
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8680 - loss: 0.3809
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5840 - loss: 0.6528
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8572 - loss: 0.3816
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6777 - loss: 0.6152
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8750 - loss: 0.3638
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7411 - loss: 0.5792
# Epoch 20/20
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7957 - loss: 0.5437
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8736 - loss: 0.3501
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - AUC: 0.4445 - loss: 0.6616
# Epoch 2/20
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - AUC: 0.4348 - loss: 0.6550Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7778 - loss: 0.5261
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.5606 - loss: 0.6166Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.5693 - loss: 0.6153
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8205 - loss: 0.4991
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.6368 - loss: 0.5962Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.6471 - loss: 0.5923
#  9/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8488 - loss: 0.4808 Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - AUC: 0.2775 - loss: 0.7634
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8509 - loss: 0.4685
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.1343 - loss: 0.7719Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.7836 - loss: 0.5477
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.3321 - loss: 0.7176
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8595 - loss: 0.4386
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7968 - loss: 0.5239
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.6280 - loss: 0.6852Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5149 - loss: 0.6627
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8516 - loss: 0.4294
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8351 - loss: 0.4907
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6056 - loss: 0.6222
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8718 - loss: 0.4015
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8425 - loss: 0.4519
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6422 - loss: 0.5982
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8645 - loss: 0.4055
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8344 - loss: 0.4469
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7505 - loss: 0.5491
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8807 - loss: 0.4102
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8760 - loss: 0.3807
# Epoch 14/20
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7571 - loss: 0.5289
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8648 - loss: 0.3951
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8861 - loss: 0.3960
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7959 - loss: 0.5025
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8800 - loss: 0.3640
# Epoch 9/20
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8740 - loss: 0.3900
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8698 - loss: 0.3681
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8585 - loss: 0.3823Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8612 - loss: 0.3832
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7957 - loss: 0.4798
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8766 - loss: 0.3774
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8653 - loss: 0.3704
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8359 - loss: 0.4518
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8677 - loss: 0.3646
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8724 - loss: 0.3620
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8476 - loss: 0.4340
# Epoch 15/20
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8846 - loss: 0.3543
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8499 - loss: 0.4121
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8892 - loss: 0.3620
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9090 - loss: 0.3293 Epoch 13/20
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8965 - loss: 0.3370
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8721 - loss: 0.3638
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8855 - loss: 0.3917
# Epoch 14/20
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - AUC: 0.8558 - loss: 0.3757Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8681 - loss: 0.3655
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8595 - loss: 0.3988
# Epoch 18/20
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8847 - loss: 0.3460
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8619 - loss: 0.3896
# Epoch 19/20
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - AUC: 0.5651 - loss: 0.7718
# 34/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8462 - loss: 0.4084Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8531 - loss: 0.3986
# 25/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.5768 - loss: 0.7352Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8831 - loss: 0.3408
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.5810 - loss: 0.7279
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8682 - loss: 0.3793
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8838 - loss: 0.3469
# 20/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.9040 - loss: 0.3308Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5860 - loss: 0.6919
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8839 - loss: 0.3540
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.6406 - loss: 0.6574
# 36/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8869 - loss: 0.3567Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8859 - loss: 0.3551
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.6889 - loss: 0.6301
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8904 - loss: 0.3491
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.7178 - loss: 0.5969Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.7197 - loss: 0.5963
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.7750 - loss: 0.5726
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.7663 - loss: 0.5450
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8131 - loss: 0.5079
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8241 - loss: 0.4835
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8112 - loss: 0.4815
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8485 - loss: 0.4437
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8408 - loss: 0.4374
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8580 - loss: 0.4202
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8645 - loss: 0.4007
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8449 - loss: 0.4129
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8717 - loss: 0.3859
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - AUC: 0.6404 - loss: 0.6308
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8687 - loss: 0.3826
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8458 - loss: 0.4389
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8620 - loss: 0.3897
# Epoch 3/20
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8759 - loss: 0.3637
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8617 - loss: 0.3782
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 3:42 4s/step - AUC: 0.6926 - loss: 0.6608Epoch 4/20
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8845 - loss: 0.3615Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8722 - loss: 0.3679
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8842 - loss: 0.3558
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - AUC: 0.4257 - loss: 0.6233
# 19/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8753 - loss: 0.3621Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8663 - loss: 0.3736
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8351 - loss: 0.4438
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - AUC: 0.7483 - loss: 0.5999
# 28/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8777 - loss: 0.3561Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8699 - loss: 0.3664
# 35/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8776 - loss: 0.3589Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8774 - loss: 0.3615
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8324 - loss: 0.4202
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8841 - loss: 0.3474
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8777 - loss: 0.3589
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8784 - loss: 0.3564
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8948 - loss: 0.3517
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8923 - loss: 0.3524
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8799 - loss: 0.3658
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8836 - loss: 0.3561
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9072 - loss: 0.3146
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8854 - loss: 0.3415
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8921 - loss: 0.3354
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8953 - loss: 0.3354
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8740 - loss: 0.3596Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8921 - loss: 0.3437
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.3591
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8887 - loss: 0.3481
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9017 - loss: 0.3147
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8651 - loss: 0.3744
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8889 - loss: 0.3498
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8841 - loss: 0.3527
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8827 - loss: 0.3579
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8925 - loss: 0.3419
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8813 - loss: 0.3669
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8883 - loss: 0.3495
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8958 - loss: 0.3361
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8890 - loss: 0.3425
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9017 - loss: 0.3325
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8716 - loss: 0.3456
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9042 - loss: 0.3312Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9016 - loss: 0.3331
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.9710 - loss: 0.2250Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9022 - loss: 0.3308
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9037 - loss: 0.3237
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8920 - loss: 0.3267
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.9710 - loss: 0.2553Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8859 - loss: 0.3487
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9002 - loss: 0.3318
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8903 - loss: 0.3272
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8741 - loss: 0.3621
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8874 - loss: 0.3316
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8913 - loss: 0.3542
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8844 - loss: 0.3432
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8930 - loss: 0.3230
# Epoch 17/20
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - AUC: 0.9614 - loss: 0.2456Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.9013 - loss: 0.3213
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.9147 - loss: 0.3010
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8876 - loss: 0.3466
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9232 - loss: 0.2792
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - AUC: 0.5920 - loss: 0.5953Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - AUC: 0.5942 - loss: 0.5943
# 18/55 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.9100 - loss: 0.3167Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9005 - loss: 0.3306
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9174 - loss: 0.3025
# 12/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8884 - loss: 0.3455Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8616 - loss: 0.3986
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8937 - loss: 0.3370
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9012 - loss: 0.3374
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8827 - loss: 0.3533
# Epoch 4/20
# 18/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8880 - loss: 0.3718Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8957 - loss: 0.3394
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8825 - loss: 0.3655
#  6/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8150 - loss: 0.4220Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8845 - loss: 0.3395
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8683 - loss: 0.3670
# Epoch 6/20
# 17/55 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.8971 - loss: 0.3509Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.8918 - loss: 0.3498
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - AUC: 0.8802 - loss: 0.3608
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8961 - loss: 0.3376
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8860 - loss: 0.3442
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8861 - loss: 0.3473
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8890 - loss: 0.3492
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8838 - loss: 0.3456
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8968 - loss: 0.3377
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8815 - loss: 0.3452
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8960 - loss: 0.3234
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8888 - loss: 0.3464
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8971 - loss: 0.3317
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - AUC: 0.6872 - loss: 0.6595
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - AUC: 0.8863 - loss: 0.4773Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8994 - loss: 0.3188
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8933 - loss: 0.3383
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8908 - loss: 0.3338
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - AUC: 0.6452 - loss: 0.6242
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8329 - loss: 0.4298
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8607 - loss: 0.3678
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8607 - loss: 0.3767
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - AUC: 0.7153 - loss: 0.6973
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8501 - loss: 0.3957
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8327 - loss: 0.4682
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8819 - loss: 0.3551
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8612 - loss: 0.3977
# Epoch 4/20
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8473 - loss: 0.4035
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8817 - loss: 0.3431
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8735 - loss: 0.3651
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8762 - loss: 0.3523
# Epoch 9/20
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8857 - loss: 0.3499
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8909 - loss: 0.3445
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8738 - loss: 0.3543
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8697 - loss: 0.3696
# 17/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.4755 - loss: 0.7635 Epoch 8/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8869 - loss: 0.3476
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8870 - loss: 0.3535
# Epoch 12/20
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8928 - loss: 0.3403
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8833 - loss: 0.3413
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8942 - loss: 0.3444
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8645 - loss: 0.3765
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8903 - loss: 0.3557
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8782 - loss: 0.3731
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9062 - loss: 0.3229
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8681 - loss: 0.3667
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9036 - loss: 0.3244
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8920 - loss: 0.3318
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - AUC: 0.8330 - loss: 0.4581
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9023 - loss: 0.3208
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8807 - loss: 0.3469
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.9407 - loss: 0.2181Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8384 - loss: 0.4104
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9073 - loss: 0.2998
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8905 - loss: 0.3474
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - AUC: 0.9257 - loss: 0.3136Epoch 19/20
# ...
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8130 - loss: 0.4524
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8466 - loss: 0.4473
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8507 - loss: 0.4381
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8345 - loss: 0.4437
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8166 - loss: 0.4498
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8554 - loss: 0.4157
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8436 - loss: 0.4340
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8794 - loss: 0.4060
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8368 - loss: 0.4384
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8600 - loss: 0.3940
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8555 - loss: 0.4158
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8534 - loss: 0.4146
# 19/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8563 - loss: 0.4065 Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8541 - loss: 0.4100
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8384 - loss: 0.4190
# 17/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8576 - loss: 0.4146 Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8590 - loss: 0.4089
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8742 - loss: 0.3894
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8278 - loss: 0.4191
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8490 - loss: 0.4017
# 22/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8499 - loss: 0.3953 Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8506 - loss: 0.3966
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8555 - loss: 0.3933
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8657 - loss: 0.3885
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8699 - loss: 0.3827
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8602 - loss: 0.3949
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8493 - loss: 0.3967
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8511 - loss: 0.4047
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8661 - loss: 0.3862
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8496 - loss: 0.3892
# Epoch 1/30
# Epoch 1/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - AUC: 0.7336 - loss: 0.7408
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.7182 - loss: 0.7194
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - AUC: 0.6358 - loss: 0.8444
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - AUC: 0.6827 - loss: 0.6997
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - AUC: 0.6772 - loss: 0.7886
# Epoch 4/30
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.7280 - loss: 0.6720
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.6620 - loss: 0.7576
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - AUC: 0.6619 - loss: 0.7296
# 26/28 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - AUC: 0.7261 - loss: 0.6503Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - AUC: 0.7265 - loss: 0.6498
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7087 - loss: 0.6978
# 20/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7354 - loss: 0.6280 Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7387 - loss: 0.6264
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7609 - loss: 0.6060
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7016 - loss: 0.6751
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7935 - loss: 0.5857
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6977 - loss: 0.6541
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7892 - loss: 0.5756
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7444 - loss: 0.6283
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7434 - loss: 0.5701
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7234 - loss: 0.6167
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7763 - loss: 0.5549
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7600 - loss: 0.5938
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7975 - loss: 0.5385
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7685 - loss: 0.5813
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7817 - loss: 0.5339
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - AUC: 0.7262 - loss: 0.5888Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7732 - loss: 0.5662
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8349 - loss: 0.5018
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7957 - loss: 0.5418
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8291 - loss: 0.5009
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8323 - loss: 0.5218
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8387 - loss: 0.4754
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8067 - loss: 0.5178
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8417 - loss: 0.4646
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8336 - loss: 0.5000
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8123 - loss: 0.4834
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8450 - loss: 0.4512
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8216 - loss: 0.4908
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8539 - loss: 0.4483
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8220 - loss: 0.4882
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8556 - loss: 0.4343
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8066 - loss: 0.4829
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8732 - loss: 0.4174
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8239 - loss: 0.4715
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 2:22 5s/step - AUC: 0.3664 - loss: 0.6475Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8736 - loss: 0.4069
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8407 - loss: 0.4558
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8614 - loss: 0.4135
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8376 - loss: 0.4511
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8611 - loss: 0.4111
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8409 - loss: 0.4475
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8791 - loss: 0.3870
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8544 - loss: 0.4284
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8557 - loss: 0.4147
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8675 - loss: 0.4104
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8725 - loss: 0.3857
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8725 - loss: 0.4043
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8599 - loss: 0.3966
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8645 - loss: 0.4007
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8668 - loss: 0.3873
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8763 - loss: 0.3900
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8604 - loss: 0.4069
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8653 - loss: 0.3923
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - AUC: 0.3893 - loss: 0.6623
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.4810 - loss: 0.6341
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - AUC: 0.5529 - loss: 0.6958
# Epoch 3/30
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5184 - loss: 0.6165
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6080 - loss: 0.6692
# Epoch 4/30
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5685 - loss: 0.6015
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5899 - loss: 0.6541
# Epoch 5/30
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6010 - loss: 0.5830
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6624 - loss: 0.6253
# Epoch 6/30
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6441 - loss: 0.5693
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6729 - loss: 0.6095
# Epoch 7/30
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6942 - loss: 0.5464
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6782 - loss: 0.6021
# Epoch 8/30
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7149 - loss: 0.5261
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7566 - loss: 0.5689
# Epoch 9/30
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7314 - loss: 0.5185
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7373 - loss: 0.5596
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7651 - loss: 0.5052
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8089 - loss: 0.5342
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7714 - loss: 0.5041
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8001 - loss: 0.5209
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7726 - loss: 0.4850
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8019 - loss: 0.5107
# Epoch 13/30
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8021 - loss: 0.4604
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7944 - loss: 0.4952
# Epoch 14/30
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8164 - loss: 0.4507
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8226 - loss: 0.4812
# Epoch 15/30
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8317 - loss: 0.4751
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8288 - loss: 0.4410
# Epoch 15/30
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8206 - loss: 0.4741
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8222 - loss: 0.4419
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8293 - loss: 0.4676
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8442 - loss: 0.4225
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8555 - loss: 0.4407
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8401 - loss: 0.4255
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8227 - loss: 0.4426
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8494 - loss: 0.4099 Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8492 - loss: 0.4101
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8503 - loss: 0.4269
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8579 - loss: 0.3992 Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8581 - loss: 0.3988
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8512 - loss: 0.4223
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8387 - loss: 0.4112 Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8393 - loss: 0.4106
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8545 - loss: 0.4158
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8654 - loss: 0.3930 Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8649 - loss: 0.3931
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8572 - loss: 0.4131
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8557 - loss: 0.3935
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8424 - loss: 0.4187
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8453 - loss: 0.4165
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8504 - loss: 0.4134
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8431 - loss: 0.3989
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8414 - loss: 0.4093
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8515 - loss: 0.3886
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8473 - loss: 0.4046
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8679 - loss: 0.3721
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8583 - loss: 0.4009
# 26/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8676 - loss: 0.3814 Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8674 - loss: 0.3812
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8711 - loss: 0.3745
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8382 - loss: 0.4085
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8595 - loss: 0.3858
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8626 - loss: 0.3631
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8825 - loss: 0.3664
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - AUC: 0.7563 - loss: 0.5363
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8905 - loss: 0.3543
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8969 - loss: 0.3363
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8828 - loss: 0.3575
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8996 - loss: 0.3350
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8818 - loss: 0.3452
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8843 - loss: 0.3371
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9011 - loss: 0.3270
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8953 - loss: 0.3305
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8803 - loss: 0.3436
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8925 - loss: 0.3418
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8939 - loss: 0.3389
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8968 - loss: 0.3291
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8762 - loss: 0.3585
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8876 - loss: 0.3363
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9013 - loss: 0.3281
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8963 - loss: 0.3273
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8963 - loss: 0.3298
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8994 - loss: 0.3246
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8951 - loss: 0.3297
# Best CV ROC AUC for robust: nan
# Best parameters: {'dnn__model__optimizer': 'adam', 'dnn__model__learning_rate': 0.001, 'dnn__model__dropout_rate': 0.2, 'dnn__epochs': 20, 'dnn__batch_size': 32}
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - AUC: 0.7732 - loss: 0.6159
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8553 - loss: 0.3852
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8877 - loss: 0.3431
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9040 - loss: 0.3110
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8960 - loss: 0.3330
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8974 - loss: 0.3266
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8971 - loss: 0.3388
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8886 - loss: 0.3402
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8988 - loss: 0.3298
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9050 - loss: 0.3221
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8996 - loss: 0.3160
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8949 - loss: 0.3379
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8953 - loss: 0.3268
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9063 - loss: 0.3166
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9020 - loss: 0.3318
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8837 - loss: 0.3443
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8911 - loss: 0.3278
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8767 - loss: 0.3570
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8975 - loss: 0.3156
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9052 - loss: 0.3131
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Submission file saved: submissions/robust_dnn_submission.csv

# %% [markdown]
# ## Compare Results
#
# We create a DataFrame from the results and sort by the best AUC score to see which preprocessing pipeline + hyperparameters performed bes.

# %%
# Compare results across pipelines
results_df = pd.DataFrame(results).sort_values(by='best_auc', ascending=False)
print("\nComparison of Preprocessing Approaches:")
display(results_df)
# Out:
# Comparison of Preprocessing Approaches:
#   preprocessing  best_auc                                        best_params  \
# 0        robust       NaN  {'dnn__model__optimizer': 'adam', 'dnn__model_...
#
#                          submission_file
# 0  submissions/robust_dnn_submission.csv

# %% [markdown]
# ## Copy Best Scoring Submission as submission.csv
#
# From the tuning results, we identify the best scoring submission and copy that file to "submission.csv" (the name required by the competition). All other submission file names remain unchanged..

# %%
# Copy the best scoring submission to "submission.csv"
import shutil

# Filter out any candidates with NaN scores and pick the best candidate
results_df = results_df[results_df['best_auc'].notna()]
if len(results_df) == 0:
    raise ValueError("No valid submission was found with a non-NaN ROC AUC score.")

best_result = results_df.iloc[0]
best_submission_file = best_result['submission_file']

# Copy the best submission file to "submission.csv"
shutil.copy(best_submission_file, 'submission.csv')
print(f"Best scoring submission ({best_submission_file}) copied as 'submission.csv'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-54f747b73f02> in <cell line: 6>()
#       5 results_df = results_df[results_df['best_auc'].notna()]
#       6 if len(results_df) == 0:
# ----> 7     raise ValueError("No valid submission was found with a non-NaN ROC AUC score.")
#       8
#       9 best_result = results_df.iloc[0]
#
# ValueError: No valid submission was found with a non-NaN ROC AUC score.

# %% [markdown]
# ## Retrain Final Models and Generate Final Submissions
#
# Optionally, you can retrain final models using the best hyperparameters from each pipeline on the entire training data and generate final submissions. This cell demonstrates that step.

# %%
# # Retrain final models with best parameters and generate final submissions
# for idx, row in results_df.iterrows():
#     prep = row['preprocessing']
#     best_params = row['best_params']
#     print(f"Retraining final model with preprocessing: {prep}")
    
#     steps = []
#     steps.append(('imputer', SimpleImputer(strategy="median")))
#     if prep in preprocessors and preprocessors[prep] is not None:
#         steps.append((prep, preprocessors[prep]))
#     steps.append(('dnn', dnn_wrapper.set_params(**best_params)))
#     final_pipeline = Pipeline(steps)
    
#     final_pipeline.fit(X, y)
#     final_preds = final_pipeline.predict_proba(X_test)[:, 1]
    
#     final_sub_filename = f"submissions/final_{prep}_dnn_submission.csv"
#     final_sub_df = pd.DataFrame({'id': test_ids, 'rainfall': final_preds})
#     final_sub_df.to_csv(final_sub_filename, index=False)
#     print(f"Final submission saved: {final_sub_filename}\n")

# %% [markdown]
# ## Conclusion
#
# - **Memory Optimization**: We downcast numeric columns to reduce memory usage.
# - **Missing Value Handling**: A SimpleImputer (median strategy) is included to ensure no NaN values persist.
# - **Preprocessing Pipelines**: We compared Standard, MinMax, Robust, and Raw (no scaling) in a pipeline with our DNN.
# - **GPU Acceleration**: The DNN is configured to run on GPU (if available) for competitive training speeds.
# - **Thorough Hyperparameter Tuning**: Using RandomizedSearchCV (50 iterations over 5-fold CV) we tuned optimizer, dropout rate, learning rate, epochs, and batch size.
# - **Submissions**: A submission file is generated for each preprocessing pipeline and saved in the "submissions" folder. The best scoring submission is explicitly copied to **submission.csv** as required.
#
# This code is designed for a competitive setting—adjust hyperparameter ranges, iterations, and preprocessing options as needed for further improvements. Happy modeling and best of luck in the competition!loration.
