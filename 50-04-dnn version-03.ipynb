# %% [markdown]
# ## Cell 0: Check for GPU Availability
#
# Ensure that TensorFlow detects one or more GPUs. Run this cell in a GPU-enabled environment (e.g., Kaggle Kernels with GPU).
# .

# %%
# Check GPU availability
import tensorflow as tf
print("GPUs Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ## Import Libraries
#
# We import necessary libraries including scikeras for wrapping our Keras model, and also import SimpleImputer (for missing value imputation). GPU-enabled training will be used if available.

# %%
# !pip install scikeras --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 88.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.6.1 which is incompatible.

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, time

from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# Install scikeras if needed
# !pip install scikeras --quiet
from scikeras.wrappers import KerasClassifier

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ## Memory Optimization Function
#
# This function attempts to reduce memory usage by downcasting numeric columns to smaller data types (e.g., float64 -> float32, int64 -> int32.

# %%
# Define memory optimization function
def reduce_memory_usage(df, verbose=True):
    """Downcasts numeric columns to reduce memory usage."""
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type == 'float64':
            df[col] = pd.to_numeric(df[col], downcast='float')
        elif col_type == 'int64':
            df[col] = pd.to_numeric(df[col], downcast='integer')
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print(f"Memory usage reduced from {start_mem:.2f} MB to {end_mem:.2f} MB "
              f"({100 * (start_mem - end_mem) / start_mem:.1f}% reduction)")
    return df

# %% [markdown]
# ## Load and Optimize Data
#
# We load our train/test data, apply the memory optimization function, and separate features/target. Adjust file names as needed for your environmen.

# %%
# Load and optimize data
train = pd.read_csv('/kaggle/input/playground-series-s5e3/train.csv')
test = pd.read_csv('/kaggle/input/playground-series-s5e3/test.csv')

print("Before memory optimization:")
print("Train shape:", train.shape)
print("Test shape:", test.shape)

train = reduce_memory_usage(train)
test = reduce_memory_usage(test)

# Separate features and target from training data
X = train.drop(columns=['id', 'rainfall'])
y = train['rainfall']

# For test data, drop the id column and save the IDs for submission
X_test = test.drop(columns=['id'])
test_ids = test['id']

print("After optimization:")
print("X shape:", X.shape)
print("X_test shape:", X_test.shape)
# Out:
# Before memory optimization:
# Train shape: (2190, 13)
# Test shape: (730, 12)
# Memory usage reduced from 0.22 MB to 0.09 MB (56.7% reduction)
# Memory usage reduced from 0.07 MB to 0.03 MB (54.1% reduction)
# After optimization:
# X shape: (2190, 11)
# X_test shape: (730, 11)

# %% [markdown]
# ## Define Preprocessing Pipelines
#
# We create a dictionary of scalers to compare (none, standard, minmax, robust). If you prefer, you can remove or add more pipeline.

# %%
# Define preprocessing pipelines
preprocessors = {
    # 'standard': StandardScaler(),
    # 'minmax': MinMaxScaler(),
    'robust': RobustScaler()
    #'raw': None
}

# %% [markdown]
# ## Define Keras Model Function
#
# We define a function that builds a DNN model. This will be used by the `KerasClassifier` wrapper. We'll allow hyperparameters like `optimizer`, `dropout_rate`, and `learning_rate` to be tune.

# %%
# Define the Keras model function
def create_dnn_model(optimizer='adam', dropout_rate=0.2, learning_rate=0.001):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    
    # Build optimizer with the specified learning rate
    if optimizer == 'adam':
        opt = Adam(learning_rate=learning_rate)
    else:
        opt = Adam(learning_rate=learning_rate)
    
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['AUC'])
    return model

# %% [markdown]
# ## Define KerasClassifier and Hyperparameter Grid
#
# We use the `KerasClassifier` wrapper from scikeras, which integrates with scikit-learn. We set up a parameter grid (or distribution) for random search. Adjust the ranges to fit your problem constraint
# We wrap our model with scikeras’ KerasClassifier. **Note:** For hyperparameters of the model-building function, we must use the prefix `model__` (and because the pipeline step is named `'dnn'`, we use `'dnn__model__'`)..

# %%
# Wrap the Keras model and define hyperparameter grid
dnn_wrapper = KerasClassifier(
    model=create_dnn_model,
    epochs=20,           # Default epochs; will be tuned
    batch_size=32,       # Default batch size; will be tuned
    verbose=1
)

# Hyperparameter grid using correct prefix "dnn__model__" for parameters passed to create_dnn_model.
param_dist = {
    'dnn__model__optimizer': ['adam', 'rmsprop'],
    'dnn__model__dropout_rate': [0.2, 0.3],
    'dnn__model__learning_rate': [1e-3, 1e-4],
    'dnn__epochs': [20, 30],
    'dnn__batch_size': [32, 64]
}

# %% [markdown]
# ## Hyperparameter Tuning and Submission Generation (Robust Scaling Only)
#
# We build a pipeline that first imputes missing values (using median strategy), then applies RobustScaler (our only option), and finally trains the DNN. We run RandomizedSearchCV (using a threading backend) for thorough tuning, re‑fit the best estimator, and generate test predictions. A submission file is saved.

# %%
# Run hyperparameter tuning and generate submission for Robust scaling only
from joblib import parallel_backend

results = []  # List to store tuning results
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Create a directory for submission files
os.makedirs("submissions", exist_ok=True)

# Since we only run Robust scaling, iterate over the single option
for prep_name, scaler in preprocessors.items():
    print(f"\n--- Preprocessing: {prep_name} ---")
    
    # Build pipeline: imputer -> RobustScaler -> DNN
    steps = []
    steps.append(('imputer', SimpleImputer(strategy="median")))
    if scaler is not None:
        steps.append((prep_name, scaler))
    steps.append(('dnn', dnn_wrapper))
    pipeline = Pipeline(steps)
    
    # Use threading backend to avoid pickling issues.
    with parallel_backend('threading', n_jobs=-1):
        search = RandomizedSearchCV(
            estimator=pipeline,
            param_distributions=param_dist,
            n_iter=50,
            scoring='roc_auc',
            cv=cv,
            verbose=1,
            random_state=42,
            n_jobs=-1
        )
        search.fit(X, y)
    
    best_score = search.best_score_
    best_params = search.best_params_
    
    print(f"Best CV ROC AUC for {prep_name}: {best_score:.4f}")
    print("Best parameters:", best_params)
    
    # Re-fit the best estimator on the full training data to ensure it is fitted.
    best_estimator = search.best_estimator_
    best_estimator.fit(X, y)
    
    # Generate test predictions (the imputer and scaler steps will automatically transform X_test)
    test_preds = best_estimator.predict_proba(X_test)[:, 1]
    
    # Save the submission file for Robust scaling
    sub_filename = f"submissions/{prep_name}_dnn_submission.csv"
    sub_df = pd.DataFrame({'id': test_ids, 'rainfall': test_preds})
    sub_df.to_csv(sub_filename, index=False)
    print(f"Submission file saved: {sub_filename}\n")
    
    # Record results for later comparison.
    results.append({
        'preprocessing': prep_name,
        'best_auc': best_score,
        'best_params': best_params,
        'submission_file': sub_filename
    })
# Out:
# --- Preprocessing: robust ---
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - AUC: 0.5722 - loss: 0.6547
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - AUC: 0.6654 - loss: 0.5883
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - AUC: 0.6959 - loss: 0.6105
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - AUC: 0.5901 - loss: 0.5681
# Epoch 2/20
# Epoch 2/20
# Epoch 2/20
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8697 - loss: 0.4058
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8438 - loss: 0.4034
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8511 - loss: 0.4161
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8632 - loss: 0.3956
# Epoch 3/20
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8803 - loss: 0.3534
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8701 - loss: 0.3716Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8747 - loss: 0.3628
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8633 - loss: 0.3585
# Epoch 4/20
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - AUC: 0.9657 - loss: 0.2801Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8701 - loss: 0.3716
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8879 - loss: 0.3483
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8795 - loss: 0.3611
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.8091 - loss: 0.4953Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8652 - loss: 0.3716
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8812 - loss: 0.3447
# Epoch 5/20
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8845 - loss: 0.3470
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8818 - loss: 0.3687Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8921 - loss: 0.3335
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8816 - loss: 0.3650
# 13/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9034 - loss: 0.3081 Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8890 - loss: 0.3480
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.8136 - loss: 0.5095Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9006 - loss: 0.3171
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8835 - loss: 0.3573Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8712 - loss: 0.3704
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8698 - loss: 0.3633Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8833 - loss: 0.3563
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8699 - loss: 0.3631
# Epoch 7/20
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9112 - loss: 0.3066
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8638 - loss: 0.3518Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8998 - loss: 0.3257
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8692 - loss: 0.3488
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8825 - loss: 0.3544
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9029 - loss: 0.3324
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8938 - loss: 0.3361
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8863 - loss: 0.3451
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8688 - loss: 0.3695
# Epoch 9/20
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9097 - loss: 0.3056
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8943 - loss: 0.3227Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8897 - loss: 0.3115
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8917 - loss: 0.3277
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8723 - loss: 0.3656
# 14/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9221 - loss: 0.2734 Epoch 10/20
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9058 - loss: 0.3116
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9045 - loss: 0.3213
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8865 - loss: 0.3398
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8964 - loss: 0.3302
# Epoch 11/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8937 - loss: 0.3350
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9000 - loss: 0.3174
# Epoch 12/20
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8999 - loss: 0.3194
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8859 - loss: 0.3525
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9029 - loss: 0.3172
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8979 - loss: 0.3291
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8799 - loss: 0.3612Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8825 - loss: 0.3552
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8895 - loss: 0.3300
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9013 - loss: 0.3157
# 27/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8700 - loss: 0.3683Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8583 - loss: 0.3775
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9034 - loss: 0.3107
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8783 - loss: 0.3587
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9203 - loss: 0.2921
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8870 - loss: 0.3330
# Epoch 15/20
# 28/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8797 - loss: 0.3667Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8976 - loss: 0.3324
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8829 - loss: 0.3576
# 25/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9212 - loss: 0.2739Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8881 - loss: 0.3487
# 27/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8940 - loss: 0.3513Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9133 - loss: 0.2929
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8936 - loss: 0.3442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8890 - loss: 0.3428
# Epoch 16/20
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9069 - loss: 0.3165
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8538 - loss: 0.4117 Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8978 - loss: 0.3223
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8786 - loss: 0.3607
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8883 - loss: 0.3301
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8992 - loss: 0.3252Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9056 - loss: 0.3148
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9011 - loss: 0.3234
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8784 - loss: 0.3569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9017 - loss: 0.3120
# Epoch 18/20
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8946 - loss: 0.3168Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8998 - loss: 0.3176
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.9010 - loss: 0.3689Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8968 - loss: 0.3175
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8960 - loss: 0.3348 Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9003 - loss: 0.3231
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8955 - loss: 0.3492
# Epoch 19/20
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9137 - loss: 0.3000Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8981 - loss: 0.3395
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - AUC: 0.9318 - loss: 0.3570Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9115 - loss: 0.3051
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8928 - loss: 0.3408
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8906 - loss: 0.3317
# Epoch 20/20
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8986 - loss: 0.3409
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9189 - loss: 0.3034
# 36/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8932 - loss: 0.3261Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8777 - loss: 0.3474
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8932 - loss: 0.3299
# Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - AUC: 0.6422 - loss: 0.6329
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - AUC: 0.5712 - loss: 0.6117
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8492 - loss: 0.4209
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - AUC: 0.6669 - loss: 0.5721Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8499 - loss: 0.4153
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - AUC: 0.6689 - loss: 0.5711
# Epoch 3/20
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - AUC: 0.6216 - loss: 0.7114
# 17/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8281 - loss: 0.3816 Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8573 - loss: 0.3691
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8404 - loss: 0.4691Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8877 - loss: 0.3666
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8595 - loss: 0.3746
# Epoch 3/20
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8481 - loss: 0.4551
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8772 - loss: 0.3451
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8939 - loss: 0.3321Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9046 - loss: 0.3225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8926 - loss: 0.3335
# Epoch 4/20
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8692 - loss: 0.3718
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8659 - loss: 0.3854
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8661 - loss: 0.3504Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8775 - loss: 0.3546
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8682 - loss: 0.3506
# Epoch 5/20
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.5943 - loss: 0.6982Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8713 - loss: 0.3463
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8695 - loss: 0.3648
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8771 - loss: 0.3562Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8773 - loss: 0.3560
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8970 - loss: 0.3347
# Epoch 6/20
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8985 - loss: 0.3218
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8775 - loss: 0.3511
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8872 - loss: 0.3560
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8871 - loss: 0.3489
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8845 - loss: 0.3273Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8846 - loss: 0.3287
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8861 - loss: 0.3526
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9004 - loss: 0.3261Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9002 - loss: 0.3264
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8965 - loss: 0.3327
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9071 - loss: 0.3058Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9056 - loss: 0.3090
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8767 - loss: 0.3467
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8905 - loss: 0.3433Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8910 - loss: 0.3419
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.7629 - loss: 0.4751Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9193 - loss: 0.3071
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8943 - loss: 0.3343Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8942 - loss: 0.3344
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8760 - loss: 0.3548
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9047 - loss: 0.3241
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8835 - loss: 0.3572
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8980 - loss: 0.3351Epoch 10/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8975 - loss: 0.3353
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8850 - loss: 0.3408
# 41/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8772 - loss: 0.3642Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8794 - loss: 0.3583
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8941 - loss: 0.3300
# Epoch 12/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9025 - loss: 0.3202
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8949 - loss: 0.3417
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8867 - loss: 0.3440Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9044 - loss: 0.3158
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8866 - loss: 0.3442
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9118 - loss: 0.3104
# Epoch 13/20
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8904 - loss: 0.3402
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8798 - loss: 0.3662Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.3569
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9076 - loss: 0.3059Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8837 - loss: 0.3576
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9075 - loss: 0.3067
# 12/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8966 - loss: 0.3308 Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8993 - loss: 0.3242
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9146 - loss: 0.3061Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9073 - loss: 0.3137
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8879 - loss: 0.3394Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8880 - loss: 0.3392
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9102 - loss: 0.3128
# 14/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8788 - loss: 0.3818 Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8792 - loss: 0.3643
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8757 - loss: 0.3579Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8796 - loss: 0.3521
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8992 - loss: 0.3158
# 14/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8550 - loss: 0.3863 Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9074 - loss: 0.3161
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.8219 - loss: 0.6022Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8800 - loss: 0.3533
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9170 - loss: 0.2938Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8875 - loss: 0.3579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8895 - loss: 0.3270
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9155 - loss: 0.2974
# Epoch 17/20
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8900 - loss: 0.3374
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8889 - loss: 0.3430
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8931 - loss: 0.3234
#  8/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8681 - loss: 0.3373 Epoch 17/20
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8968 - loss: 0.3160
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8894 - loss: 0.3368
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9092 - loss: 0.3216
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9098 - loss: 0.3101
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9059 - loss: 0.3141
# Epoch 19/20
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8993 - loss: 0.3202
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8817 - loss: 0.3337Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9039 - loss: 0.3136
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8983 - loss: 0.3260
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8862 - loss: 0.3319
# Epoch 20/20
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8925 - loss: 0.3392
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9208 - loss: 0.3003
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8913 - loss: 0.3492
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9097 - loss: 0.3123
# Epoch 20/20
# 14/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.9096 - loss: 0.2784Epoch 1/20
# 24/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9084 - loss: 0.2909Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.9059 - loss: 0.3050
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.9154 - loss: 0.3035
# Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - AUC: 0.5198 - loss: 0.6372
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - AUC: 0.6584 - loss: 0.6277
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8529 - loss: 0.4307
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8673 - loss: 0.4022
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - AUC: 0.5329 - loss: 0.7658
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8384 - loss: 0.3976
# Epoch 2/20
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8738 - loss: 0.3593
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - AUC: 0.4948 - loss: 0.7007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8816 - loss: 0.3476
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5546 - loss: 0.7156
# Epoch 5/20
# Epoch 2/20
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9022 - loss: 0.3239
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5861 - loss: 0.6624
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8913 - loss: 0.3516
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.6637 - loss: 0.6663
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8819 - loss: 0.3522
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6248 - loss: 0.6315
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6488 - loss: 0.6435Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8856 - loss: 0.3416
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.6516 - loss: 0.6424
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8893 - loss: 0.3336Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8888 - loss: 0.3349
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.7411 - loss: 0.5985Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8739 - loss: 0.3489
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7330 - loss: 0.5906
# Epoch 8/20
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7081 - loss: 0.6121
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8705 - loss: 0.3587
# 17/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7047 - loss: 0.5799 Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7373 - loss: 0.5707
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7369 - loss: 0.5868Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8903 - loss: 0.3337
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8646 - loss: 0.3469Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7367 - loss: 0.5865
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8731 - loss: 0.3407
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7796 - loss: 0.5466
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8849 - loss: 0.3410
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8924 - loss: 0.3326Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7388 - loss: 0.5646
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.8519 - loss: 0.4839Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8924 - loss: 0.3332
# 13/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8910 - loss: 0.3498 Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8080 - loss: 0.5121
# 51/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7697 - loss: 0.5376Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8941 - loss: 0.3327
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7702 - loss: 0.5375
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9108 - loss: 0.3088
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8124 - loss: 0.4952
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7887 - loss: 0.5132Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8970 - loss: 0.3424
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7894 - loss: 0.5134
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - AUC: 0.8914 - loss: 0.4409Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8922 - loss: 0.3386
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9221 - loss: 0.2887 Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8984 - loss: 0.3244
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8367 - loss: 0.4665
# Epoch 13/20
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8250 - loss: 0.4992
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8889 - loss: 0.3306
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8968 - loss: 0.3297
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8477 - loss: 0.4642
# Epoch 11/20
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8367 - loss: 0.4916
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8789 - loss: 0.3375
# 12/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8182 - loss: 0.4091 Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8241 - loss: 0.4417
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8661 - loss: 0.3640
# Epoch 12/20
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8330 - loss: 0.4743
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8887 - loss: 0.3435
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8603 - loss: 0.4147
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8981 - loss: 0.3326
# Epoch 13/20
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8335 - loss: 0.4529
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8855 - loss: 0.3482
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8937 - loss: 0.3425
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8971 - loss: 0.3168Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8645 - loss: 0.3964
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8640 - loss: 0.4284
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8971 - loss: 0.3195
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8904 - loss: 0.3242
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8762 - loss: 0.3900Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8759 - loss: 0.3899
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8484 - loss: 0.4200
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8937 - loss: 0.3321
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9182 - loss: 0.2875
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8692 - loss: 0.3780Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8701 - loss: 0.3774
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - AUC: 0.7778 - loss: 0.5693Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8775 - loss: 0.3920
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8951 - loss: 0.3276
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.4333 - loss: 0.4184Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8755 - loss: 0.3580
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8562 - loss: 0.3743Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8576 - loss: 0.3742
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8555 - loss: 0.4111
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8857 - loss: 0.3421Epoch 17/20
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - AUC: 0.9375 - loss: 0.2508Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8872 - loss: 0.3402
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.9103 - loss: 0.2927Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8771 - loss: 0.3497
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8840 - loss: 0.3520
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8663 - loss: 0.3933
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9027 - loss: 0.3191
# 16/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8964 - loss: 0.3723Epoch 1/20
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8788 - loss: 0.3501Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8819 - loss: 0.3512
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.8722 - loss: 0.3836
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.8822 - loss: 0.3632
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.8580 - loss: 0.3946
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.8615 - loss: 0.3716Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - AUC: 0.8688 - loss: 0.3646
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - AUC: 0.6064 - loss: 0.6783
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - AUC: 0.6610 - loss: 0.7284
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6786 - loss: 0.6918
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7074 - loss: 0.6585
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7576 - loss: 0.6180
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - AUC: 0.2555 - loss: 0.6740
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7730 - loss: 0.5918
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.3947 - loss: 0.6335
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8140 - loss: 0.5556
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.4884 - loss: 0.6032
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - AUC: 0.6233 - loss: 0.7243
# Epoch 4/20
# 19/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8359 - loss: 0.5324 Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8375 - loss: 0.5233
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7030 - loss: 0.6706
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6016 - loss: 0.5804
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8375 - loss: 0.5002
# 18/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7327 - loss: 0.5362 Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7221 - loss: 0.6366
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7175 - loss: 0.5423
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8280 - loss: 0.4795
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7651 - loss: 0.6003
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7767 - loss: 0.5161
# 33/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8358 - loss: 0.4571Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8394 - loss: 0.4549
# 18/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7812 - loss: 0.5213 Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7806 - loss: 0.5716
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7937 - loss: 0.4996
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8341 - loss: 0.4445
# 19/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8055 - loss: 0.5484 Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8070 - loss: 0.5465
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8227 - loss: 0.4622
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8585 - loss: 0.4214
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8197 - loss: 0.5193
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8146 - loss: 0.4579
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8590 - loss: 0.4093Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8612 - loss: 0.4066
# 21/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8488 - loss: 0.4938 Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8398 - loss: 0.4943
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8466 - loss: 0.4327
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8668 - loss: 0.3940
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8514 - loss: 0.4728
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8508 - loss: 0.4270
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8764 - loss: 0.3738
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8400 - loss: 0.4603
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8614 - loss: 0.4001
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8676 - loss: 0.3727
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8447 - loss: 0.4409
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8572 - loss: 0.3883
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.8171 - loss: 0.4590Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8612 - loss: 0.3754
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8380 - loss: 0.4336
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8635 - loss: 0.3815
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8636 - loss: 0.3710
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8834 - loss: 0.3923
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8761 - loss: 0.3667Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8755 - loss: 0.3676
# 32/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8755 - loss: 0.3675Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8725 - loss: 0.3707
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8670 - loss: 0.4025
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8907 - loss: 0.3611
# 30/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8686 - loss: 0.3748Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8725 - loss: 0.3654
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8660 - loss: 0.3944
# 16/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.6513 - loss: 0.6379Epoch 1/20
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8763 - loss: 0.3570
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - AUC: 0.6668 - loss: 0.6338
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8767 - loss: 0.3863Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8720 - loss: 0.3873
# 16/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7257 - loss: 0.6039Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8677 - loss: 0.3746
# 23/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7236 - loss: 0.6036Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.7317 - loss: 0.5987
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8626 - loss: 0.3927
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8794 - loss: 0.3599
# Epoch 18/20
# 26/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7279 - loss: 0.5667Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.7473 - loss: 0.5630
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8694 - loss: 0.3687
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - AUC: 0.8740 - loss: 0.3696
# 35/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7430 - loss: 0.5507Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.7595 - loss: 0.5443
# 19/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8764 - loss: 0.3614Epoch 6/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8679 - loss: 0.3757
# 26/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8030 - loss: 0.5040Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8155 - loss: 0.5005
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8532 - loss: 0.3885
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8262 - loss: 0.4814Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8270 - loss: 0.4805
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.8490 - loss: 0.4425
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8490 - loss: 0.4441
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8510 - loss: 0.4187
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.8570 - loss: 0.4195
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8684 - loss: 0.3897
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8779 - loss: 0.3802
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8740 - loss: 0.3684
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - AUC: 0.6476 - loss: 0.6720
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - AUC: 0.8599 - loss: 0.3983Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8744 - loss: 0.3637
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7150 - loss: 0.6220
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8748 - loss: 0.3696
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7360 - loss: 0.5924
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8812 - loss: 0.3566
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7575 - loss: 0.5603
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8764 - loss: 0.3684
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8611 - loss: 0.3732
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - AUC: 0.7897 - loss: 0.5309
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8663 - loss: 0.3741
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8213 - loss: 0.4991
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.6204 - loss: 0.6776Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8380 - loss: 0.4827
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - AUC: 0.4301 - loss: 0.6478
# Epoch 8/20
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8565 - loss: 0.4432
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8487 - loss: 0.4425
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8605 - loss: 0.4128
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8720 - loss: 0.4082
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - AUC: 0.6213 - loss: 0.6755
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8733 - loss: 0.3932
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6877 - loss: 0.6196
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8899 - loss: 0.3675
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7446 - loss: 0.5853
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8645 - loss: 0.3838
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7706 - loss: 0.5536
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8888 - loss: 0.3658
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8060 - loss: 0.5178
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8801 - loss: 0.3774
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8261 - loss: 0.4856
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8792 - loss: 0.3741
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8311 - loss: 0.4713
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8835 - loss: 0.3557
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8264 - loss: 0.4558
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8886 - loss: 0.3497
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8649 - loss: 0.4162
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8847 - loss: 0.3534
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - AUC: 0.8148 - loss: 0.4491Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8473 - loss: 0.4119
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8585 - loss: 0.3989
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8574 - loss: 0.3953
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8559 - loss: 0.3920
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8659 - loss: 0.3803
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8686 - loss: 0.3759
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - AUC: 0.6595 - loss: 0.6520
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8786 - loss: 0.3586
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - AUC: 0.4824 - loss: 0.6250
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8694 - loss: 0.3630
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7331 - loss: 0.6053
# Epoch 18/20
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6018 - loss: 0.5888
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8616 - loss: 0.3665
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7719 - loss: 0.5759
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7074 - loss: 0.5450
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8729 - loss: 0.3686
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7651 - loss: 0.5510
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7474 - loss: 0.5272
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - AUC: 0.9427 - loss: 0.2953Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8811 - loss: 0.3558
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8095 - loss: 0.5161
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7983 - loss: 0.5052
# Epoch 7/20
#  8/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8134 - loss: 0.4711 Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8321 - loss: 0.4782
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8232 - loss: 0.4779
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - AUC: 0.9821 - loss: 0.3899Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8530 - loss: 0.4579
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8480 - loss: 0.4630Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8480 - loss: 0.4629
# 13/55 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.4223 - loss: 0.6724Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8398 - loss: 0.4440
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8461 - loss: 0.4239Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8471 - loss: 0.4255
#  8/55 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.8632 - loss: 0.4099Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8580 - loss: 0.4172
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8380 - loss: 0.4271
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8581 - loss: 0.4097
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8534 - loss: 0.4289
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8613 - loss: 0.3886
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8686 - loss: 0.3968Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8680 - loss: 0.3972
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8773 - loss: 0.3896
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8666 - loss: 0.3647  Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8695 - loss: 0.3773
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8744 - loss: 0.3759
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8773 - loss: 0.3735
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8855 - loss: 0.3673
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8795 - loss: 0.3685
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8841 - loss: 0.3386
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8526 - loss: 0.3995
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8555 - loss: 0.3792Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8587 - loss: 0.3770
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - AUC: 0.5282 - loss: 0.6231
# 45/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8755 - loss: 0.3660Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8821 - loss: 0.3671
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8756 - loss: 0.3658
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - AUC: 0.9115 - loss: 0.3194Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8310 - loss: 0.4361
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8762 - loss: 0.3633
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8875 - loss: 0.3551
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8673 - loss: 0.3714
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8867 - loss: 0.3499
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8786 - loss: 0.3576
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8695 - loss: 0.3753
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8824 - loss: 0.3430Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8818 - loss: 0.3416
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8806 - loss: 0.3464
# 35/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8958 - loss: 0.3481Epoch 1/20
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8896 - loss: 0.3525Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8880 - loss: 0.3535
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.8617 - loss: 0.3809
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - AUC: 0.6889 - loss: 0.6047
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - AUC: 0.8791 - loss: 0.3639Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - AUC: 0.8772 - loss: 0.3634
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - AUC: 0.8626 - loss: 0.4016
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8796 - loss: 0.3567
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8597 - loss: 0.3824
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8772 - loss: 0.3513
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8832 - loss: 0.3442
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.8442 - loss: 0.5246Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8862 - loss: 0.3344
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8823 - loss: 0.3518
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8849 - loss: 0.3392
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8950 - loss: 0.3280Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8923 - loss: 0.3346
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8786 - loss: 0.3642
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8937 - loss: 0.3413
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8769 - loss: 0.3638
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8810 - loss: 0.3424
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9058 - loss: 0.3243
# 35/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8966 - loss: 0.3269Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8967 - loss: 0.3290
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9068 - loss: 0.3191
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8880 - loss: 0.3337
# 46/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9035 - loss: 0.3194Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9012 - loss: 0.3228
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - AUC: 0.9635 - loss: 0.2262Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8916 - loss: 0.3307
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8991 - loss: 0.3254
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - AUC: 0.9829 - loss: 0.1682Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9236 - loss: 0.2859
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8845 - loss: 0.3550
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8889 - loss: 0.3388
# 30/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6117 - loss: 0.6136Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8621 - loss: 0.3788
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9060 - loss: 0.3124
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8859 - loss: 0.3465
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8950 - loss: 0.3350Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8962 - loss: 0.3332
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.9082 - loss: 0.3144
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.9091 - loss: 0.3186
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.9213 - loss: 0.2915
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - AUC: 0.6659 - loss: 0.5780
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - AUC: 0.5815 - loss: 0.6363
# 11/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8265 - loss: 0.4288Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9044 - loss: 0.3184
# 19/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8019 - loss: 0.4801 Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8504 - loss: 0.3973
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8301 - loss: 0.4404
# 30/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8841 - loss: 0.3459Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8941 - loss: 0.3341
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8807 - loss: 0.3527
# 47/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8584 - loss: 0.3972Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8600 - loss: 0.3942Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8601 - loss: 0.3938
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8598 - loss: 0.3974
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8616 - loss: 0.3694
#  7/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8872 - loss: 0.3509 Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8763 - loss: 0.3573
# 48/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8862 - loss: 0.3441Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8862 - loss: 0.3445
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8583 - loss: 0.3791
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8937 - loss: 0.3476
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8783 - loss: 0.3652Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - AUC: 0.8786 - loss: 0.3645
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8465 - loss: 0.3935
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8977 - loss: 0.3187
# Epoch 9/20
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9097 - loss: 0.3034
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8825 - loss: 0.3407
# Epoch 9/20
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8797 - loss: 0.3514
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8849 - loss: 0.3509
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8676 - loss: 0.3558
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8736 - loss: 0.3561
# Epoch 12/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9034 - loss: 0.3227
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8777 - loss: 0.3495
# Epoch 12/20
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8856 - loss: 0.3275
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8909 - loss: 0.3313
# Epoch 14/20
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9055 - loss: 0.3178
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9045 - loss: 0.3242
# Epoch 15/20
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8719 - loss: 0.3525
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8759 - loss: 0.3567
# Epoch 16/20
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8962 - loss: 0.3314
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9065 - loss: 0.3281
# Epoch 16/20
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - AUC: 0.6625 - loss: 0.6047
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9030 - loss: 0.3257
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8894 - loss: 0.3438
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8323 - loss: 0.4244
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8844 - loss: 0.3446Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8868 - loss: 0.3425
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8871 - loss: 0.3415
# Epoch 18/20
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8847 - loss: 0.3419
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9066 - loss: 0.3115
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8871 - loss: 0.3444
# 17/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8480 - loss: 0.4552 Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8640 - loss: 0.3970
# 32/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8830 - loss: 0.3332Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8966 - loss: 0.3217
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8692 - loss: 0.3833 Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8864 - loss: 0.3313
# ...
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7404 - loss: 0.5932
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6341 - loss: 0.5733
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7424 - loss: 0.5787
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7039 - loss: 0.5540
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7811 - loss: 0.5532
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6923 - loss: 0.5459
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7897 - loss: 0.5485
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7501 - loss: 0.5267
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7820 - loss: 0.5355
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7832 - loss: 0.5187
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8119 - loss: 0.5240
# 16/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8066 - loss: 0.4968 Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7982 - loss: 0.5003
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8148 - loss: 0.5095
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8028 - loss: 0.4864
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - AUC: 0.8019 - loss: 0.4967Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8359 - loss: 0.4927
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7881 - loss: 0.4970
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8144 - loss: 0.4863
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8245 - loss: 0.4685
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8362 - loss: 0.4793
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8219 - loss: 0.4687
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8287 - loss: 0.4718
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8407 - loss: 0.4484
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8500 - loss: 0.4534
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8351 - loss: 0.4533
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8531 - loss: 0.4511
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8466 - loss: 0.4385
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8549 - loss: 0.4317
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8628 - loss: 0.4188
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8580 - loss: 0.4248
# 23/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8752 - loss: 0.3978Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8711 - loss: 0.4021
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8474 - loss: 0.4319
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8669 - loss: 0.4153
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8566 - loss: 0.4172
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8712 - loss: 0.4128
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8416 - loss: 0.4119
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - AUC: 0.7565 - loss: 0.5433Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8327 - loss: 0.4285
# 22/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.4642 - loss: 0.8205Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8772 - loss: 0.3907
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8677 - loss: 0.4037
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8756 - loss: 0.3843
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8677 - loss: 0.3966
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8674 - loss: 0.3831
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8639 - loss: 0.4008
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8734 - loss: 0.3676
# Epoch 27/30
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8781 - loss: 0.3837
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8714 - loss: 0.3848
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8839 - loss: 0.3834
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8633 - loss: 0.3870
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8675 - loss: 0.3872
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8775 - loss: 0.3795
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8852 - loss: 0.3618
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - AUC: 0.4495 - loss: 0.7499
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.4465 - loss: 0.7360
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5246 - loss: 0.6903
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - AUC: 0.4732 - loss: 0.8153
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5081 - loss: 0.6808
# 25/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5452 - loss: 0.7705 Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5430 - loss: 0.7699
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5716 - loss: 0.6545
# 26/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5176 - loss: 0.7555 Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5208 - loss: 0.7538
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6146 - loss: 0.6386
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5717 - loss: 0.7259
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6353 - loss: 0.6195
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6093 - loss: 0.7083
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6666 - loss: 0.6038
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6439 - loss: 0.6816
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6869 - loss: 0.5879
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6957 - loss: 0.6630
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7320 - loss: 0.5661
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6331 - loss: 0.6587
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7685 - loss: 0.5508
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7118 - loss: 0.6340
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7439 - loss: 0.5492
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7285 - loss: 0.6190
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7659 - loss: 0.5261
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7649 - loss: 0.6034
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7891 - loss: 0.5053
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7572 - loss: 0.5933
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7882 - loss: 0.5013
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7913 - loss: 0.5756
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7915 - loss: 0.4983
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7683 - loss: 0.5654
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8183 - loss: 0.4772
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7916 - loss: 0.5431
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8148 - loss: 0.4747
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7793 - loss: 0.5401
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8128 - loss: 0.4740
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7821 - loss: 0.5300
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8305 - loss: 0.4425
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8135 - loss: 0.5141
# Epoch 21/30
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8253 - loss: 0.4470
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8026 - loss: 0.4927
# Epoch 22/30
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8107 - loss: 0.4859
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8356 - loss: 0.4357
# Epoch 21/30
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8213 - loss: 0.4727
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8615 - loss: 0.4072
# Epoch 22/30
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8283 - loss: 0.4646
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8344 - loss: 0.4249
# Epoch 23/30
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8463 - loss: 0.4508
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8551 - loss: 0.4049
# Epoch 24/30
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8559 - loss: 0.4419
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8518 - loss: 0.4031
# Epoch 25/30
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8519 - loss: 0.4247
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8622 - loss: 0.4021
# Epoch 26/30
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8188 - loss: 0.4451
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8615 - loss: 0.3985
# Epoch 27/30
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8585 - loss: 0.4144
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8385 - loss: 0.4003
# Epoch 28/30
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8490 - loss: 0.4089
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8635 - loss: 0.3849
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8069 - loss: 0.4447
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8795 - loss: 0.3894
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - AUC: 0.5090 - loss: 0.6169
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8625 - loss: 0.4111
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8800 - loss: 0.3499
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8809 - loss: 0.3605
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8850 - loss: 0.3502
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8958 - loss: 0.3333
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8844 - loss: 0.3504
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8955 - loss: 0.3505
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8907 - loss: 0.3496
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9035 - loss: 0.3233
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8821 - loss: 0.3432
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8819 - loss: 0.3476
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8903 - loss: 0.3510
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9087 - loss: 0.3060
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8917 - loss: 0.3343
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8916 - loss: 0.3286
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8940 - loss: 0.3360
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8970 - loss: 0.3167
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8896 - loss: 0.3416
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8875 - loss: 0.3529
# Best CV ROC AUC for robust: nan
# Best parameters: {'dnn__model__optimizer': 'adam', 'dnn__model__learning_rate': 0.001, 'dnn__model__dropout_rate': 0.2, 'dnn__epochs': 20, 'dnn__batch_size': 32}
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - AUC: 0.4881 - loss: 0.6789
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8455 - loss: 0.4004
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8718 - loss: 0.3634
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8783 - loss: 0.3547
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8924 - loss: 0.3252
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8944 - loss: 0.3308
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9100 - loss: 0.3017
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9006 - loss: 0.3277
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8856 - loss: 0.3414
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8982 - loss: 0.3278
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8854 - loss: 0.3344
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9016 - loss: 0.3260
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9019 - loss: 0.3176
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9111 - loss: 0.3071
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9125 - loss: 0.3049
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8887 - loss: 0.3382
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8889 - loss: 0.3431
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8975 - loss: 0.3220
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8976 - loss: 0.3335
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9007 - loss: 0.3288
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-be26b33a2c68> in <cell line: 11>()
#      45
#      46     # Generate test predictions (the imputer and scaler steps will automatically transform X_test)
# ---> 47     test_preds = best_estimator.predict_proba(X_test)[:, 1]
#      48
#      49     # Save the submission file for Robust scaling
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in predict_proba(self, X, **params)
#     896         """
#     897         # TODO(1.8): Remove the context manager and use check_is_fitted(self)
# --> 898         with _raise_or_warn_if_not_fitted(self):
#     899             Xt = X
#     900
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     140         if typ is None:
#     141             try:
# --> 142                 next(self.gen)
#     143             except StopIteration:
#     144                 return False
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in _raise_or_warn_if_not_fitted(estimator)
#      58     # we only get here if the above didn't raise
#      59     try:
# ---> 60         check_is_fitted(estimator)
#      61     except NotFittedError:
#      62         warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1754         return
#    1755
# -> 1756     if not _is_fitted(estimator, attributes, all_or_any):
#    1757         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1758
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _is_fitted(estimator, attributes, all_or_any)
#    1663
#    1664     if hasattr(estimator, "__sklearn_is_fitted__"):
# -> 1665         return estimator.__sklearn_is_fitted__()
#    1666
#    1667     fitted_attrs = [
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in __sklearn_is_fitted__(self)
#    1319             # means the previous steps should also be fit. This is faster than
#    1320             # checking if every step of the pipeline is fit.
# -> 1321             check_is_fitted(last_step)
#    1322             return True
#    1323         except NotFittedError:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1749         raise TypeError("%s is not an estimator instance." % (estimator))
#    1750
# -> 1751     tags = get_tags(estimator)
#    1752
#    1753     if not tags.requires_fit and attributes is None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py in get_tags(estimator)
#     428         for klass in reversed(type(estimator).mro()):
#     429             if "__sklearn_tags__" in vars(klass):
# --> 430                 sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431                 class_order.append(klass)
#     432             elif "_more_tags" in vars(klass):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in __sklearn_tags__(self)
#     538
#     539     def __sklearn_tags__(self):
# --> 540         tags = super().__sklearn_tags__()
#     541         tags.estimator_type = "classifier"
#     542         tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'

# %% [markdown]
# ## Compare Results
#
# We create a DataFrame from the results and sort by the best AUC score to see which preprocessing pipeline + hyperparameters performed bes.

# %%
# Compare results across pipelines
results_df = pd.DataFrame(results).sort_values(by='best_auc', ascending=False)
print("\nComparison of Preprocessing Approaches:")
display(results_df)

# %% [markdown]
# ## Copy Best Scoring Submission as submission.csv
#
# From the tuning results, we identify the best scoring submission and copy that file to "submission.csv" (the name required by the competition). All other submission file names remain unchanged..

# %%
# Copy the best scoring submission to "submission.csv"
import shutil

# Filter out any candidates with NaN scores and pick the best candidate
results_df = results_df[results_df['best_auc'].notna()]
if len(results_df) == 0:
    raise ValueError("No valid submission was found with a non-NaN ROC AUC score.")

best_result = results_df.iloc[0]
best_submission_file = best_result['submission_file']

# Copy the best submission file to "submission.csv"
shutil.copy(best_submission_file, 'submission.csv')
print(f"Best scoring submission ({best_submission_file}) copied as 'submission.csv'")

# %% [markdown]
# ## Retrain Final Models and Generate Final Submissions
#
# Optionally, you can retrain final models using the best hyperparameters from each pipeline on the entire training data and generate final submissions. This cell demonstrates that step.

# %%
# # Retrain final models with best parameters and generate final submissions
# for idx, row in results_df.iterrows():
#     prep = row['preprocessing']
#     best_params = row['best_params']
#     print(f"Retraining final model with preprocessing: {prep}")
    
#     steps = []
#     steps.append(('imputer', SimpleImputer(strategy="median")))
#     if prep in preprocessors and preprocessors[prep] is not None:
#         steps.append((prep, preprocessors[prep]))
#     steps.append(('dnn', dnn_wrapper.set_params(**best_params)))
#     final_pipeline = Pipeline(steps)
    
#     final_pipeline.fit(X, y)
#     final_preds = final_pipeline.predict_proba(X_test)[:, 1]
    
#     final_sub_filename = f"submissions/final_{prep}_dnn_submission.csv"
#     final_sub_df = pd.DataFrame({'id': test_ids, 'rainfall': final_preds})
#     final_sub_df.to_csv(final_sub_filename, index=False)
#     print(f"Final submission saved: {final_sub_filename}\n")

# %% [markdown]
# ## Conclusion
#
# - **Memory Optimization**: We downcast numeric columns to reduce memory usage.
# - **Missing Value Handling**: A SimpleImputer (median strategy) is included to ensure no NaN values persist.
# - **Preprocessing Pipelines**: We compared Standard, MinMax, Robust, and Raw (no scaling) in a pipeline with our DNN.
# - **GPU Acceleration**: The DNN is configured to run on GPU (if available) for competitive training speeds.
# - **Thorough Hyperparameter Tuning**: Using RandomizedSearchCV (50 iterations over 5-fold CV) we tuned optimizer, dropout rate, learning rate, epochs, and batch size.
# - **Submissions**: A submission file is generated for each preprocessing pipeline and saved in the "submissions" folder. The best scoring submission is explicitly copied to **submission.csv** as required.
#
# This code is designed for a competitive setting—adjust hyperparameter ranges, iterations, and preprocessing options as needed for further improvements. Happy modeling and best of luck in the competition!loration.
