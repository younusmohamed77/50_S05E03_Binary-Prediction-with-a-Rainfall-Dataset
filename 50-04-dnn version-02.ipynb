# %% [markdown]
# ## DNN
# ## Check for GPU Availability
#
# Ensure that TensorFlow detects a GPU. Run this cell in a GPU-enabled environment (e.g., Kaggle Kernels with GPU or a local GPU machine.
# .

# %%
# Check GPU availability
import tensorflow as tf
print("GPUs Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ## Import Libraries
#
# We import necessary libraries including scikeras for wrapping our Keras model, and also import SimpleImputer (for missing value imputation). GPU-enabled training will be used if available.

# %%
# !pip install scikeras --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 92.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.6.1 which is incompatible.

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, time

from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# Install scikeras if needed
# !pip install scikeras --quiet
from scikeras.wrappers import KerasClassifier

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ## Memory Optimization Function
#
# This function attempts to reduce memory usage by downcasting numeric columns to smaller data types (e.g., float64 -> float32, int64 -> int32.

# %%
# Define memory optimization function
def reduce_memory_usage(df, verbose=True):
    """Downcasts numeric columns to reduce memory usage."""
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type == 'float64':
            df[col] = pd.to_numeric(df[col], downcast='float')
        elif col_type == 'int64':
            df[col] = pd.to_numeric(df[col], downcast='integer')
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print(f"Memory usage reduced from {start_mem:.2f} MB to {end_mem:.2f} MB "
              f"({100 * (start_mem - end_mem) / start_mem:.1f}% reduction)")
    return df

# %% [markdown]
# ## Load and Optimize Data
#
# We load our train/test data, apply the memory optimization function, and separate features/target. Adjust file names as needed for your environmen.

# %%
# Load and optimize data
train = pd.read_csv('/kaggle/input/playground-series-s5e3/train.csv')
test = pd.read_csv('/kaggle/input/playground-series-s5e3/test.csv')

print("Before memory optimization:")
print("Train shape:", train.shape)
print("Test shape:", test.shape)

train = reduce_memory_usage(train)
test = reduce_memory_usage(test)

# Separate features and target from training data
X = train.drop(columns=['id', 'rainfall'])
y = train['rainfall']

# For test data, drop the id column and save the IDs for submission
X_test = test.drop(columns=['id'])
test_ids = test['id']

print("After optimization:")
print("X shape:", X.shape)
print("X_test shape:", X_test.shape)
# Out:
# Before memory optimization:
# Train shape: (2190, 13)
# Test shape: (730, 12)
# Memory usage reduced from 0.22 MB to 0.09 MB (56.7% reduction)
# Memory usage reduced from 0.07 MB to 0.03 MB (54.1% reduction)
# After optimization:
# X shape: (2190, 11)
# X_test shape: (730, 11)

# %% [markdown]
# ## Define Preprocessing Pipelines
#
# We create a dictionary of scalers to compare (none, standard, minmax, robust). If you prefer, you can remove or add more pipeline.

# %%
# Define preprocessing pipelines
preprocessors = {
    'standard': StandardScaler(),
    'minmax': MinMaxScaler(),
    'robust': RobustScaler(),
    'raw': None
}

# %% [markdown]
# ## Define Keras Model Function
#
# We define a function that builds a DNN model. This will be used by the `KerasClassifier` wrapper. We'll allow hyperparameters like `optimizer`, `dropout_rate`, and `learning_rate` to be tune.

# %%
# Define the Keras model function
def create_dnn_model(optimizer='adam', dropout_rate=0.2, learning_rate=0.001):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    
    # Build optimizer with the specified learning rate
    if optimizer == 'adam':
        opt = Adam(learning_rate=learning_rate)
    else:
        opt = Adam(learning_rate=learning_rate)
    
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['AUC'])
    return model

# %% [markdown]
# ## Define KerasClassifier and Hyperparameter Grid
#
# We use the `KerasClassifier` wrapper from scikeras, which integrates with scikit-learn. We set up a parameter grid (or distribution) for random search. Adjust the ranges to fit your problem constraint
# We wrap our model with scikeras’ KerasClassifier. **Note:** For hyperparameters of the model-building function, we must use the prefix `model__` (and because the pipeline step is named `'dnn'`, we use `'dnn__model__'`)..

# %%
# Wrap the Keras model and define hyperparameter grid
dnn_wrapper = KerasClassifier(
    model=create_dnn_model,
    epochs=20,           # Default epochs; will be tuned
    batch_size=32,       # Default batch size; will be tuned
    verbose=1
)

# Hyperparameter grid using correct prefix "dnn__model__" for parameters passed to create_dnn_model.
param_dist = {
    'dnn__model__optimizer': ['adam', 'rmsprop'],
    'dnn__model__dropout_rate': [0.2, 0.3],
    'dnn__model__learning_rate': [1e-3, 1e-4],
    'dnn__epochs': [20, 30],
    'dnn__batch_size': [32, 64]
}

# %% [markdown]
# ## Randomized Search and Submission Generation
#
# For each preprocessing pipeline, we build a pipeline that first imputes missing values (using median strategy), then applies the scaler (if any), and finally trains the DNN. To avoid pickling errors in parallel processing, we run the search within a threading backend context. A submission file is generated for each pipeline.

# %%
# Hyperparameter tuning and generate submissions
from joblib import parallel_backend

results = []  # List to store tuning results
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Create a directory for submission files
os.makedirs("submissions", exist_ok=True)

for prep_name, scaler in preprocessors.items():
    print(f"\n--- Preprocessing: {prep_name} ---")
    
    # Build pipeline: imputer -> (scaler if any) -> DNN
    steps = []
    steps.append(('imputer', SimpleImputer(strategy="median")))
    if scaler is not None:
        steps.append((prep_name, scaler))
    steps.append(('dnn', dnn_wrapper))
    pipeline = Pipeline(steps)
    
    # Use threading backend to avoid pickling issues
    with parallel_backend('threading', n_jobs=-1):
        search = RandomizedSearchCV(
            estimator=pipeline,
            param_distributions=param_dist,
            n_iter=50,
            scoring='roc_auc',
            cv=cv,
            verbose=1,
            random_state=42,
            n_jobs=-1
        )
        search.fit(X, y)
    
    best_score = search.best_score_
    best_params = search.best_params_
    
    print(f"Best CV ROC AUC for {prep_name}: {best_score:.4f}")
    print("Best parameters:", best_params)
    
    # Re-fit the best estimator on the full training data to ensure it is fitted
    best_estimator = search.best_estimator_
    best_estimator.fit(X, y)
    
    # Generate test predictions (the imputer and scaler steps will automatically transform X_test)
    test_preds = best_estimator.predict_proba(X_test)[:, 1]
    
    # Save the submission file for this preprocessing method
    sub_filename = f"submissions/{prep_name}_dnn_submission.csv"
    sub_df = pd.DataFrame({'id': test_ids, 'rainfall': test_preds})
    sub_df.to_csv(sub_filename, index=False)
    print(f"Submission file saved: {sub_filename}\n")
    
    # Record results for later comparison.
    results.append({
        'preprocessing': prep_name,
        'best_auc': best_score,
        'best_params': best_params,
        'submission_file': sub_filename
    })
# Out:
# --- Preprocessing: standard ---
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - AUC: 0.5822 - loss: 0.5715
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - AUC: 0.6507 - loss: 0.6705
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - AUC: 0.6910 - loss: 0.5949
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - AUC: 0.6106 - loss: 0.6937
# Epoch 2/20
# Epoch 2/20
# Epoch 2/20
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8546 - loss: 0.3907
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8566 - loss: 0.4042
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8487 - loss: 0.4112
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8609 - loss: 0.3998
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8643 - loss: 0.3880
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8830 - loss: 0.3533
# Epoch 4/20
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8906 - loss: 0.3525
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8814 - loss: 0.3446
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8387 - loss: 0.3898
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8830 - loss: 0.3422Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8824 - loss: 0.3510
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8830 - loss: 0.3424
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8912 - loss: 0.3406
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.9375 - loss: 0.3924Epoch 5/20
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8685 - loss: 0.3834
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9039 - loss: 0.3207Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9034 - loss: 0.3214
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8841 - loss: 0.3520Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8689 - loss: 0.3608
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8841 - loss: 0.3515
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - AUC: 0.9551 - loss: 0.2392Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8945 - loss: 0.3320
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8959 - loss: 0.3250
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8948 - loss: 0.3240
# Epoch 7/20
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8870 - loss: 0.3544Epoch 7/20
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8868 - loss: 0.3537
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8828 - loss: 0.3356
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9071 - loss: 0.3245
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9044 - loss: 0.3181
# Epoch 8/20
# Epoch 8/20
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8840 - loss: 0.3557
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8949 - loss: 0.3301
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8918 - loss: 0.3310
# Epoch 9/20
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8891 - loss: 0.3362
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8803 - loss: 0.3560
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8588 - loss: 0.3813
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9104 - loss: 0.3094
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8899 - loss: 0.3367
# Epoch 10/20
# Epoch 10/20
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8935 - loss: 0.3185
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9102 - loss: 0.3062
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8895 - loss: 0.3446
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9059 - loss: 0.3079
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8933 - loss: 0.3381
# Epoch 11/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9097 - loss: 0.3101
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8870 - loss: 0.3591Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8871 - loss: 0.3584
# 52/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8763 - loss: 0.3431Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8962 - loss: 0.3291
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8772 - loss: 0.3426
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8976 - loss: 0.3370
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8802 - loss: 0.3428
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9030 - loss: 0.3178
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8958 - loss: 0.3322
# Epoch 13/20
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9049 - loss: 0.3082
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8745 - loss: 0.3665
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9034 - loss: 0.3314
# Epoch 14/20
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8793 - loss: 0.3506
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.6636 - loss: 0.6525Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8998 - loss: 0.3300
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8793 - loss: 0.3567
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9061 - loss: 0.3169
# Epoch 15/20
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8845 - loss: 0.3476
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9108 - loss: 0.3017
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9154 - loss: 0.3113
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8819 - loss: 0.3562
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8939 - loss: 0.3252
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9106 - loss: 0.3134
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8970 - loss: 0.3267Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9011 - loss: 0.3209
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - AUC: 0.8831 - loss: 0.3935Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8954 - loss: 0.3281
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8784 - loss: 0.3706
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9119 - loss: 0.3178
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8867 - loss: 0.3478Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8915 - loss: 0.3366
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8839 - loss: 0.3645
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - AUC: 0.9437 - loss: 0.2635Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8868 - loss: 0.3471
# 17/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9303 - loss: 0.2826 Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9165 - loss: 0.3010
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8927 - loss: 0.3362
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - AUC: 0.9952 - loss: 0.2138Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8791 - loss: 0.3482
# 49/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8860 - loss: 0.3344Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8858 - loss: 0.3361
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9134 - loss: 0.3077
# 27/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8762 - loss: 0.3672Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9018 - loss: 0.3345
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8952 - loss: 0.3225
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8811 - loss: 0.3587
# 28/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9011 - loss: 0.3160Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9045 - loss: 0.3154
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9179 - loss: 0.3007
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8795 - loss: 0.3560
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8882 - loss: 0.3357Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8881 - loss: 0.3360
# Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - AUC: 0.6858 - loss: 0.6224
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - AUC: 0.5900 - loss: 0.5875
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8503 - loss: 0.3996
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - AUC: 0.7070 - loss: 0.5775
# Epoch 3/20
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8841 - loss: 0.3569
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8670 - loss: 0.3764
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8781 - loss: 0.3660
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8813 - loss: 0.3583
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - AUC: 0.5333 - loss: 0.5814
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8800 - loss: 0.3498
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8778 - loss: 0.3524
# Epoch 6/20
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8864 - loss: 0.3685
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8697 - loss: 0.3646
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8803 - loss: 0.3479
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8530 - loss: 0.3833
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8761 - loss: 0.3446
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9093 - loss: 0.3123
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8783 - loss: 0.3427
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9026 - loss: 0.3319Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8980 - loss: 0.3348
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8902 - loss: 0.3328
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8798 - loss: 0.3606
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8910 - loss: 0.3355
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8945 - loss: 0.3229
# 21/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8672 - loss: 0.3708 Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8743 - loss: 0.3616
# 38/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8905 - loss: 0.3285Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8894 - loss: 0.3323
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8999 - loss: 0.3219
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8939 - loss: 0.3335
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8754 - loss: 0.3608
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8886 - loss: 0.3554
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8913 - loss: 0.3490Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8913 - loss: 0.3487
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8962 - loss: 0.3369
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8869 - loss: 0.3582
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8971 - loss: 0.3300
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8895 - loss: 0.3272
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8953 - loss: 0.3361
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8958 - loss: 0.3291
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8912 - loss: 0.3370
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9049 - loss: 0.3245
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8930 - loss: 0.3288
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9000 - loss: 0.3216
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8914 - loss: 0.3360
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8947 - loss: 0.3384
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8936 - loss: 0.3372
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8888 - loss: 0.3449
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8694 - loss: 0.3532
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8977 - loss: 0.3149
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9043 - loss: 0.3261
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8886 - loss: 0.3618
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9016 - loss: 0.3235
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8842 - loss: 0.3397
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8973 - loss: 0.3294
# 40/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8970 - loss: 0.3158Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8960 - loss: 0.3195
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8914 - loss: 0.3369
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9043 - loss: 0.3074
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9161 - loss: 0.3078
# 20/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8926 - loss: 0.3208 Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8949 - loss: 0.3291
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9015 - loss: 0.3176
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8961 - loss: 0.3213
# 13/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9002 - loss: 0.3369 Epoch 1/20
# 31/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8942 - loss: 0.3410Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8937 - loss: 0.3391
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - AUC: 0.8997 - loss: 0.3205
# 18/55 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - AUC: 0.8563 - loss: 0.4028Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - AUC: 0.8696 - loss: 0.3773
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - AUC: 0.9117 - loss: 0.3064
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8774 - loss: 0.3667Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.8796 - loss: 0.3611
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8913 - loss: 0.3230
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8927 - loss: 0.3434
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8990 - loss: 0.3263
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8816 - loss: 0.3511
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9045 - loss: 0.3291
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8968 - loss: 0.3243
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8998 - loss: 0.3243
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9026 - loss: 0.3234
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9065 - loss: 0.3240
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9227 - loss: 0.2902
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8998 - loss: 0.3312
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9129 - loss: 0.3126
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8876 - loss: 0.3404
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9255 - loss: 0.2791
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9147 - loss: 0.2953
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9180 - loss: 0.3018
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9173 - loss: 0.2910
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - AUC: 0.6761 - loss: 0.5784
# Epoch 2/20
# 13/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8379 - loss: 0.4243 Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8608 - loss: 0.3919
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - AUC: 0.6799 - loss: 0.6032
# 23/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8967 - loss: 0.3267Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8890 - loss: 0.3386
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8538 - loss: 0.3852
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8581 - loss: 0.3600
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - AUC: 0.2510 - loss: 0.8338
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8701 - loss: 0.3660
# 22/55 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.2821 - loss: 0.7717Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8824 - loss: 0.3630
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.2940 - loss: 0.7581
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8743 - loss: 0.3429
# 16/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8840 - loss: 0.3515 Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8866 - loss: 0.3448
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.3507 - loss: 0.6898
# Epoch 7/20
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8961 - loss: 0.3235
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8858 - loss: 0.3489
# 33/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.4470 - loss: 0.6521Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9026 - loss: 0.3145
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4612 - loss: 0.6466
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8853 - loss: 0.3470
# 32/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5206 - loss: 0.6173Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9025 - loss: 0.3169
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5300 - loss: 0.6118
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.9855 - loss: 0.2220Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9032 - loss: 0.3239
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8899 - loss: 0.3351
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5916 - loss: 0.5894
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - AUC: 1.0000 - loss: 0.1405Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8745 - loss: 0.3609
# 45/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6559 - loss: 0.5562Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8903 - loss: 0.3323
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6616 - loss: 0.5541
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8927 - loss: 0.3367
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8929 - loss: 0.3400
# Epoch 12/20
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7168 - loss: 0.5227
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9087 - loss: 0.3197
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8805 - loss: 0.3419
# Epoch 13/20
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7862 - loss: 0.4920
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8959 - loss: 0.3290
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8877 - loss: 0.3413
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8314 - loss: 0.4684
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8897 - loss: 0.3409
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9053 - loss: 0.3160
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8262 - loss: 0.4461
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9104 - loss: 0.3036
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8862 - loss: 0.3340
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8073 - loss: 0.4505
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8977 - loss: 0.3284
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8107 - loss: 0.4227
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9019 - loss: 0.3300
# Epoch 16/20
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8965 - loss: 0.3163
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8411 - loss: 0.4179
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9120 - loss: 0.3030
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8929 - loss: 0.3277
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8306 - loss: 0.4143
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9043 - loss: 0.3185
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8959 - loss: 0.3249
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8673 - loss: 0.3823
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9042 - loss: 0.3204
# Epoch 17/20
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8794 - loss: 0.3512
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8975 - loss: 0.3280
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8536 - loss: 0.3843
# Epoch 20/20
# Epoch 18/20
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - AUC: 0.8203 - loss: 0.4335Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8976 - loss: 0.3322
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - AUC: 0.5570 - loss: 0.7177
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8506 - loss: 0.3938
# Epoch 2/20
# Epoch 19/20
# 20/55 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.8674 - loss: 0.3739Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.8689 - loss: 0.3713
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.6424 - loss: 0.6443
# Epoch 3/20
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.7038 - loss: 0.5902
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.8567 - loss: 0.3738
# 35/55 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.7612 - loss: 0.5551Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.7613 - loss: 0.5502
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7761 - loss: 0.5155
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8174 - loss: 0.4768
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8152 - loss: 0.4582
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8315 - loss: 0.4513
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8587 - loss: 0.4045
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8679 - loss: 0.3978
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8598 - loss: 0.3984
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8473 - loss: 0.3938
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8653 - loss: 0.3816
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8830 - loss: 0.3466
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8900 - loss: 0.3505
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8873 - loss: 0.3491
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8570 - loss: 0.3734
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8848 - loss: 0.3583
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8632 - loss: 0.3727
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8742 - loss: 0.3615
# 12/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7066 - loss: 0.7323 Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - AUC: 0.4756 - loss: 0.6140
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.6129 - loss: 0.5613
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - AUC: 0.6460 - loss: 0.7240
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.6430 - loss: 0.5434Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.6790 - loss: 0.5321
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.6751 - loss: 0.6572
# 16/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.7552 - loss: 0.4980Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - AUC: 0.7225 - loss: 0.7118
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7614 - loss: 0.4937
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7306 - loss: 0.5938
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6961 - loss: 0.6562
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8040 - loss: 0.4635
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7844 - loss: 0.5505
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7033 - loss: 0.6085
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8475 - loss: 0.4326
# 33/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7923 - loss: 0.5202Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7946 - loss: 0.5195
# 15/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8113 - loss: 0.4445 Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7627 - loss: 0.5572
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8360 - loss: 0.4316
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8158 - loss: 0.4959
# 18/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7807 - loss: 0.5399 Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7795 - loss: 0.5356
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8422 - loss: 0.4223
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8170 - loss: 0.4660
# 16/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8227 - loss: 0.4939 Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8158 - loss: 0.4931
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8530 - loss: 0.4116
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8520 - loss: 0.4469
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8566 - loss: 0.4125
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8648 - loss: 0.4198Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8078 - loss: 0.4797
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8602 - loss: 0.4222
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.8646 - loss: 0.4239Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8862 - loss: 0.3707
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8418 - loss: 0.4458
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8551 - loss: 0.4199
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8592 - loss: 0.4036
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8532 - loss: 0.4297
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8410 - loss: 0.4186
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8711 - loss: 0.3704
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8312 - loss: 0.4281
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - AUC: 0.9864 - loss: 0.2750Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8468 - loss: 0.4085
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - AUC: 0.6926 - loss: 0.6064Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8916 - loss: 0.3502
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8354 - loss: 0.4159
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8769 - loss: 0.3870
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9041 - loss: 0.3416
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8581 - loss: 0.3957
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8771 - loss: 0.3762
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - AUC: 0.9818 - loss: 0.3660Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8723 - loss: 0.3715
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8528 - loss: 0.3999
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8640 - loss: 0.3725
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8612 - loss: 0.3750
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8961 - loss: 0.3457
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - AUC: 0.8934 - loss: 0.3443
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8553 - loss: 0.3832
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8832 - loss: 0.3644
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8854 - loss: 0.3477
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8566 - loss: 0.3831
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8722 - loss: 0.3624
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8973 - loss: 0.3480
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8856 - loss: 0.3421
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8641 - loss: 0.3667
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8936 - loss: 0.3437
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8704 - loss: 0.3702
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - AUC: 0.6292 - loss: 0.6516
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8928 - loss: 0.3413
# 22/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.6454 - loss: 0.6244Epoch 1/20
# 29/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.6492 - loss: 0.6225Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.8511 - loss: 0.3687
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.6687 - loss: 0.6142
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - AUC: 0.9807 - loss: 0.2167Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.7518 - loss: 0.5683
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.8771 - loss: 0.3504
# 23/55 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8238 - loss: 0.5353Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - AUC: 0.8093 - loss: 0.5306
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8178 - loss: 0.4997
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8291 - loss: 0.4751
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - AUC: 0.8465 - loss: 0.4553
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8395 - loss: 0.4309
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8497 - loss: 0.4381
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8623 - loss: 0.4136
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8682 - loss: 0.3978
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8571 - loss: 0.3960
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8794 - loss: 0.3752
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8732 - loss: 0.3742
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8771 - loss: 0.3621
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8586 - loss: 0.3861
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8708 - loss: 0.3667
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8833 - loss: 0.3638
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8750 - loss: 0.3686
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8667 - loss: 0.3763
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - AUC: 0.5203 - loss: 0.6817
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.5895 - loss: 0.6119
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.7114 - loss: 0.5547
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - AUC: 0.4304 - loss: 0.6060
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - AUC: 0.4226 - loss: 0.6868
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7517 - loss: 0.5275Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.7519 - loss: 0.5273
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.5540 - loss: 0.5731
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5429 - loss: 0.6415
# 53/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7848 - loss: 0.4829Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7853 - loss: 0.4828
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6740 - loss: 0.5409
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.9195 - loss: 0.3695Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6673 - loss: 0.5900
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8346 - loss: 0.4486
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7682 - loss: 0.4946
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8280 - loss: 0.4504
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6855 - loss: 0.5731
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7891 - loss: 0.4771Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7925 - loss: 0.4765
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - AUC: 0.8043 - loss: 0.4304Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8437 - loss: 0.4136
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7512 - loss: 0.5406
# Epoch 9/20
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8409 - loss: 0.4564
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8513 - loss: 0.4039
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8041 - loss: 0.5016
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8353 - loss: 0.4468
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8921 - loss: 0.3701
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8315 - loss: 0.4689
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8493 - loss: 0.4151
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8647 - loss: 0.3818
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8795 - loss: 0.4176Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8196 - loss: 0.4618
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8787 - loss: 0.4147
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - AUC: 0.8727 - loss: 0.4615Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8839 - loss: 0.3542
# 44/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8733 - loss: 0.4000Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8393 - loss: 0.4353
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8745 - loss: 0.3967
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8304 - loss: 0.4286
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8657 - loss: 0.3618
# Epoch 11/20
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8801 - loss: 0.3743
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8552 - loss: 0.4038
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8767 - loss: 0.3699
# Epoch 12/20
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8719 - loss: 0.3764
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8393 - loss: 0.4017
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8927 - loss: 0.3514Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8742 - loss: 0.3565
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8925 - loss: 0.3516
# Epoch 16/20
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8689 - loss: 0.3718
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8826 - loss: 0.3522
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8831 - loss: 0.3617
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8867 - loss: 0.3488
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8677 - loss: 0.3595
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8455 - loss: 0.3943
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8841 - loss: 0.3634
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8712 - loss: 0.3681
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8939 - loss: 0.3391
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8772 - loss: 0.3534
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8555 - loss: 0.3918
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8824 - loss: 0.3497
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9050 - loss: 0.3187
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8526 - loss: 0.3827Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8546 - loss: 0.3806
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8785 - loss: 0.3582
# 43/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8803 - loss: 0.3403Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8869 - loss: 0.3414
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8766 - loss: 0.3458
#  5/55 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.8528 - loss: 0.4275Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - AUC: 0.4130 - loss: 0.7585
# 24/55 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8618 - loss: 0.3842Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - AUC: 0.8739 - loss: 0.3627
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8839 - loss: 0.3571
# Epoch 20/20
#  5/55 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - AUC: 0.8401 - loss: 0.3782Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.8671 - loss: 0.3722
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - AUC: 0.5323 - loss: 0.6675
# Epoch 3/20
#  7/55 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - AUC: 0.5921 - loss: 0.6283Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - AUC: 0.6179 - loss: 0.6047
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - AUC: 0.7199 - loss: 0.5494
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.7939 - loss: 0.5071
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8306 - loss: 0.4746
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8431 - loss: 0.4469
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8621 - loss: 0.4263
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8619 - loss: 0.4073
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8587 - loss: 0.4060
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8656 - loss: 0.3958
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8725 - loss: 0.3673
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8794 - loss: 0.3659
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8707 - loss: 0.3788
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8811 - loss: 0.3655
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8757 - loss: 0.3626
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8732 - loss: 0.3514
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8906 - loss: 0.3413
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8945 - loss: 0.3291
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8755 - loss: 0.3556
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - AUC: 0.6516 - loss: 0.6315
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - AUC: 0.6476 - loss: 0.5685
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8568 - loss: 0.3943
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - AUC: 0.6731 - loss: 0.6159
# 17/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8752 - loss: 0.3772Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8889 - loss: 0.3584
#  8/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8263 - loss: 0.4411 Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8768 - loss: 0.3654
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8393 - loss: 0.4151
# 39/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8744 - loss: 0.3572 Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8738 - loss: 0.3600
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8639 - loss: 0.3620
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8829 - loss: 0.3613
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8926 - loss: 0.3428
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8720 - loss: 0.3544
# 50/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8953 - loss: 0.3384Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8949 - loss: 0.3386
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8828 - loss: 0.3657
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8841 - loss: 0.3381
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8799 - loss: 0.3432
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8935 - loss: 0.3496
# 18/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8804 - loss: 0.3608 Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8824 - loss: 0.3556
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8842 - loss: 0.3516
# 31/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9051 - loss: 0.3252Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9028 - loss: 0.3260
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8743 - loss: 0.3623
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8902 - loss: 0.3536
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9059 - loss: 0.3199
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8817 - loss: 0.3470
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8879 - loss: 0.3388
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8825 - loss: 0.3479
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8816 - loss: 0.3535
# 31/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8873 - loss: 0.3559Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8624 - loss: 0.3697
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8896 - loss: 0.3492
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8874 - loss: 0.3319
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8642 - loss: 0.3717
# Epoch 11/20
# 31/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8938 - loss: 0.3465Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8955 - loss: 0.3396
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8973 - loss: 0.3344
# 32/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9003 - loss: 0.3214Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8933 - loss: 0.3364
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9024 - loss: 0.3204
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8856 - loss: 0.3345
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8798 - loss: 0.3460
# 13/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9307 - loss: 0.2856 Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8942 - loss: 0.3316
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9046 - loss: 0.3215
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8830 - loss: 0.3538
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8987 - loss: 0.3309
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9057 - loss: 0.3263
# 29/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9007 - loss: 0.3387Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8794 - loss: 0.3591
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9036 - loss: 0.3284
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9014 - loss: 0.3300
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8848 - loss: 0.3506
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9005 - loss: 0.3411
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8912 - loss: 0.3365
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8743 - loss: 0.3556
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9080 - loss: 0.3199
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9024 - loss: 0.3104
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8839 - loss: 0.3553
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9227 - loss: 0.2905
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9137 - loss: 0.3072
# 32/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9174 - loss: 0.2861Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8783 - loss: 0.3561
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9097 - loss: 0.3015
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9027 - loss: 0.3162
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8536 - loss: 0.3679
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9059 - loss: 0.3177
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - AUC: 0.6441 - loss: 0.5814
# Epoch 1/20
# 37/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.9074 - loss: 0.3174Epoch 2/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - AUC: 0.9030 - loss: 0.3237
# 42/55 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.8563 - loss: 0.4003Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - AUC: 0.8574 - loss: 0.3957
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - AUC: 0.8837 - loss: 0.3526
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8714 - loss: 0.3613
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8606 - loss: 0.3842
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8703 - loss: 0.3707
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8757 - loss: 0.3490
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8839 - loss: 0.3504
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8879 - loss: 0.3451
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8868 - loss: 0.3569
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8785 - loss: 0.3469
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8883 - loss: 0.3470
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8884 - loss: 0.3422
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9122 - loss: 0.3138
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8855 - loss: 0.3487
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8672 - loss: 0.3795
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8949 - loss: 0.3343
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8786 - loss: 0.3460
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8881 - loss: 0.3344
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8922 - loss: 0.3291
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - AUC: 0.5535 - loss: 0.7245
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - AUC: 0.6229 - loss: 0.6244
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - AUC: 0.6727 - loss: 0.5449
# 27/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8022 - loss: 0.4527Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8139 - loss: 0.4434
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8576 - loss: 0.3939
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8773 - loss: 0.3622
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8752 - loss: 0.3648
# Epoch 4/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8865 - loss: 0.3486
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8893 - loss: 0.3512
# Epoch 5/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8817 - loss: 0.3483
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8900 - loss: 0.3380
# Epoch 6/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8732 - loss: 0.3685
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9053 - loss: 0.3232
# Epoch 7/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8786 - loss: 0.3532
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8963 - loss: 0.3337
# Epoch 8/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8907 - loss: 0.3350
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9077 - loss: 0.3244
# Epoch 9/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8798 - loss: 0.3475
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8980 - loss: 0.3167
# Epoch 10/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8800 - loss: 0.3521
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8923 - loss: 0.3356
# Epoch 11/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8938 - loss: 0.3252
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9135 - loss: 0.3084
# Epoch 12/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8877 - loss: 0.3501
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9052 - loss: 0.3181
# Epoch 13/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8944 - loss: 0.3355
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9019 - loss: 0.3255
# Epoch 14/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8920 - loss: 0.3346
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9119 - loss: 0.3124
# Epoch 15/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8836 - loss: 0.3454
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8951 - loss: 0.3344
# Epoch 16/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8888 - loss: 0.3282
# 22/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8978 - loss: 0.3370 Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9007 - loss: 0.3292
# Epoch 17/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8880 - loss: 0.3411
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9122 - loss: 0.3119
# Epoch 18/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8909 - loss: 0.3355
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9088 - loss: 0.3060
# Epoch 19/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8836 - loss: 0.3626
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9147 - loss: 0.3040
# Epoch 20/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8854 - loss: 0.3455
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.9013 - loss: 0.3184
# Epoch 1/20
# Epoch 1/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - AUC: 0.7093 - loss: 0.6287
# Epoch 2/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.8348 - loss: 0.4282
# 21/55 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.8396 - loss: 0.4263Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - AUC: 0.8366 - loss: 0.4233
# Epoch 3/20
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - AUC: 0.8654 - loss: 0.3796
# Epoch 4/20
# ...
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8326 - loss: 0.4018
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8567 - loss: 0.3939
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8575 - loss: 0.3973
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8791 - loss: 0.3736
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8552 - loss: 0.3979
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8329 - loss: 0.4149
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8691 - loss: 0.3797
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8580 - loss: 0.3970
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8569 - loss: 0.3885
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8361 - loss: 0.4049
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8581 - loss: 0.3867
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8244 - loss: 0.4067
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8828 - loss: 0.3631
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8688 - loss: 0.3759
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8783 - loss: 0.3597
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8438 - loss: 0.3978
# 14/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8935 - loss: 0.3547 Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8860 - loss: 0.3576
#  1/28 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - AUC: 0.9844 - loss: 0.2181Epoch 1/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8633 - loss: 0.3772
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - AUC: 0.3500 - loss: 0.7690
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8770 - loss: 0.3610
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.3384 - loss: 0.7433
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - AUC: 0.4443 - loss: 0.7316
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.3504 - loss: 0.7190
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.5116 - loss: 0.6944
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.3895 - loss: 0.6891
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.5170 - loss: 0.6645
#  8/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.4302 - loss: 0.6711 Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.4238 - loss: 0.6715
# 18/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.5409 - loss: 0.6501Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - AUC: 0.5518 - loss: 0.6462
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5028 - loss: 0.6441
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6393 - loss: 0.6093
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5096 - loss: 0.6289
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6538 - loss: 0.5956
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5627 - loss: 0.6050
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6777 - loss: 0.5879
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6179 - loss: 0.5925
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6974 - loss: 0.5601
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6351 - loss: 0.5754
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7127 - loss: 0.5472
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6903 - loss: 0.5545
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7511 - loss: 0.5364
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7396 - loss: 0.5366
# 23/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7824 - loss: 0.5188 Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7819 - loss: 0.5175
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7396 - loss: 0.5231
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7793 - loss: 0.4983
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7462 - loss: 0.5165
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8150 - loss: 0.4850
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7565 - loss: 0.5091
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8059 - loss: 0.4888
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7739 - loss: 0.4961
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8064 - loss: 0.4685
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8081 - loss: 0.4722
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8100 - loss: 0.4657
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8270 - loss: 0.4602
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8250 - loss: 0.4533
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8340 - loss: 0.4500
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8443 - loss: 0.4342
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8596 - loss: 0.4237
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8192 - loss: 0.4434
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8267 - loss: 0.4378
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8274 - loss: 0.4352
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8324 - loss: 0.4331
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8576 - loss: 0.4147
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8556 - loss: 0.4067
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8406 - loss: 0.4260
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8438 - loss: 0.4003
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8548 - loss: 0.4111
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8661 - loss: 0.3823
# 22/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8678 - loss: 0.4032 Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8663 - loss: 0.4027
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8506 - loss: 0.4032
# 22/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8641 - loss: 0.3973 Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8606 - loss: 0.3994
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8650 - loss: 0.3810
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8627 - loss: 0.4014
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8620 - loss: 0.3978
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8635 - loss: 0.3876
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8621 - loss: 0.3894
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8604 - loss: 0.3834
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8508 - loss: 0.3993
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8554 - loss: 0.3981
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8480 - loss: 0.4063
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - AUC: 0.5477 - loss: 0.7078
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5286 - loss: 0.6795
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5728 - loss: 0.6391
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.5802 - loss: 0.6253
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.6602 - loss: 0.5823
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.6532 - loss: 0.5698
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.6976 - loss: 0.5485
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7491 - loss: 0.5161
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.7902 - loss: 0.4974
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.7868 - loss: 0.4838
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8038 - loss: 0.4703
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8029 - loss: 0.4653
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8174 - loss: 0.4502
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8214 - loss: 0.4433
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8379 - loss: 0.4260
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8388 - loss: 0.4138
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8515 - loss: 0.4120
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8504 - loss: 0.4022
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8320 - loss: 0.4122
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8655 - loss: 0.3984
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8675 - loss: 0.3997
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8520 - loss: 0.3897
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8732 - loss: 0.3746
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8690 - loss: 0.3706
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8699 - loss: 0.3770
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8763 - loss: 0.3590
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8511 - loss: 0.3915
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8665 - loss: 0.3818
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8546 - loss: 0.3804
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8613 - loss: 0.3787
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - AUC: 0.7409 - loss: 0.5663
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8749 - loss: 0.3670
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8641 - loss: 0.3811
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8695 - loss: 0.3750
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8761 - loss: 0.3579
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8835 - loss: 0.3489
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8910 - loss: 0.3403
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8873 - loss: 0.3352
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8804 - loss: 0.3435
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8901 - loss: 0.3332
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8848 - loss: 0.3408
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8894 - loss: 0.3303
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8958 - loss: 0.3343
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8904 - loss: 0.3218
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8978 - loss: 0.3321
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8990 - loss: 0.3247
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9000 - loss: 0.3257
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8917 - loss: 0.3401
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8967 - loss: 0.3332
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8946 - loss: 0.3292
# Best CV ROC AUC for standard: nan
# Best parameters: {'dnn__model__optimizer': 'adam', 'dnn__model__learning_rate': 0.001, 'dnn__model__dropout_rate': 0.2, 'dnn__epochs': 20, 'dnn__batch_size': 32}
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - AUC: 0.6833 - loss: 0.5474
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8678 - loss: 0.3744
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8839 - loss: 0.3429
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8808 - loss: 0.3401
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8928 - loss: 0.3402
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8663 - loss: 0.3644
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8881 - loss: 0.3366
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8830 - loss: 0.3400
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8957 - loss: 0.3315
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8829 - loss: 0.3373
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8956 - loss: 0.3259
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.8994 - loss: 0.3188
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8934 - loss: 0.3365
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9120 - loss: 0.2992
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9020 - loss: 0.3256
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9023 - loss: 0.3235
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9054 - loss: 0.3166
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8941 - loss: 0.3297
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.8793 - loss: 0.3481
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9066 - loss: 0.3149
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-37dbae0de4ec> in <cell line: 10>()
#      44
#      45     # Generate test predictions (the imputer and scaler steps will automatically transform X_test)
# ---> 46     test_preds = best_estimator.predict_proba(X_test)[:, 1]
#      47
#      48     # Save the submission file for this preprocessing method
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in predict_proba(self, X, **params)
#     896         """
#     897         # TODO(1.8): Remove the context manager and use check_is_fitted(self)
# --> 898         with _raise_or_warn_if_not_fitted(self):
#     899             Xt = X
#     900
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     140         if typ is None:
#     141             try:
# --> 142                 next(self.gen)
#     143             except StopIteration:
#     144                 return False
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in _raise_or_warn_if_not_fitted(estimator)
#      58     # we only get here if the above didn't raise
#      59     try:
# ---> 60         check_is_fitted(estimator)
#      61     except NotFittedError:
#      62         warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1754         return
#    1755
# -> 1756     if not _is_fitted(estimator, attributes, all_or_any):
#    1757         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1758
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _is_fitted(estimator, attributes, all_or_any)
#    1663
#    1664     if hasattr(estimator, "__sklearn_is_fitted__"):
# -> 1665         return estimator.__sklearn_is_fitted__()
#    1666
#    1667     fitted_attrs = [
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in __sklearn_is_fitted__(self)
#    1319             # means the previous steps should also be fit. This is faster than
#    1320             # checking if every step of the pipeline is fit.
# -> 1321             check_is_fitted(last_step)
#    1322             return True
#    1323         except NotFittedError:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1749         raise TypeError("%s is not an estimator instance." % (estimator))
#    1750
# -> 1751     tags = get_tags(estimator)
#    1752
#    1753     if not tags.requires_fit and attributes is None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py in get_tags(estimator)
#     428         for klass in reversed(type(estimator).mro()):
#     429             if "__sklearn_tags__" in vars(klass):
# --> 430                 sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431                 class_order.append(klass)
#     432             elif "_more_tags" in vars(klass):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in __sklearn_tags__(self)
#     538
#     539     def __sklearn_tags__(self):
# --> 540         tags = super().__sklearn_tags__()
#     541         tags.estimator_type = "classifier"
#     542         tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'

# %% [markdown]
# ## Compare Results
#
# We create a DataFrame from the results and sort by the best AUC score to see which preprocessing pipeline + hyperparameters performed bes.

# %%
# Compare results across pipelines
results_df = pd.DataFrame(results).sort_values(by='best_auc', ascending=False)
print("\nComparison of Preprocessing Approaches:")
display(results_df)

# %% [markdown]
# ## Copy Best Scoring Submission as submission.csv
#
# From the tuning results, we identify the best scoring submission and copy that file to "submission.csv" (the name required by the competition). All other submission file names remain unchanged..

# %%
# Copy the best scoring submission to "submission.csv"
import shutil

# Filter out any candidates with NaN scores and pick the best candidate
results_df = results_df[results_df['best_auc'].notna()]
if len(results_df) == 0:
    raise ValueError("No valid submission was found with a non-NaN ROC AUC score.")

best_result = results_df.iloc[0]
best_submission_file = best_result['submission_file']

# Copy the best submission file to "submission.csv"
shutil.copy(best_submission_file, 'submission.csv')
print(f"Best scoring submission ({best_submission_file}) copied as 'submission.csv'")

# %% [markdown]
# ## Retrain Final Models and Generate Final Submissions
#
# Optionally, you can retrain final models using the best hyperparameters from each pipeline on the entire training data and generate final submissions. This cell demonstrates that step.

# %%
# Retrain final models with best parameters and generate final submissions
for idx, row in results_df.iterrows():
    prep = row['preprocessing']
    best_params = row['best_params']
    print(f"Retraining final model with preprocessing: {prep}")
    
    steps = []
    steps.append(('imputer', SimpleImputer(strategy="median")))
    if prep in preprocessors and preprocessors[prep] is not None:
        steps.append((prep, preprocessors[prep]))
    steps.append(('dnn', dnn_wrapper.set_params(**best_params)))
    final_pipeline = Pipeline(steps)
    
    final_pipeline.fit(X, y)
    final_preds = final_pipeline.predict_proba(X_test)[:, 1]
    
    final_sub_filename = f"submissions/final_{prep}_dnn_submission.csv"
    final_sub_df = pd.DataFrame({'id': test_ids, 'rainfall': final_preds})
    final_sub_df.to_csv(final_sub_filename, index=False)
    print(f"Final submission saved: {final_sub_filename}\n")

# %% [markdown]
# ## Conclusion
#
# - **Memory Optimization**: We downcast numeric columns to reduce memory usage.
# - **Missing Value Handling**: A SimpleImputer (median strategy) is included to ensure no NaN values persist.
# - **Preprocessing Pipelines**: We compared Standard, MinMax, Robust, and Raw (no scaling) in a pipeline with our DNN.
# - **GPU Acceleration**: The DNN is configured to run on GPU (if available) for competitive training speeds.
# - **Thorough Hyperparameter Tuning**: Using RandomizedSearchCV (50 iterations over 5-fold CV) we tuned optimizer, dropout rate, learning rate, epochs, and batch size.
# - **Submissions**: A submission file is generated for each preprocessing pipeline and saved in the "submissions" folder. The best scoring submission is explicitly copied to **submission.csv** as required.
#
# This code is designed for a competitive setting—adjust hyperparameter ranges, iterations, and preprocessing options as needed for further improvements. Happy modeling and best of luck in the competition!loration.
