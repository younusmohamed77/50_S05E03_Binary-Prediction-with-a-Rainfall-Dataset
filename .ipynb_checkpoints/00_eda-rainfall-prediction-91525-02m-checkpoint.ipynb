# %% [markdown]
# <div class="alert alert-success">
#         <h1 align="center" style="color:chocolate;">Binary Prediction with a Rainfall Dataset
#
#
# </h1>
#
# </div>

# %% [markdown]
# <p><center style="color:blue; font-family: 'Dancing Script'; font-size:30px;">🙏🏿Thanks for visiting my notebook 🕺🏿</center></p>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: white; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DAA520'>💡 About The Competition :</font></h3>
#
# **Task**: The goal for this competition is to find Binary Prediction with a Rainfall Dataset.
#
# **Evaluation**: Submissions are evaluated using the Area under ROC Cruve.

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: lightgrey; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='black'>💡 Evalaution Metric :</font></h3>
#
#
#
# ![kxfbR.png](attachment:29071361-f52f-448c-aaa8-9905a6d7a8c0.png)

# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center" style="color:darkgoldenrod;">Importing Libraries</h1>
#
# </div>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: white; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DAA520'>💡 About The Packages :</font></h3>
#
# 🎭we are Importing several Python packages
#
#
# 🥽 XGBoost (eXtreme Gradient Boosting) and LightGBM are both powerful machine learning algorithms used for supervised learning tasks, particularly in the realm of gradient boosting
#
#
# 🎍Numpy, Pandas, Matplotlib, Seaborn :NumPy for numerical computing, Pandas for data manipulation, Matplotlib for plotting, and Seaborn for statistical visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_hist_gradient_boosting  
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import median_absolute_error
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from matplotlib.patches import ConnectionPatch

from sklearn.metrics import roc_auc_score,f1_score,accuracy_score
from sklearn.model_selection import KFold
from xgboost import XGBClassifier
from catboost import Pool, CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier, GradientBoostingClassifier, RandomForestClassifier,VotingClassifier
from sklearn.preprocessing import LabelEncoder,StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout, MaxPooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
df_train = pd.read_csv('/kaggle/input/playground-series-s5e3/train.csv')
df_test  = pd.read_csv('/kaggle/input/playground-series-s5e3/test.csv')
df_sub = pd.read_csv('/kaggle/input/playground-series-s5e3/sample_submission.csv')

# %%
df_train.columns
# Out:
# Index(['id', 'day', 'pressure', 'maxtemp', 'temparature', 'mintemp',
#        'dewpoint', 'humidity', 'cloud', 'sunshine', 'winddirection',
#        'windspeed', 'rainfall'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (2190, 13)

# %%
df_train.head()
# Out:
#    id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 0   0    1    1017.4     21.2         20.6     19.9      19.4      87.0
# 1   1    2    1019.5     16.2         16.9     15.8      15.4      95.0
# 2   2    3    1024.1     19.4         16.1     14.6       9.3      75.0
# 3   3    4    1013.4     18.1         17.8     16.9      16.8      95.0
# 4   4    5    1021.8     21.3         18.4     15.2       9.6      52.0
#
#    cloud  sunshine  winddirection  windspeed  rainfall
# 0   88.0       1.1           60.0       17.2         1
# 1   91.0       0.0           50.0       21.9         1
# 2   47.0       8.3           70.0       18.1         1
# 3   95.0       0.0           60.0       35.6         1
# 4   45.0       3.6           40.0       24.8         0

# %%
df_train.describe()
# Out:
#                 id          day     pressure      maxtemp  temparature  \
# count  2190.000000  2190.000000  2190.000000  2190.000000  2190.000000
# mean   1094.500000   179.948402  1013.602146    26.365799    23.953059
# std     632.342866   105.203592     5.655366     5.654330     5.222410
# min       0.000000     1.000000   999.000000    10.400000     7.400000
# 25%     547.250000    89.000000  1008.600000    21.300000    19.300000
# 50%    1094.500000   178.500000  1013.000000    27.800000    25.500000
# 75%    1641.750000   270.000000  1017.775000    31.200000    28.400000
# max    2189.000000   365.000000  1034.600000    36.000000    31.500000
#
#            mintemp     dewpoint     humidity        cloud     sunshine  \
# count  2190.000000  2190.000000  2190.000000  2190.000000  2190.000000
# mean     22.170091    20.454566    82.036530    75.721918     3.744429
# std       5.059120     5.288406     7.800654    18.026498     3.626327
# min       4.000000    -0.300000    39.000000     2.000000     0.000000
# 25%      17.700000    16.800000    77.000000    69.000000     0.400000
# 50%      23.850000    22.150000    82.000000    83.000000     2.400000
# 75%      26.400000    25.000000    88.000000    88.000000     6.800000
# max      29.800000    26.700000    98.000000   100.000000    12.100000
#
#        winddirection    windspeed     rainfall
# count    2190.000000  2190.000000  2190.000000
# mean      104.863151    21.804703     0.753425
# std        80.002416     9.898659     0.431116
# min        10.000000     4.400000     0.000000
# 25%        40.000000    14.125000     1.000000
# 50%        70.000000    20.500000     1.000000
# 75%       200.000000    27.900000     1.000000
# max       300.000000    59.500000     1.000000

# %%
df_test.head()
# Out:
#      id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 0  2190    1    1019.5     17.5         15.8     12.7      14.9      96.0
# 1  2191    2    1016.5     17.5         16.5     15.8      15.1      97.0
# 2  2192    3    1023.9     11.2         10.4      9.4       8.9      86.0
# 3  2193    4    1022.9     20.6         17.3     15.2       9.5      75.0
# 4  2194    5    1022.2     16.1         13.8      6.4       4.3      68.0
#
#    cloud  sunshine  winddirection  windspeed
# 0   99.0       0.0           50.0       24.3
# 1   99.0       0.0           50.0       35.3
# 2   96.0       0.0           40.0       16.9
# 3   45.0       7.1           20.0       50.6
# 4   49.0       9.2           20.0       19.4

# %%
df_sub.head()
# Out:
#      id  rainfall
# 0  2190         0
# 1  2191         0
# 2  2192         0
# 3  2193         0
# 4  2194         0

# %%
df_train = df_train.drop(columns=['id'])
df_test = df_test.drop(columns=['id'])

# %%
df_train.shape,df_test.shape
# Out:
# ((2190, 12), (730, 11))

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            2190 non-null   int64
#  1   pressure       2190 non-null   float64
#  2   maxtemp        2190 non-null   float64
#  3   temparature    2190 non-null   float64
#  4   mintemp        2190 non-null   float64
#  5   dewpoint       2190 non-null   float64
#  6   humidity       2190 non-null   float64
#  7   cloud          2190 non-null   float64
#  8   sunshine       2190 non-null   float64
#  9   winddirection  2190 non-null   float64
#  10  windspeed      2190 non-null   float64
#  11  rainfall       2190 non-null   int64
# dtypes: float64(10), int64(2)
# memory usage: 205.4 KB

# %%
df_train.isnull().sum()
# Out:
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# sunshine         0
# winddirection    0
# windspeed        0
# rainfall         0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# sunshine         0
# winddirection    1
# windspeed        0
# dtype: int64

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: lightgreen; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='green'>💡 Summary from above :</font></h3>
#
# 1. Time Period: Data spans 2190 days (~6 years).
# 1. Pressure: Ranges from 999 to 1034.6 hPa, with an average of 1013.6 hPa..
# 1. Temperature Metrics:Max: 10.4°C to 36°C (Avg: 26.37°C),Min: 4°C to 29.8°C (Avg: 22.17°C),Mean Temp: 7.4°C to 31.5°C (Avg: 23.95°C)
# 1. Dew Point: Varies from -0.3°C to 26.7°C (Avg: 20.45°C).Humidity: High overall, ranging from 39% to 98% (Avg: 82%).
# 1. Cloud Cover: 2% to 100% (Avg: 75.7%).Sunshine Hours: 0 to 12.1 hours per day (Avg: 3.74 hours).
# 1. Wind Direction: Highly variable, from 10° to 300° (Avg: 104.86°).Wind Speed: 4.4 km/h to 59.5 km/h (Avg: 21.8 km/h).
# 1. Rainfall: Mostly binary (0 or 1), indicating dry or rainy days (Avg: 0.75).There are no null and categorical datatype in dataset

# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center" style="color:darkgoldenrod;">⚠🍜Exploratory Data Analysis♒🌊</h1>
#
# </div>

# %%
def stacked_bar_plot(df, feature, target='rainfall'):
    crosstab = pd.crosstab(df[feature], df[target], normalize='index')
    crosstab.plot(kind='bar', stacked=True, figsize=(12, 6), cmap='coolwarm')
    plt.title(f'Stacked Bar Plot of {feature} vs {target}')
    plt.ylabel('Proportion')
    plt.show()
stacked_bar_plot(df_train, 'winddirection')

# %%
df_train.hist(figsize=(12, 10), color='skyblue', edgecolor='black')
plt.gcf().set_facecolor('yellow')
plt.tight_layout()
plt.show()

# %%
df_train.shape,df_test.shape
# Out:
# ((2190, 12), (730, 11))

# %%
fig, axes = plt.subplots(3, 2, figsize=(14, 18))

rain_counts = df_train['rainfall'].value_counts()
axes[0, 0].pie(rain_counts, labels=['No Rain', 'Rain'], autopct='%1.1f%%', colors=['skyblue', 'darkblue'])
axes[0, 0].set_title("Rainfall Distribution")

sns.countplot(x=df_train['rainfall'], ax=axes[0, 1], palette=['skyblue', 'darkblue'])
axes[0, 1].set_xticklabels(['No Rain', 'Rain'])
axes[0, 1].set_title("Rainfall Count")

sns.histplot(df_train['cloud'], bins=20, kde=True, ax=axes[1, 0], color="gray")
axes[1, 0].set_title("Cloud Cover Distribution")

sns.histplot(df_train['sunshine'], bins=20, kde=True, ax=axes[1, 1], color="orange")
axes[1, 1].set_title("Sunshine Distribution")

sns.histplot(df_train['temparature'], bins=20, kde=True, ax=axes[2, 0], color="red")
axes[2, 0].set_title("Temperature Distribution")

sns.kdeplot(df_train['maxtemp'], label="Max Temp", color="red", ax=axes[2, 1])
sns.kdeplot(df_train['mintemp'], label="Min Temp", color="blue", ax=axes[2, 1])
axes[2, 1].legend()
axes[2, 1].set_title("Max vs. Min Temperature")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

sns.histplot(df_train['rainfall'], bins=20, kde=True, ax=axes[0, 0], color="blue")
axes[0, 0].set_title("Rainfall Distribution")

sns.scatterplot(x=df_train['dewpoint'], y=df_train['humidity'], ax=axes[0, 1], color="green")
axes[0, 1].set_title("Humidity vs. Dewpoint")

df_train['cloud_bins'] = pd.cut(df_train['cloud'], bins=[0, 25, 50, 75, 100], labels=["0-25%", "26-50%", "51-75%", "76-100%"])
sns.barplot(x=df_train['cloud_bins'], y=df_train['sunshine'], ax=axes[1, 0], palette="coolwarm")
axes[1, 0].set_title("Sunshine Hours by Cloud Cover")

sns.boxplot(x=df_train['winddirection'], y=df_train['windspeed'], ax=axes[1, 1])
axes[1, 1].set_title("Wind Speed by Wind Direction")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

sns.boxplot(data=df_train[['temparature', 'maxtemp', 'mintemp']], ax=axes[0, 0])
axes[0, 0].set_title("Temperature Variations (Boxplot)")

sns.violinplot(x=df_train['windspeed'], ax=axes[0, 1], color="blue")
axes[0, 1].set_title("Wind Speed Distribution (Violin Plot)")

corr_matrix = df_train[['temparature', 'maxtemp', 'mintemp', 'dewpoint', 'humidity', 'windspeed', 'pressure', 'rainfall']].corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", ax=axes[1, 0])
axes[1, 0].set_title("Feature Correlation Heatmap")

sns.lineplot(x='day', y='temparature', data=df_train, ax=axes[1, 1], label="Avg Temp", color='red')
sns.lineplot(x='day', y='maxtemp', data=df_train, ax=axes[1, 1], label="Max Temp", color='blue')
sns.lineplot(x='day', y='mintemp', data=df_train, ax=axes[1, 1], label="Min Temp", color='green')
axes[1, 1].set_title("Temperature Trends Over Time")
axes[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: white; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DAA520'>💡 Observation from above plot :</font></h3>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: lightgreen; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DAA520'>💡 What We got from data, Lets have a look :</font></h3>
#
# **Correlation Insights**:
# Pressure & Temperature have a strong negative correlation (-0.80 to -0.82) → **Higher pressure is associated with lower temperatures.Max Temp, Avg Temp, Min Temp, and Dew Point are highly correlated (0.90 - 0.99)**
# → Redundant information among these variables.
# **Cloud Cover & Sunshine are strongly negatively correlated (-0.81) → More clouds mean less sunshine**.
# Cloud Cover & Rainfall have a strong positive correlation (0.64) → More clouds generally lead to more rain.
# **Wind Direction & Temperature (0.66 correlation) → Wind patterns significantly influence temperature.**
# **Humidity & Cloud Cover (0.58 correlation)** → Higher humidity is associated with more cloud formation.
# **Sunshine & Rainfall (-0.55 correlation) → More sunshine means less rainfall, which aligns with general weather patterns.**
#
# **Multicollinearity Issues:**
# **Severe multicollinearity exists among temperature-related features (MaxTemp, Temp, MinTemp, DewPoint) → May cause instability in regression models.**
# Pressure’s strong negative correlation with temperature variables (-0.80+) suggests it might be redundant in models including temperature.

# %%
df_train = df_train.drop(columns=['cloud_bins'])

# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center" style="color:darkgoldenrod;">🎇🌭Regression Analysis♒🌊</h1>
#
# </div>

# %%
df_ext = pd.read_csv('/kaggle/input/rainfall-prediction-using-machine-learning/Rainfall.csv')
df_ext = df_ext.rename(columns={'pressure ': 'pressure', 'humidity ': 'humidity', 'cloud ': 'cloud','winddirection':'winddirection'})

# %%
df_train = pd.concat([df_train, df_ext], axis=0, ignore_index=True)

# %%
df_train = df_train[df_train.columns].replace({'yes': 1, 'no': 0})

# %% [markdown]
# Thanks to igor and muhammadqasimshabbir for  wonderfull work some features and catbboost code are brought from there **https://www.kaggle.com/code/igorvolianiuk/rainfall-prediction-eda-catboost-optuna/notebook**
# https://www.kaggle.com/code/muhammadqasimshabbir/6thplacesolution-binarypredictionrainfall-872/notebook

# %%
def create_weather_features(df):    

    df["temp_Range"] = df["maxtemp"] - df["mintemp"]
    df["Heat_Index"] = df["temparature"] + 0.5 * (df["temparature"] - 10) * (df["humidity"] / 100)    
    df['csr'] = df['cloud'] / (df['sunshine'] + 1e-5)
    df["Dew_Dep"] = df["temparature"] - df["dewpoint"]    
    df["Wind_Chill"] = np.where(
        df["temparature"] < 10,
        13.12 + 0.6215 * df["temparature"] - 11.37 * df["windspeed"]**0.16 + 
       0.3965 * df["temparature"] * df["windspeed"]**0.16,
        df["temparature"]
    )   
    df['hsi'] = df['humidity'] * df['sunshine']
    df["Cloud_Sun_Ratio"] = df["cloud"] / (df["sunshine"] + 1)    
    df["Pressure_Change"] = df["pressure"].diff().fillna(0)    
    air_density = 1.225  
    df['wi'] = (0.4 * df['humidity']) + (0.3 * df['cloud']) - (0.3 * df['sunshine'])
    df["Wind_Power"] = 0.5 * air_density * df["windspeed"]**3         
    #df["Wind_Direction_Cat"] = pd.cut(df["winddirection"], 
                                      #bins=[0, 90, 180, 270, 360], 
                                     # labels=["North", "East", "South", "West"], 
                                      #include_lowest=True)

    df['cloud + humidity'] = df.cloud + df.humidity
    df['cloud + humidity + sunshine'] = df.cloud + df.humidity + df.sunshine
    df['sp'] = df['sunshine'] / (df['sunshine'] + df['cloud'] + 1e-5)
    df['cloud * sunshine'] = df.cloud * df.sunshine
    df['humidity * sunshine'] = df.humidity * df.sunshine
    df['rd'] = 100 - df['humidity']
    df["HTI"] = df["temparature"] + 0.2 * df["humidity"]    
    df["ACI"] = (df["maxtemp"] + df["mintemp"]) / 2 - (df["humidity"] / 2) + df["dewpoint"]    
    df["CSI"] = (df["sunshine"] - df["cloud"]) / (df["sunshine"] + df["cloud"] + 1)  
    df['hci'] = df['humidity'] * df['cloud']
    df["WCI"] = df["temparature"] - 0.5 * df["windspeed"]
    df['day'] = pd.to_datetime(df['day'], errors='coerce')    
   
    
    return df

# %%
df_train = create_weather_features(df_train)
df_test = create_weather_features(df_test)

# %%
df_test.fillna(df_test.median(), inplace=True)
df_train.fillna(df_train.median(), inplace=True)
# Out:
# /tmp/ipykernel_20/1101998587.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df_test.fillna(df_test.median(), inplace=True)
# /tmp/ipykernel_20/1101998587.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df_train.fillna(df_train.median(), inplace=True)

# %%
df_train = df_train.drop(columns=['day','         winddirection'])
df_test = df_test.drop(columns=['day'])

# %%
y = df_train['rainfall'] 
df_train = df_train.drop(['rainfall'],axis=1)
X = df_train

# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center" style="color:darkgoldenrod;">🎇🌭Algorithm Which requires Scaling♒🌊</h1>
#
# </div>

# %% [markdown]
# ![inbox_2175703_cc4d46b6bb4a14ae085b9db28ad8b8f4_FeatureScaling_ML.jpg](attachment:f76dbffe-c5cb-4d72-8a9a-184c0dd11dc2.jpg)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_train_data = df_train
scaled_test_data = df_test

# %%
df_train.shape
# Out:
# (2556, 31)

# %%
X.shape
# Out:
# (2556, 31)

# %%
scaled_test_data.shape
# Out:
# (730, 31)

# %%
X.columns
# Out:
# Index(['pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint', 'humidity',
#        'cloud', 'sunshine', 'winddirection', 'windspeed', 'temp_Range',
#        'Heat_Index', 'csr', 'Dew_Dep', 'Wind_Chill', 'hsi', 'Cloud_Sun_Ratio',
#        'Pressure_Change', 'wi', 'Wind_Power', 'cloud + humidity',
#        'cloud + humidity + sunshine', 'sp', 'cloud * sunshine',
#        'humidity * sunshine', 'rd', 'HTI', 'ACI', 'CSI', 'hci', 'WCI'],
#       dtype='object')

# %%
scaled_test_data.columns
# Out:
# Index(['pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint', 'humidity',
#        'cloud', 'sunshine', 'winddirection', 'windspeed', 'temp_Range',
#        'Heat_Index', 'csr', 'Dew_Dep', 'Wind_Chill', 'hsi', 'Cloud_Sun_Ratio',
#        'Pressure_Change', 'wi', 'Wind_Power', 'cloud + humidity',
#        'cloud + humidity + sunshine', 'sp', 'cloud * sunshine',
#        'humidity * sunshine', 'rd', 'HTI', 'ACI', 'CSI', 'hci', 'WCI'],
#       dtype='object')

# %%
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(scaled_test_data)
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42,stratify=y)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))
X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))

# %%
model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Conv1D(filters=32, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid') 
])

# %%
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[AUC(name='auc')])
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-5, verbose=1)

# %%
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/200
# 64/64 [==============================] - 2s 12ms/step - loss: 0.6537 - auc: 0.5006 - val_loss: 0.6096 - val_auc: 0.5072 - lr: 1.0000e-04
# Epoch 2/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.5892 - auc: 0.5430 - val_loss: 0.5489 - val_auc: 0.7207 - lr: 1.0000e-04
# Epoch 3/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.5301 - auc: 0.7157 - val_loss: 0.4766 - val_auc: 0.8484 - lr: 1.0000e-04
# Epoch 4/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4757 - auc: 0.8112 - val_loss: 0.4171 - val_auc: 0.8588 - lr: 1.0000e-04
# Epoch 5/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4310 - auc: 0.8376 - val_loss: 0.3823 - val_auc: 0.8660 - lr: 1.0000e-04
# Epoch 6/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4070 - auc: 0.8478 - val_loss: 0.3671 - val_auc: 0.8757 - lr: 1.0000e-04
# Epoch 7/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3923 - auc: 0.8581 - val_loss: 0.3567 - val_auc: 0.8793 - lr: 1.0000e-04
# Epoch 8/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3792 - auc: 0.8638 - val_loss: 0.3515 - val_auc: 0.8839 - lr: 1.0000e-04
# Epoch 9/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3869 - auc: 0.8596 - val_loss: 0.3479 - val_auc: 0.8855 - lr: 1.0000e-04
# Epoch 10/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3791 - auc: 0.8672 - val_loss: 0.3467 - val_auc: 0.8876 - lr: 1.0000e-04
# Epoch 11/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3713 - auc: 0.8702 - val_loss: 0.3446 - val_auc: 0.8884 - lr: 1.0000e-04
# Epoch 12/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3717 - auc: 0.8751 - val_loss: 0.3430 - val_auc: 0.8905 - lr: 1.0000e-04
# Epoch 13/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3732 - auc: 0.8728 - val_loss: 0.3426 - val_auc: 0.8901 - lr: 1.0000e-04
# Epoch 14/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3729 - auc: 0.8702 - val_loss: 0.3419 - val_auc: 0.8908 - lr: 1.0000e-04
# Epoch 15/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3700 - auc: 0.8717 - val_loss: 0.3412 - val_auc: 0.8911 - lr: 1.0000e-04
# Epoch 16/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3620 - auc: 0.8787 - val_loss: 0.3413 - val_auc: 0.8915 - lr: 1.0000e-04
# Epoch 17/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3685 - auc: 0.8738 - val_loss: 0.3408 - val_auc: 0.8910 - lr: 1.0000e-04
# Epoch 18/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3668 - auc: 0.8733 - val_loss: 0.3389 - val_auc: 0.8924 - lr: 1.0000e-04
# Epoch 19/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3678 - auc: 0.8726 - val_loss: 0.3384 - val_auc: 0.8922 - lr: 1.0000e-04
# Epoch 20/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3689 - auc: 0.8712 - val_loss: 0.3386 - val_auc: 0.8928 - lr: 1.0000e-04
# Epoch 21/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3690 - auc: 0.8737 - val_loss: 0.3390 - val_auc: 0.8925 - lr: 1.0000e-04
# Epoch 22/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3648 - auc: 0.8770 - val_loss: 0.3384 - val_auc: 0.8929 - lr: 1.0000e-04
# Epoch 23/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3634 - auc: 0.8775 - val_loss: 0.3375 - val_auc: 0.8933 - lr: 1.0000e-04
# Epoch 24/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3648 - auc: 0.8752 - val_loss: 0.3363 - val_auc: 0.8935 - lr: 1.0000e-04
# Epoch 25/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3564 - auc: 0.8818 - val_loss: 0.3355 - val_auc: 0.8945 - lr: 1.0000e-04
# Epoch 26/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3561 - auc: 0.8839 - val_loss: 0.3353 - val_auc: 0.8955 - lr: 1.0000e-04
# Epoch 27/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3623 - auc: 0.8768 - val_loss: 0.3349 - val_auc: 0.8942 - lr: 1.0000e-04
# Epoch 28/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3590 - auc: 0.8771 - val_loss: 0.3354 - val_auc: 0.8949 - lr: 1.0000e-04
# Epoch 29/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3588 - auc: 0.8805 - val_loss: 0.3352 - val_auc: 0.8960 - lr: 1.0000e-04
# Epoch 30/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3561 - auc: 0.8835 - val_loss: 0.3348 - val_auc: 0.8947 - lr: 1.0000e-04
# Epoch 31/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3586 - auc: 0.8817 - val_loss: 0.3343 - val_auc: 0.8956 - lr: 1.0000e-04
# Epoch 32/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3549 - auc: 0.8821 - val_loss: 0.3339 - val_auc: 0.8962 - lr: 1.0000e-04
# Epoch 33/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3558 - auc: 0.8822 - val_loss: 0.3331 - val_auc: 0.8965 - lr: 1.0000e-04
# Epoch 34/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3579 - auc: 0.8823 - val_loss: 0.3345 - val_auc: 0.8956 - lr: 1.0000e-04
# Epoch 35/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3565 - auc: 0.8843 - val_loss: 0.3354 - val_auc: 0.8949 - lr: 1.0000e-04
# Epoch 36/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3552 - auc: 0.8826 - val_loss: 0.3358 - val_auc: 0.8944 - lr: 1.0000e-04
# Epoch 37/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3507 - auc: 0.8862 - val_loss: 0.3357 - val_auc: 0.8947 - lr: 1.0000e-04
# Epoch 38/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3574 - auc: 0.8806 - val_loss: 0.3346 - val_auc: 0.8960 - lr: 1.0000e-04
# Epoch 39/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3548 - auc: 0.8854 - val_loss: 0.3342 - val_auc: 0.8956 - lr: 1.0000e-04
# Epoch 40/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3568 - auc: 0.8819 - val_loss: 0.3342 - val_auc: 0.8955 - lr: 1.0000e-04
# Epoch 41/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3490 - auc: 0.8885 - val_loss: 0.3342 - val_auc: 0.8953 - lr: 1.0000e-04
# Epoch 42/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3499 - auc: 0.8853 - val_loss: 0.3349 - val_auc: 0.8957 - lr: 1.0000e-04
# Epoch 43/200
# 57/64 [=========================>....] - ETA: 0s - loss: 0.3576 - auc: 0.8809
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1e-05.
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3549 - auc: 0.8820 - val_loss: 0.3350 - val_auc: 0.8951 - lr: 1.0000e-04
# Epoch 44/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3515 - auc: 0.8857 - val_loss: 0.3349 - val_auc: 0.8952 - lr: 1.0000e-05
# Epoch 45/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3508 - auc: 0.8872 - val_loss: 0.3349 - val_auc: 0.8950 - lr: 1.0000e-05
# Epoch 46/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3587 - auc: 0.8822 - val_loss: 0.3349 - val_auc: 0.8952 - lr: 1.0000e-05
# Epoch 47/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3587 - auc: 0.8800 - val_loss: 0.3351 - val_auc: 0.8950 - lr: 1.0000e-05
# Epoch 48/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3490 - auc: 0.8881 - val_loss: 0.3350 - val_auc: 0.8952 - lr: 1.0000e-05
# Epoch 49/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3598 - auc: 0.8808 - val_loss: 0.3349 - val_auc: 0.8950 - lr: 1.0000e-05
# Epoch 50/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3580 - auc: 0.8800 - val_loss: 0.3350 - val_auc: 0.8950 - lr: 1.0000e-05
# Epoch 51/200
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3532 - auc: 0.8845 - val_loss: 0.3349 - val_auc: 0.8949 - lr: 1.0000e-05
# Epoch 52/200
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3509 - auc: 0.8865 - val_loss: 0.3349 - val_auc: 0.8949 - lr: 1.0000e-05
# Epoch 53/200
# 60/64 [===========================>..] - ETA: 0s - loss: 0.3556 - auc: 0.8847Restoring model weights from the end of the best epoch: 33.
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3521 - auc: 0.8864 - val_loss: 0.3348 - val_auc: 0.8951 - lr: 1.0000e-05
# Epoch 53: early stopping

# %%
sns.set(style="whitegrid")

history_dict = history.history
metrics = list(history_dict.keys())
print("Available metrics:", metrics)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
colors = sns.color_palette("muted")

axes[0].plot(history_dict['loss'], label='Train Loss', color=colors[0], linewidth=2)
axes[0].plot(history_dict['val_loss'], label='Val Loss', color=colors[1], linestyle='--', linewidth=2)
axes[0].set_title('Training and Validation Loss', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epochs', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].legend()
axes[0].grid(True)

if 'auc' in metrics and 'val_auc' in metrics:
    axes[1].plot(history_dict['auc'], label='Train AUC', color=colors[2], linewidth=2)
    axes[1].plot(history_dict['val_auc'], label='Val AUC', color=colors[3], linestyle='--', linewidth=2)
    axes[1].set_title('Training and Validation AUC', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epochs', fontsize=12)
    axes[1].set_ylabel('AUC', fontsize=12)
    axes[1].legend()
    axes[1].grid(True)
    
if 'lr' in metrics:
    fig, ax_lr = plt.subplots(figsize=(8, 4))
    ax_lr.plot(history_dict['lr'], color=colors[4], linewidth=2)
    ax_lr.set_title('Learning Rate over Epochs', fontsize=14, fontweight='bold')
    ax_lr.set_xlabel('Epochs', fontsize=12)
    ax_lr.set_ylabel('Learning Rate', fontsize=12)
    plt.grid(True)
    plt.show()

if 'epoch_time' in metrics:
    fig, ax_time = plt.subplots(figsize=(8, 4))
    ax_time.plot(history_dict['epoch_time'], color=colors[5], linewidth=2)
    ax_time.set_title('Epoch Time over Epochs', fontsize=14, fontweight='bold')
    ax_time.set_xlabel('Epochs', fontsize=12)
    ax_time.set_ylabel('Time (seconds)', fontsize=12)
    plt.grid(True)
    plt.show()

plt.tight_layout()
plt.show()
# Out:
# Available metrics: ['loss', 'auc', 'val_loss', 'val_auc', 'lr']

# %%
lgb_params = {'max_depth': 11, 
              'num_leaves': 152, 
              'learning_rate': 0.1284552398987031,
                'feature_fraction': 0.699205159877181965, 
              'bagging_fraction': 0.964565149953761379, 
                'bagging_freq': 3, 
              'min_child_samples': 93, 
              'lambda_l1': 1.4313376954414664e-09, 
                'lambda_l2': 5.9890062038048195, 
                'min_gain_to_split': 0.5655566115584013}

n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
lgbm_predictions = np.zeros(len(scaled_train_data))
lgbm_true_labels = np.zeros(len(scaled_train_data))
lgbm_test_predictions = np.zeros(len(scaled_test_data))

for fold, (train_idx, val_idx) in enumerate(skf.split(scaled_train_data, y)):
    X_train, X_val = scaled_train_data.iloc[train_idx], scaled_train_data.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]    
   
    lgbm_model = LGBMClassifier(**lgb_params)
    lgbm_model.fit(X_train, y_train,
                   eval_set=[(X_val, y_val)],
                   eval_metric='auc',
                   #early_stopping_rounds=10,
                   #verbose=False
                  )    

    lgbm_fold_preds = lgbm_model.predict_proba(X_val)[:, 1]  
    lgbm_fold_test_preds = lgbm_model.predict_proba(scaled_test_data)[:, 1]   
    lgbm_predictions[val_idx] = lgbm_fold_preds
    lgbm_true_labels[val_idx] = y_val    
    lgbm_test_predictions += lgbm_fold_test_preds / n_splits
overall_metric_lgbm = roc_auc_score(lgbm_true_labels, lgbm_predictions)
print("Overall AUC (LGBMClassifier with StratifiedKFold):", overall_metric_lgbm)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=1.4313376954414664e-09, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.4313376954414664e-09
# [LightGBM] [Warning] bagging_fraction is set=0.9645651499537614, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9645651499537614
# [LightGBM] [Warning] min_gain_to_split is set=0.5655566115584013, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.5655566115584013
# [LightGBM] [Warning] lambda_l2 is set=5.989006203804819, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.989006203804819
# [LightGBM] [Warning] feature_fraction is set=0.699205159877182, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.699205159877182
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [1]	valid_0's auc: 0.848575	valid_0's binary_logloss: 0.523394
# [2]	valid_0's auc: 0.860686	valid_0's binary_logloss: 0.490826
# [3]	valid_0's auc: 0.863387	valid_0's binary_logloss: 0.464206
# [4]	valid_0's auc: 0.873345	valid_0's binary_logloss: 0.44335
# [5]	valid_0's auc: 0.883463	valid_0's binary_logloss: 0.425986
# [6]	valid_0's auc: 0.884081	valid_0's binary_logloss: 0.412807
# [7]	valid_0's auc: 0.882895	valid_0's binary_logloss: 0.401754
# [8]	valid_0's auc: 0.884579	valid_0's binary_logloss: 0.392658
# [9]	valid_0's auc: 0.886144	valid_0's binary_logloss: 0.385695
# [10]	valid_0's auc: 0.88743	valid_0's binary_logloss: 0.378418
# [11]	valid_0's auc: 0.889015	valid_0's binary_logloss: 0.3738
# [12]	valid_0's auc: 0.890152	valid_0's binary_logloss: 0.369759
# [13]	valid_0's auc: 0.892085	valid_0's binary_logloss: 0.364446
# [14]	valid_0's auc: 0.892215	valid_0's binary_logloss: 0.361003
# [15]	valid_0's auc: 0.892085	valid_0's binary_logloss: 0.357613
# [16]	valid_0's auc: 0.893491	valid_0's binary_logloss: 0.354869
# [17]	valid_0's auc: 0.893351	valid_0's binary_logloss: 0.353329
# [18]	valid_0's auc: 0.896013	valid_0's binary_logloss: 0.349724
# [19]	valid_0's auc: 0.895514	valid_0's binary_logloss: 0.348269
# [20]	valid_0's auc: 0.895375	valid_0's binary_logloss: 0.347306
# [21]	valid_0's auc: 0.893959	valid_0's binary_logloss: 0.346437
# [22]	valid_0's auc: 0.894368	valid_0's binary_logloss: 0.345526
# [23]	valid_0's auc: 0.893551	valid_0's binary_logloss: 0.345056
# [24]	valid_0's auc: 0.89383	valid_0's binary_logloss: 0.344328
# [25]	valid_0's auc: 0.894707	valid_0's binary_logloss: 0.343416
# [26]	valid_0's auc: 0.893032	valid_0's binary_logloss: 0.343508
# [27]	valid_0's auc: 0.891567	valid_0's binary_logloss: 0.34442
# [28]	valid_0's auc: 0.892384	valid_0's binary_logloss: 0.343191
# [29]	valid_0's auc: 0.891886	valid_0's binary_logloss: 0.343528
# [30]	valid_0's auc: 0.892723	valid_0's binary_logloss: 0.341727
# [31]	valid_0's auc: 0.891866	valid_0's binary_logloss: 0.342001
# [32]	valid_0's auc: 0.892703	valid_0's binary_logloss: 0.3407
# [33]	valid_0's auc: 0.891966	valid_0's binary_logloss: 0.341023
# [34]	valid_0's auc: 0.892504	valid_0's binary_logloss: 0.340943
# [35]	valid_0's auc: 0.892165	valid_0's binary_logloss: 0.341386
# [36]	valid_0's auc: 0.891846	valid_0's binary_logloss: 0.342208
# [37]	valid_0's auc: 0.891587	valid_0's binary_logloss: 0.341811
# [38]	valid_0's auc: 0.891926	valid_0's binary_logloss: 0.341079
# [39]	valid_0's auc: 0.891866	valid_0's binary_logloss: 0.340765
# [40]	valid_0's auc: 0.891707	valid_0's binary_logloss: 0.340801
# [41]	valid_0's auc: 0.891368	valid_0's binary_logloss: 0.341165
# [42]	valid_0's auc: 0.891089	valid_0's binary_logloss: 0.341149
# [43]	valid_0's auc: 0.89063	valid_0's binary_logloss: 0.340978
# [44]	valid_0's auc: 0.889992	valid_0's binary_logloss: 0.341063
# [45]	valid_0's auc: 0.889195	valid_0's binary_logloss: 0.342127
# [46]	valid_0's auc: 0.889035	valid_0's binary_logloss: 0.342504
# [47]	valid_0's auc: 0.889354	valid_0's binary_logloss: 0.342178
# [48]	valid_0's auc: 0.888616	valid_0's binary_logloss: 0.342798
# [49]	valid_0's auc: 0.889055	valid_0's binary_logloss: 0.342507
# [50]	valid_0's auc: 0.887919	valid_0's binary_logloss: 0.343101
# [51]	valid_0's auc: 0.888457	valid_0's binary_logloss: 0.342721
# [52]	valid_0's auc: 0.888238	valid_0's binary_logloss: 0.343842
# [53]	valid_0's auc: 0.888138	valid_0's binary_logloss: 0.343836
# [54]	valid_0's auc: 0.888457	valid_0's binary_logloss: 0.343592
# [55]	valid_0's auc: 0.889175	valid_0's binary_logloss: 0.34368
# [56]	valid_0's auc: 0.889055	valid_0's binary_logloss: 0.344448
# [57]	valid_0's auc: 0.890052	valid_0's binary_logloss: 0.34409
# [58]	valid_0's auc: 0.889793	valid_0's binary_logloss: 0.344244
# [59]	valid_0's auc: 0.888896	valid_0's binary_logloss: 0.345225
# [60]	valid_0's auc: 0.889254	valid_0's binary_logloss: 0.345074
# [61]	valid_0's auc: 0.888935	valid_0's binary_logloss: 0.345308
# [62]	valid_0's auc: 0.888656	valid_0's binary_logloss: 0.345814
# [63]	valid_0's auc: 0.888955	valid_0's binary_logloss: 0.345456
# [64]	valid_0's auc: 0.888497	valid_0's binary_logloss: 0.346496
# [65]	valid_0's auc: 0.888417	valid_0's binary_logloss: 0.346482
# [66]	valid_0's auc: 0.888317	valid_0's binary_logloss: 0.346707
# [67]	valid_0's auc: 0.888178	valid_0's binary_logloss: 0.346869
# [68]	valid_0's auc: 0.888876	valid_0's binary_logloss: 0.346175
# [69]	valid_0's auc: 0.888796	valid_0's binary_logloss: 0.346135
# [70]	valid_0's auc: 0.888756	valid_0's binary_logloss: 0.346048
# [71]	valid_0's auc: 0.888616	valid_0's binary_logloss: 0.347053
# [72]	valid_0's auc: 0.888636	valid_0's binary_logloss: 0.34739
# [73]	valid_0's auc: 0.889434	valid_0's binary_logloss: 0.346028
# [74]	valid_0's auc: 0.89047	valid_0's binary_logloss: 0.34512
# [75]	valid_0's auc: 0.890092	valid_0's binary_logloss: 0.3452
# [76]	valid_0's auc: 0.890371	valid_0's binary_logloss: 0.345441
# [77]	valid_0's auc: 0.889414	valid_0's binary_logloss: 0.346264
# [78]	valid_0's auc: 0.889593	valid_0's binary_logloss: 0.34644
# [79]	valid_0's auc: 0.889833	valid_0's binary_logloss: 0.346815
# [80]	valid_0's auc: 0.889394	valid_0's binary_logloss: 0.347214
# [81]	valid_0's auc: 0.889135	valid_0's binary_logloss: 0.347463
# [82]	valid_0's auc: 0.888776	valid_0's binary_logloss: 0.348857
# [83]	valid_0's auc: 0.888876	valid_0's binary_logloss: 0.348839
# [84]	valid_0's auc: 0.888896	valid_0's binary_logloss: 0.34888
# [85]	valid_0's auc: 0.888616	valid_0's binary_logloss: 0.348789
# [86]	valid_0's auc: 0.888278	valid_0's binary_logloss: 0.34907
# [87]	valid_0's auc: 0.888178	valid_0's binary_logloss: 0.349762
# [88]	valid_0's auc: 0.888138	valid_0's binary_logloss: 0.349571
# [89]	valid_0's auc: 0.888317	valid_0's binary_logloss: 0.34911
# [90]	valid_0's auc: 0.888158	valid_0's binary_logloss: 0.349357
# [91]	valid_0's auc: 0.888278	valid_0's binary_logloss: 0.349405
# [92]	valid_0's auc: 0.888238	valid_0's binary_logloss: 0.349865
# [93]	valid_0's auc: 0.888038	valid_0's binary_logloss: 0.3502
# [94]	valid_0's auc: 0.888577	valid_0's binary_logloss: 0.349449
# [95]	valid_0's auc: 0.888258	valid_0's binary_logloss: 0.349839
# [96]	valid_0's auc: 0.887779	valid_0's binary_logloss: 0.350356
# [97]	valid_0's auc: 0.8875	valid_0's binary_logloss: 0.350569
# [98]	valid_0's auc: 0.88744	valid_0's binary_logloss: 0.350571
# [99]	valid_0's auc: 0.887699	valid_0's binary_logloss: 0.350434
# [100]	valid_0's auc: 0.88762	valid_0's binary_logloss: 0.350459
# [LightGBM] [Warning] lambda_l1 is set=1.4313376954414664e-09, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.4313376954414664e-09
# [LightGBM] [Warning] bagging_fraction is set=0.9645651499537614, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9645651499537614
# [LightGBM] [Warning] min_gain_to_split is set=0.5655566115584013, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.5655566115584013
# [LightGBM] [Warning] lambda_l2 is set=5.989006203804819, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.989006203804819
# [LightGBM] [Warning] feature_fraction is set=0.699205159877182, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.699205159877182
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [1]	valid_0's auc: 0.873323	valid_0's binary_logloss: 0.522279
# [2]	valid_0's auc: 0.882804	valid_0's binary_logloss: 0.486995
# [3]	valid_0's auc: 0.886701	valid_0's binary_logloss: 0.459746
# [4]	valid_0's auc: 0.889614	valid_0's binary_logloss: 0.437717
# [5]	valid_0's auc: 0.888761	valid_0's binary_logloss: 0.42046
# [6]	valid_0's auc: 0.890358	valid_0's binary_logloss: 0.40629
# [7]	valid_0's auc: 0.895832	valid_0's binary_logloss: 0.394441
# [8]	valid_0's auc: 0.89762	valid_0's binary_logloss: 0.384342
# [9]	valid_0's auc: 0.898674	valid_0's binary_logloss: 0.37631
# [10]	valid_0's auc: 0.898222	valid_0's binary_logloss: 0.369628
# [11]	valid_0's auc: 0.89765	valid_0's binary_logloss: 0.364387
# [12]	valid_0's auc: 0.897378	valid_0's binary_logloss: 0.359703
# [13]	valid_0's auc: 0.89784	valid_0's binary_logloss: 0.355926
# [14]	valid_0's auc: 0.897851	valid_0's binary_logloss: 0.352668
# [15]	valid_0's auc: 0.897439	valid_0's binary_logloss: 0.35045
# [16]	valid_0's auc: 0.89762	valid_0's binary_logloss: 0.348292
# [17]	valid_0's auc: 0.89772	valid_0's binary_logloss: 0.346353
# [18]	valid_0's auc: 0.895932	valid_0's binary_logloss: 0.345668
# [19]	valid_0's auc: 0.896053	valid_0's binary_logloss: 0.343895
# [20]	valid_0's auc: 0.895671	valid_0's binary_logloss: 0.34348
# [21]	valid_0's auc: 0.895169	valid_0's binary_logloss: 0.34268
# [22]	valid_0's auc: 0.894204	valid_0's binary_logloss: 0.342956
# [23]	valid_0's auc: 0.892557	valid_0's binary_logloss: 0.343821
# [24]	valid_0's auc: 0.892246	valid_0's binary_logloss: 0.343607
# [25]	valid_0's auc: 0.891543	valid_0's binary_logloss: 0.343464
# [26]	valid_0's auc: 0.889675	valid_0's binary_logloss: 0.343281
# [27]	valid_0's auc: 0.889313	valid_0's binary_logloss: 0.342695
# [28]	valid_0's auc: 0.889434	valid_0's binary_logloss: 0.343149
# [29]	valid_0's auc: 0.889052	valid_0's binary_logloss: 0.343189
# [30]	valid_0's auc: 0.887666	valid_0's binary_logloss: 0.344503
# [31]	valid_0's auc: 0.887264	valid_0's binary_logloss: 0.344906
# [32]	valid_0's auc: 0.887083	valid_0's binary_logloss: 0.345191
# [33]	valid_0's auc: 0.88642	valid_0's binary_logloss: 0.344973
# [34]	valid_0's auc: 0.886521	valid_0's binary_logloss: 0.34475
# [35]	valid_0's auc: 0.886239	valid_0's binary_logloss: 0.344937
# [36]	valid_0's auc: 0.886501	valid_0's binary_logloss: 0.344403
# [37]	valid_0's auc: 0.88634	valid_0's binary_logloss: 0.344806
# [38]	valid_0's auc: 0.886059	valid_0's binary_logloss: 0.344948
# [39]	valid_0's auc: 0.886219	valid_0's binary_logloss: 0.344654
# [40]	valid_0's auc: 0.885878	valid_0's binary_logloss: 0.345632
# [41]	valid_0's auc: 0.886119	valid_0's binary_logloss: 0.345519
# [42]	valid_0's auc: 0.884773	valid_0's binary_logloss: 0.346586
# [43]	valid_0's auc: 0.884833	valid_0's binary_logloss: 0.346472
# [44]	valid_0's auc: 0.885255	valid_0's binary_logloss: 0.346329
# [45]	valid_0's auc: 0.88417	valid_0's binary_logloss: 0.347308
# [46]	valid_0's auc: 0.885195	valid_0's binary_logloss: 0.346581
# [47]	valid_0's auc: 0.885335	valid_0's binary_logloss: 0.346977
# [48]	valid_0's auc: 0.886239	valid_0's binary_logloss: 0.346801
# [49]	valid_0's auc: 0.887224	valid_0's binary_logloss: 0.345716
# [50]	valid_0's auc: 0.887384	valid_0's binary_logloss: 0.345302
# [51]	valid_0's auc: 0.886822	valid_0's binary_logloss: 0.345944
# [52]	valid_0's auc: 0.88632	valid_0's binary_logloss: 0.346425
# [53]	valid_0's auc: 0.887224	valid_0's binary_logloss: 0.346057
# [54]	valid_0's auc: 0.886641	valid_0's binary_logloss: 0.346871
# [55]	valid_0's auc: 0.886501	valid_0's binary_logloss: 0.347164
# [56]	valid_0's auc: 0.88638	valid_0's binary_logloss: 0.34707
# [57]	valid_0's auc: 0.886481	valid_0's binary_logloss: 0.346717
# [58]	valid_0's auc: 0.8864	valid_0's binary_logloss: 0.347347
# [59]	valid_0's auc: 0.886902	valid_0's binary_logloss: 0.347338
# [60]	valid_0's auc: 0.886822	valid_0's binary_logloss: 0.347261
# [61]	valid_0's auc: 0.88636	valid_0's binary_logloss: 0.347944
# [62]	valid_0's auc: 0.886179	valid_0's binary_logloss: 0.34815
# [63]	valid_0's auc: 0.885677	valid_0's binary_logloss: 0.348518
# [64]	valid_0's auc: 0.885536	valid_0's binary_logloss: 0.349216
# [65]	valid_0's auc: 0.884793	valid_0's binary_logloss: 0.349949
# [66]	valid_0's auc: 0.88419	valid_0's binary_logloss: 0.35059
# [67]	valid_0's auc: 0.884793	valid_0's binary_logloss: 0.350048
# [68]	valid_0's auc: 0.885416	valid_0's binary_logloss: 0.349827
# [69]	valid_0's auc: 0.885918	valid_0's binary_logloss: 0.350025
# [70]	valid_0's auc: 0.884934	valid_0's binary_logloss: 0.351232
# [71]	valid_0's auc: 0.884452	valid_0's binary_logloss: 0.351761
# [72]	valid_0's auc: 0.883588	valid_0's binary_logloss: 0.3523
# [73]	valid_0's auc: 0.88403	valid_0's binary_logloss: 0.352328
# [74]	valid_0's auc: 0.88419	valid_0's binary_logloss: 0.352504
# [75]	valid_0's auc: 0.884271	valid_0's binary_logloss: 0.352588
# [76]	valid_0's auc: 0.884251	valid_0's binary_logloss: 0.352546
# [77]	valid_0's auc: 0.88405	valid_0's binary_logloss: 0.352469
# [78]	valid_0's auc: 0.88417	valid_0's binary_logloss: 0.352768
# [79]	valid_0's auc: 0.883789	valid_0's binary_logloss: 0.352832
# [80]	valid_0's auc: 0.883327	valid_0's binary_logloss: 0.353326
# [81]	valid_0's auc: 0.883065	valid_0's binary_logloss: 0.353469
# [82]	valid_0's auc: 0.883367	valid_0's binary_logloss: 0.353371
# [83]	valid_0's auc: 0.883387	valid_0's binary_logloss: 0.353777
# [84]	valid_0's auc: 0.882784	valid_0's binary_logloss: 0.354142
# [85]	valid_0's auc: 0.883427	valid_0's binary_logloss: 0.353518
# [86]	valid_0's auc: 0.883548	valid_0's binary_logloss: 0.353484
# [87]	valid_0's auc: 0.883849	valid_0's binary_logloss: 0.35331
# [88]	valid_0's auc: 0.883467	valid_0's binary_logloss: 0.35352
# [89]	valid_0's auc: 0.883809	valid_0's binary_logloss: 0.353444
# [90]	valid_0's auc: 0.883548	valid_0's binary_logloss: 0.353686
# [91]	valid_0's auc: 0.883708	valid_0's binary_logloss: 0.353747
# [92]	valid_0's auc: 0.883929	valid_0's binary_logloss: 0.353718
# [93]	valid_0's auc: 0.88405	valid_0's binary_logloss: 0.353608
# [94]	valid_0's auc: 0.883246	valid_0's binary_logloss: 0.354518
# [95]	valid_0's auc: 0.883327	valid_0's binary_logloss: 0.354034
# [96]	valid_0's auc: 0.883568	valid_0's binary_logloss: 0.354005
# [97]	valid_0's auc: 0.883266	valid_0's binary_logloss: 0.354681
# [98]	valid_0's auc: 0.883608	valid_0's binary_logloss: 0.354479
# [99]	valid_0's auc: 0.883367	valid_0's binary_logloss: 0.354966
# [100]	valid_0's auc: 0.883126	valid_0's binary_logloss: 0.355287
# [LightGBM] [Warning] lambda_l1 is set=1.4313376954414664e-09, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.4313376954414664e-09
# [LightGBM] [Warning] bagging_fraction is set=0.9645651499537614, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9645651499537614
# [LightGBM] [Warning] min_gain_to_split is set=0.5655566115584013, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.5655566115584013
# [LightGBM] [Warning] lambda_l2 is set=5.989006203804819, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.989006203804819
# [LightGBM] [Warning] feature_fraction is set=0.699205159877182, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.699205159877182
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [1]	valid_0's auc: 0.875994	valid_0's binary_logloss: 0.51834
# [2]	valid_0's auc: 0.87734	valid_0's binary_logloss: 0.481983
# [3]	valid_0's auc: 0.889293	valid_0's binary_logloss: 0.453112
# [4]	valid_0's auc: 0.891914	valid_0's binary_logloss: 0.4301
# [5]	valid_0's auc: 0.894837	valid_0's binary_logloss: 0.411017
# [6]	valid_0's auc: 0.894877	valid_0's binary_logloss: 0.396201
# [7]	valid_0's auc: 0.897328	valid_0's binary_logloss: 0.383616
# [8]	valid_0's auc: 0.895882	valid_0's binary_logloss: 0.374581
# [9]	valid_0's auc: 0.895721	valid_0's binary_logloss: 0.366387
# [10]	valid_0's auc: 0.896123	valid_0's binary_logloss: 0.359502
# [11]	valid_0's auc: 0.89779	valid_0's binary_logloss: 0.353494
# [12]	valid_0's auc: 0.89778	valid_0's binary_logloss: 0.349316
# [13]	valid_0's auc: 0.898785	valid_0's binary_logloss: 0.345104
# [14]	valid_0's auc: 0.899076	valid_0's binary_logloss: 0.341683
# [15]	valid_0's auc: 0.901738	valid_0's binary_logloss: 0.338689
# [16]	valid_0's auc: 0.901939	valid_0's binary_logloss: 0.336835
# [17]	valid_0's auc: 0.901185	valid_0's binary_logloss: 0.335228
# [18]	valid_0's auc: 0.90223	valid_0's binary_logloss: 0.333221
# [19]	valid_0's auc: 0.903716	valid_0's binary_logloss: 0.331464
# [20]	valid_0's auc: 0.905012	valid_0's binary_logloss: 0.329272
# [21]	valid_0's auc: 0.905072	valid_0's binary_logloss: 0.328321
# [22]	valid_0's auc: 0.905675	valid_0's binary_logloss: 0.326953
# [23]	valid_0's auc: 0.904992	valid_0's binary_logloss: 0.326416
# [24]	valid_0's auc: 0.904972	valid_0's binary_logloss: 0.326678
# [25]	valid_0's auc: 0.904691	valid_0's binary_logloss: 0.326761
# [26]	valid_0's auc: 0.904731	valid_0's binary_logloss: 0.326719
# [27]	valid_0's auc: 0.904942	valid_0's binary_logloss: 0.326062
# [28]	valid_0's auc: 0.905896	valid_0's binary_logloss: 0.324938
# [29]	valid_0's auc: 0.906519	valid_0's binary_logloss: 0.323338
# [30]	valid_0's auc: 0.90689	valid_0's binary_logloss: 0.322564
# [31]	valid_0's auc: 0.907312	valid_0's binary_logloss: 0.322382
# [32]	valid_0's auc: 0.908337	valid_0's binary_logloss: 0.321246
# [33]	valid_0's auc: 0.908397	valid_0's binary_logloss: 0.321178
# [34]	valid_0's auc: 0.908477	valid_0's binary_logloss: 0.321271
# [35]	valid_0's auc: 0.907995	valid_0's binary_logloss: 0.321555
# [36]	valid_0's auc: 0.907232	valid_0's binary_logloss: 0.321955
# [37]	valid_0's auc: 0.907533	valid_0's binary_logloss: 0.321635
# [38]	valid_0's auc: 0.908598	valid_0's binary_logloss: 0.32087
# [39]	valid_0's auc: 0.909361	valid_0's binary_logloss: 0.320008
# [40]	valid_0's auc: 0.909723	valid_0's binary_logloss: 0.31955
# [41]	valid_0's auc: 0.910245	valid_0's binary_logloss: 0.319132
# [42]	valid_0's auc: 0.909763	valid_0's binary_logloss: 0.319191
# [43]	valid_0's auc: 0.9091	valid_0's binary_logloss: 0.32003
# [44]	valid_0's auc: 0.910546	valid_0's binary_logloss: 0.318981
# [45]	valid_0's auc: 0.910808	valid_0's binary_logloss: 0.318573
# [46]	valid_0's auc: 0.911551	valid_0's binary_logloss: 0.317888
# [47]	valid_0's auc: 0.911812	valid_0's binary_logloss: 0.317524
# [48]	valid_0's auc: 0.912294	valid_0's binary_logloss: 0.316364
# [49]	valid_0's auc: 0.911933	valid_0's binary_logloss: 0.316164
# [50]	valid_0's auc: 0.912153	valid_0's binary_logloss: 0.315792
# [51]	valid_0's auc: 0.912616	valid_0's binary_logloss: 0.31497
# [52]	valid_0's auc: 0.913961	valid_0's binary_logloss: 0.313942
# [53]	valid_0's auc: 0.91358	valid_0's binary_logloss: 0.314449
# [54]	valid_0's auc: 0.913801	valid_0's binary_logloss: 0.314402
# [55]	valid_0's auc: 0.91366	valid_0's binary_logloss: 0.314441
# [56]	valid_0's auc: 0.913359	valid_0's binary_logloss: 0.314504
# [57]	valid_0's auc: 0.91354	valid_0's binary_logloss: 0.314113
# [58]	valid_0's auc: 0.913319	valid_0's binary_logloss: 0.314418
# [59]	valid_0's auc: 0.9136	valid_0's binary_logloss: 0.314038
# [60]	valid_0's auc: 0.91358	valid_0's binary_logloss: 0.314105
# [61]	valid_0's auc: 0.912495	valid_0's binary_logloss: 0.315253
# [62]	valid_0's auc: 0.913238	valid_0's binary_logloss: 0.314635
# [63]	valid_0's auc: 0.913459	valid_0's binary_logloss: 0.314604
# [64]	valid_0's auc: 0.913379	valid_0's binary_logloss: 0.314138
# [65]	valid_0's auc: 0.913198	valid_0's binary_logloss: 0.314268
# [66]	valid_0's auc: 0.913499	valid_0's binary_logloss: 0.313812
# [67]	valid_0's auc: 0.913982	valid_0's binary_logloss: 0.31353
# [68]	valid_0's auc: 0.913439	valid_0's binary_logloss: 0.313987
# [69]	valid_0's auc: 0.913178	valid_0's binary_logloss: 0.314435
# [70]	valid_0's auc: 0.912816	valid_0's binary_logloss: 0.315089
# [71]	valid_0's auc: 0.912716	valid_0's binary_logloss: 0.315532
# [72]	valid_0's auc: 0.912877	valid_0's binary_logloss: 0.315689
# [73]	valid_0's auc: 0.912515	valid_0's binary_logloss: 0.315773
# [74]	valid_0's auc: 0.912334	valid_0's binary_logloss: 0.316102
# [75]	valid_0's auc: 0.912194	valid_0's binary_logloss: 0.315941
# [76]	valid_0's auc: 0.912274	valid_0's binary_logloss: 0.315946
# [77]	valid_0's auc: 0.912073	valid_0's binary_logloss: 0.316148
# [78]	valid_0's auc: 0.912133	valid_0's binary_logloss: 0.31656
# [79]	valid_0's auc: 0.91145	valid_0's binary_logloss: 0.316934
# [80]	valid_0's auc: 0.91127	valid_0's binary_logloss: 0.317396
# [81]	valid_0's auc: 0.91145	valid_0's binary_logloss: 0.317345
# [82]	valid_0's auc: 0.911993	valid_0's binary_logloss: 0.316903
# [83]	valid_0's auc: 0.912314	valid_0's binary_logloss: 0.316644
# [84]	valid_0's auc: 0.912636	valid_0's binary_logloss: 0.316052
# [85]	valid_0's auc: 0.912836	valid_0's binary_logloss: 0.316127
# [86]	valid_0's auc: 0.912395	valid_0's binary_logloss: 0.316252
# [87]	valid_0's auc: 0.912274	valid_0's binary_logloss: 0.316582
# [88]	valid_0's auc: 0.912435	valid_0's binary_logloss: 0.316232
# [89]	valid_0's auc: 0.912395	valid_0's binary_logloss: 0.31641
# [90]	valid_0's auc: 0.912194	valid_0's binary_logloss: 0.316837
# [91]	valid_0's auc: 0.912174	valid_0's binary_logloss: 0.317395
# [92]	valid_0's auc: 0.912234	valid_0's binary_logloss: 0.317346
# [93]	valid_0's auc: 0.912334	valid_0's binary_logloss: 0.317068
# [94]	valid_0's auc: 0.912334	valid_0's binary_logloss: 0.317068
# [95]	valid_0's auc: 0.912053	valid_0's binary_logloss: 0.317268
# [96]	valid_0's auc: 0.911611	valid_0's binary_logloss: 0.317871
# [97]	valid_0's auc: 0.911611	valid_0's binary_logloss: 0.317871
# [98]	valid_0's auc: 0.911611	valid_0's binary_logloss: 0.317871
# [99]	valid_0's auc: 0.911571	valid_0's binary_logloss: 0.317964
# [100]	valid_0's auc: 0.911792	valid_0's binary_logloss: 0.318029
# [LightGBM] [Warning] lambda_l1 is set=1.4313376954414664e-09, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.4313376954414664e-09
# [LightGBM] [Warning] bagging_fraction is set=0.9645651499537614, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9645651499537614
# [LightGBM] [Warning] min_gain_to_split is set=0.5655566115584013, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.5655566115584013
# [LightGBM] [Warning] lambda_l2 is set=5.989006203804819, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.989006203804819
# [LightGBM] [Warning] feature_fraction is set=0.699205159877182, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.699205159877182
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [1]	valid_0's auc: 0.845751	valid_0's binary_logloss: 0.527524
# [2]	valid_0's auc: 0.856087	valid_0's binary_logloss: 0.494693
# [3]	valid_0's auc: 0.85681	valid_0's binary_logloss: 0.471015
# [4]	valid_0's auc: 0.857382	valid_0's binary_logloss: 0.451513
# [5]	valid_0's auc: 0.859291	valid_0's binary_logloss: 0.435518
# [6]	valid_0's auc: 0.86147	valid_0's binary_logloss: 0.42304
# [7]	valid_0's auc: 0.863831	valid_0's binary_logloss: 0.412862
# [8]	valid_0's auc: 0.864223	valid_0's binary_logloss: 0.404541
# [9]	valid_0's auc: 0.86361	valid_0's binary_logloss: 0.397894
# [10]	valid_0's auc: 0.866472	valid_0's binary_logloss: 0.392874
# [11]	valid_0's auc: 0.866764	valid_0's binary_logloss: 0.388126
# [12]	valid_0's auc: 0.866563	valid_0's binary_logloss: 0.384931
# [13]	valid_0's auc: 0.866824	valid_0's binary_logloss: 0.381612
# [14]	valid_0's auc: 0.867658	valid_0's binary_logloss: 0.378336
# [15]	valid_0's auc: 0.866975	valid_0's binary_logloss: 0.377049
# [16]	valid_0's auc: 0.86589	valid_0's binary_logloss: 0.37656
# [17]	valid_0's auc: 0.872941	valid_0's binary_logloss: 0.374678
# [18]	valid_0's auc: 0.87263	valid_0's binary_logloss: 0.373898
# [19]	valid_0's auc: 0.872027	valid_0's binary_logloss: 0.373318
# [20]	valid_0's auc: 0.872298	valid_0's binary_logloss: 0.372302
# [21]	valid_0's auc: 0.870661	valid_0's binary_logloss: 0.372475
# [22]	valid_0's auc: 0.870791	valid_0's binary_logloss: 0.371805
# [23]	valid_0's auc: 0.871796	valid_0's binary_logloss: 0.370788
# [24]	valid_0's auc: 0.870611	valid_0's binary_logloss: 0.371299
# [25]	valid_0's auc: 0.871073	valid_0's binary_logloss: 0.371524
# [26]	valid_0's auc: 0.870179	valid_0's binary_logloss: 0.371665
# [27]	valid_0's auc: 0.870038	valid_0's binary_logloss: 0.37128
# [28]	valid_0's auc: 0.869737	valid_0's binary_logloss: 0.371801
# [29]	valid_0's auc: 0.869807	valid_0's binary_logloss: 0.372805
# [30]	valid_0's auc: 0.869104	valid_0's binary_logloss: 0.373223
# [31]	valid_0's auc: 0.867517	valid_0's binary_logloss: 0.374947
# [32]	valid_0's auc: 0.868381	valid_0's binary_logloss: 0.374954
# [33]	valid_0's auc: 0.867838	valid_0's binary_logloss: 0.374674
# [34]	valid_0's auc: 0.869807	valid_0's binary_logloss: 0.373547
# [35]	valid_0's auc: 0.869305	valid_0's binary_logloss: 0.373268
# [36]	valid_0's auc: 0.869667	valid_0's binary_logloss: 0.372212
# [37]	valid_0's auc: 0.869245	valid_0's binary_logloss: 0.372664
# [38]	valid_0's auc: 0.87053	valid_0's binary_logloss: 0.37182
# [39]	valid_0's auc: 0.869425	valid_0's binary_logloss: 0.372811
# [40]	valid_0's auc: 0.869144	valid_0's binary_logloss: 0.372685
# [41]	valid_0's auc: 0.868883	valid_0's binary_logloss: 0.373001
# [42]	valid_0's auc: 0.868401	valid_0's binary_logloss: 0.373879
# [43]	valid_0's auc: 0.867718	valid_0's binary_logloss: 0.374814
# [44]	valid_0's auc: 0.868361	valid_0's binary_logloss: 0.374851
# [45]	valid_0's auc: 0.868039	valid_0's binary_logloss: 0.374891
# [46]	valid_0's auc: 0.867979	valid_0's binary_logloss: 0.376182
# [47]	valid_0's auc: 0.867316	valid_0's binary_logloss: 0.378046
# [48]	valid_0's auc: 0.867517	valid_0's binary_logloss: 0.377734
# [49]	valid_0's auc: 0.867618	valid_0's binary_logloss: 0.377806
# [50]	valid_0's auc: 0.867537	valid_0's binary_logloss: 0.377812
# [51]	valid_0's auc: 0.86812	valid_0's binary_logloss: 0.377302
# [52]	valid_0's auc: 0.867778	valid_0's binary_logloss: 0.378169
# [53]	valid_0's auc: 0.866874	valid_0's binary_logloss: 0.379033
# [54]	valid_0's auc: 0.866995	valid_0's binary_logloss: 0.379129
# [55]	valid_0's auc: 0.867155	valid_0's binary_logloss: 0.379545
# [56]	valid_0's auc: 0.867055	valid_0's binary_logloss: 0.379422
# [57]	valid_0's auc: 0.866211	valid_0's binary_logloss: 0.380047
# [58]	valid_0's auc: 0.866533	valid_0's binary_logloss: 0.380029
# [59]	valid_0's auc: 0.866312	valid_0's binary_logloss: 0.38009
# [60]	valid_0's auc: 0.86601	valid_0's binary_logloss: 0.380472
# [61]	valid_0's auc: 0.865428	valid_0's binary_logloss: 0.381854
# [62]	valid_0's auc: 0.864725	valid_0's binary_logloss: 0.382869
# [63]	valid_0's auc: 0.864444	valid_0's binary_logloss: 0.383354
# [64]	valid_0's auc: 0.864283	valid_0's binary_logloss: 0.384534
# [65]	valid_0's auc: 0.86366	valid_0's binary_logloss: 0.385729
# [66]	valid_0's auc: 0.863258	valid_0's binary_logloss: 0.38611
# [67]	valid_0's auc: 0.862917	valid_0's binary_logloss: 0.386847
# [68]	valid_0's auc: 0.862957	valid_0's binary_logloss: 0.387158
# [69]	valid_0's auc: 0.862274	valid_0's binary_logloss: 0.388167
# [70]	valid_0's auc: 0.862435	valid_0's binary_logloss: 0.388558
# [71]	valid_0's auc: 0.861189	valid_0's binary_logloss: 0.390644
# [72]	valid_0's auc: 0.860948	valid_0's binary_logloss: 0.391268
# [73]	valid_0's auc: 0.861129	valid_0's binary_logloss: 0.390838
# [74]	valid_0's auc: 0.861631	valid_0's binary_logloss: 0.390619
# [75]	valid_0's auc: 0.86147	valid_0's binary_logloss: 0.391009
# [76]	valid_0's auc: 0.861069	valid_0's binary_logloss: 0.391287
# [77]	valid_0's auc: 0.860767	valid_0's binary_logloss: 0.391071
# [78]	valid_0's auc: 0.860787	valid_0's binary_logloss: 0.391681
# [79]	valid_0's auc: 0.860988	valid_0's binary_logloss: 0.391423
# [80]	valid_0's auc: 0.860968	valid_0's binary_logloss: 0.391071
# [81]	valid_0's auc: 0.86127	valid_0's binary_logloss: 0.391117
# [82]	valid_0's auc: 0.860707	valid_0's binary_logloss: 0.39152
# [83]	valid_0's auc: 0.860908	valid_0's binary_logloss: 0.391689
# [84]	valid_0's auc: 0.860908	valid_0's binary_logloss: 0.391665
# [85]	valid_0's auc: 0.861089	valid_0's binary_logloss: 0.391651
# [86]	valid_0's auc: 0.86135	valid_0's binary_logloss: 0.391424
# [87]	valid_0's auc: 0.861852	valid_0's binary_logloss: 0.391156
# [88]	valid_0's auc: 0.861531	valid_0's binary_logloss: 0.391337
# [89]	valid_0's auc: 0.861611	valid_0's binary_logloss: 0.39139
# [90]	valid_0's auc: 0.861691	valid_0's binary_logloss: 0.391708
# [91]	valid_0's auc: 0.862133	valid_0's binary_logloss: 0.39181
# [92]	valid_0's auc: 0.862816	valid_0's binary_logloss: 0.391669
# [93]	valid_0's auc: 0.862716	valid_0's binary_logloss: 0.391347
# [94]	valid_0's auc: 0.862214	valid_0's binary_logloss: 0.392156
# [95]	valid_0's auc: 0.862033	valid_0's binary_logloss: 0.39273
# [96]	valid_0's auc: 0.861792	valid_0's binary_logloss: 0.393345
# [97]	valid_0's auc: 0.861792	valid_0's binary_logloss: 0.393345
# [98]	valid_0's auc: 0.862636	valid_0's binary_logloss: 0.392471
# [99]	valid_0's auc: 0.862776	valid_0's binary_logloss: 0.392463
# [100]	valid_0's auc: 0.862274	valid_0's binary_logloss: 0.39258
# [LightGBM] [Warning] lambda_l1 is set=1.4313376954414664e-09, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.4313376954414664e-09
# [LightGBM] [Warning] bagging_fraction is set=0.9645651499537614, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9645651499537614
# [LightGBM] [Warning] min_gain_to_split is set=0.5655566115584013, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.5655566115584013
# [LightGBM] [Warning] lambda_l2 is set=5.989006203804819, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.989006203804819
# [LightGBM] [Warning] feature_fraction is set=0.699205159877182, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.699205159877182
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [1]	valid_0's auc: 0.87461	valid_0's binary_logloss: 0.525844
# [2]	valid_0's auc: 0.881446	valid_0's binary_logloss: 0.493312
# [3]	valid_0's auc: 0.885114	valid_0's binary_logloss: 0.467062
# [4]	valid_0's auc: 0.890571	valid_0's binary_logloss: 0.44564
# [5]	valid_0's auc: 0.888792	valid_0's binary_logloss: 0.429394
# [6]	valid_0's auc: 0.886174	valid_0's binary_logloss: 0.417201
# [7]	valid_0's auc: 0.888283	valid_0's binary_logloss: 0.406625
# [8]	valid_0's auc: 0.889092	valid_0's binary_logloss: 0.397923
# [9]	valid_0's auc: 0.890891	valid_0's binary_logloss: 0.390107
# [10]	valid_0's auc: 0.891151	valid_0's binary_logloss: 0.383782
# [11]	valid_0's auc: 0.888762	valid_0's binary_logloss: 0.37923
# [12]	valid_0's auc: 0.888462	valid_0's binary_logloss: 0.375774
# [13]	valid_0's auc: 0.888113	valid_0's binary_logloss: 0.372786
# [14]	valid_0's auc: 0.888393	valid_0's binary_logloss: 0.36943
# [15]	valid_0's auc: 0.889162	valid_0's binary_logloss: 0.366725
# [16]	valid_0's auc: 0.887993	valid_0's binary_logloss: 0.364977
# [17]	valid_0's auc: 0.888273	valid_0's binary_logloss: 0.362801
# [18]	valid_0's auc: 0.888203	valid_0's binary_logloss: 0.361301
# [19]	valid_0's auc: 0.888552	valid_0's binary_logloss: 0.359812
# [20]	valid_0's auc: 0.890022	valid_0's binary_logloss: 0.358093
# [21]	valid_0's auc: 0.891221	valid_0's binary_logloss: 0.356929
# [22]	valid_0's auc: 0.891301	valid_0's binary_logloss: 0.356225
# [23]	valid_0's auc: 0.891361	valid_0's binary_logloss: 0.355448
# [24]	valid_0's auc: 0.891341	valid_0's binary_logloss: 0.35498
# [25]	valid_0's auc: 0.891351	valid_0's binary_logloss: 0.354553
# [26]	valid_0's auc: 0.89283	valid_0's binary_logloss: 0.353359
# [27]	valid_0's auc: 0.89259	valid_0's binary_logloss: 0.353131
# [28]	valid_0's auc: 0.89199	valid_0's binary_logloss: 0.353363
# [29]	valid_0's auc: 0.89216	valid_0's binary_logloss: 0.353107
# [30]	valid_0's auc: 0.89248	valid_0's binary_logloss: 0.353409
# [31]	valid_0's auc: 0.89257	valid_0's binary_logloss: 0.352536
# [32]	valid_0's auc: 0.89309	valid_0's binary_logloss: 0.352659
# [33]	valid_0's auc: 0.894109	valid_0's binary_logloss: 0.351448
# [34]	valid_0's auc: 0.89337	valid_0's binary_logloss: 0.352256
# [35]	valid_0's auc: 0.89235	valid_0's binary_logloss: 0.353399
# [36]	valid_0's auc: 0.891811	valid_0's binary_logloss: 0.354231
# [37]	valid_0's auc: 0.89255	valid_0's binary_logloss: 0.353871
# [38]	valid_0's auc: 0.8923	valid_0's binary_logloss: 0.353853
# [39]	valid_0's auc: 0.89224	valid_0's binary_logloss: 0.35326
# [40]	valid_0's auc: 0.89276	valid_0's binary_logloss: 0.353216
# [41]	valid_0's auc: 0.89302	valid_0's binary_logloss: 0.353865
# [42]	valid_0's auc: 0.89338	valid_0's binary_logloss: 0.353985
# [43]	valid_0's auc: 0.89324	valid_0's binary_logloss: 0.353776
# [44]	valid_0's auc: 0.894099	valid_0's binary_logloss: 0.353112
# [45]	valid_0's auc: 0.894679	valid_0's binary_logloss: 0.35282
# [46]	valid_0's auc: 0.895938	valid_0's binary_logloss: 0.351594
# [47]	valid_0's auc: 0.895099	valid_0's binary_logloss: 0.3526
# [48]	valid_0's auc: 0.895139	valid_0's binary_logloss: 0.352219
# [49]	valid_0's auc: 0.894579	valid_0's binary_logloss: 0.352833
# [50]	valid_0's auc: 0.893799	valid_0's binary_logloss: 0.352994
# [51]	valid_0's auc: 0.894879	valid_0's binary_logloss: 0.352471
# [52]	valid_0's auc: 0.894099	valid_0's binary_logloss: 0.353911
# [53]	valid_0's auc: 0.895219	valid_0's binary_logloss: 0.353617
# [54]	valid_0's auc: 0.894859	valid_0's binary_logloss: 0.353607
# [55]	valid_0's auc: 0.894099	valid_0's binary_logloss: 0.354643
# [56]	valid_0's auc: 0.893919	valid_0's binary_logloss: 0.355001
# [57]	valid_0's auc: 0.89278	valid_0's binary_logloss: 0.356049
# [58]	valid_0's auc: 0.8925	valid_0's binary_logloss: 0.3567
# [59]	valid_0's auc: 0.89272	valid_0's binary_logloss: 0.356861
# [60]	valid_0's auc: 0.8923	valid_0's binary_logloss: 0.357297
# [61]	valid_0's auc: 0.89256	valid_0's binary_logloss: 0.3567
# [62]	valid_0's auc: 0.891961	valid_0's binary_logloss: 0.357368
# [63]	valid_0's auc: 0.89216	valid_0's binary_logloss: 0.357462
# [64]	valid_0's auc: 0.891661	valid_0's binary_logloss: 0.358258
# [65]	valid_0's auc: 0.8921	valid_0's binary_logloss: 0.358575
# [66]	valid_0's auc: 0.89216	valid_0's binary_logloss: 0.358096
# [67]	valid_0's auc: 0.89242	valid_0's binary_logloss: 0.357747
# [68]	valid_0's auc: 0.891761	valid_0's binary_logloss: 0.358712
# [69]	valid_0's auc: 0.891901	valid_0's binary_logloss: 0.358884
# [70]	valid_0's auc: 0.89218	valid_0's binary_logloss: 0.358672
# [71]	valid_0's auc: 0.89244	valid_0's binary_logloss: 0.357976
# [72]	valid_0's auc: 0.891881	valid_0's binary_logloss: 0.35851
# [73]	valid_0's auc: 0.891341	valid_0's binary_logloss: 0.358838
# [74]	valid_0's auc: 0.891081	valid_0's binary_logloss: 0.358887
# [75]	valid_0's auc: 0.891121	valid_0's binary_logloss: 0.359199
# [76]	valid_0's auc: 0.890142	valid_0's binary_logloss: 0.360104
# [77]	valid_0's auc: 0.889342	valid_0's binary_logloss: 0.361138
# [78]	valid_0's auc: 0.889482	valid_0's binary_logloss: 0.361516
# [79]	valid_0's auc: 0.888063	valid_0's binary_logloss: 0.36298
# [80]	valid_0's auc: 0.887223	valid_0's binary_logloss: 0.363899
# [81]	valid_0's auc: 0.887283	valid_0's binary_logloss: 0.364373
# [82]	valid_0's auc: 0.886783	valid_0's binary_logloss: 0.364988
# [83]	valid_0's auc: 0.887383	valid_0's binary_logloss: 0.364554
# [84]	valid_0's auc: 0.887623	valid_0's binary_logloss: 0.364239
# [85]	valid_0's auc: 0.887463	valid_0's binary_logloss: 0.364827
# [86]	valid_0's auc: 0.886703	valid_0's binary_logloss: 0.364951
# [87]	valid_0's auc: 0.886324	valid_0's binary_logloss: 0.365902
# [88]	valid_0's auc: 0.886484	valid_0's binary_logloss: 0.365716
# [89]	valid_0's auc: 0.885844	valid_0's binary_logloss: 0.366451
# [90]	valid_0's auc: 0.885944	valid_0's binary_logloss: 0.366326
# [91]	valid_0's auc: 0.886484	valid_0's binary_logloss: 0.366412
# [92]	valid_0's auc: 0.886863	valid_0's binary_logloss: 0.365797
# [93]	valid_0's auc: 0.887263	valid_0's binary_logloss: 0.36545
# [94]	valid_0's auc: 0.886743	valid_0's binary_logloss: 0.365783
# [95]	valid_0's auc: 0.886344	valid_0's binary_logloss: 0.366152
# [96]	valid_0's auc: 0.886504	valid_0's binary_logloss: 0.366351
# [97]	valid_0's auc: 0.887063	valid_0's binary_logloss: 0.366142
# [98]	valid_0's auc: 0.887543	valid_0's binary_logloss: 0.36606
# [99]	valid_0's auc: 0.887643	valid_0's binary_logloss: 0.365739
# [100]	valid_0's auc: 0.888163	valid_0's binary_logloss: 0.36591
# Overall AUC (LGBMClassifier with StratifiedKFold): 0.8854904808506922

# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center" style="color:darkgoldenrod;">🎇🌭Plots from results for lightgbm♒🌊</h1>
#
# </div>

# %%
categorical_columns = X.select_dtypes(include=['object', 'category']).columns.tolist()

label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])  
    label_encoders[col] = le  

cat_features = [X.columns.get_loc(col) for col in categorical_columns]
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=41)
accuracy_list = []
f1_list = []
roc_auc_list = []
for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    print(f"\nTraining Fold {fold}/{n_splits}")
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    catboost_model = CatBoostClassifier(
        iterations=1000,
        learning_rate=0.1,
        depth=6,
        cat_features=cat_features, 
        verbose=200,
        early_stopping_rounds=10
    )
 
    catboost_model.fit(X_train, y_train, eval_set=(X_val, y_val), early_stopping_rounds=10, verbose=200)
    y_pred = catboost_model.predict(X_val)
    y_pred_proba = catboost_model.predict_proba(X_val)[:, 1]
    accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average="weighted")
    roc_auc = roc_auc_score(y_val, y_pred_proba)
    accuracy_list.append(accuracy)
    f1_list.append(f1)
    roc_auc_list.append(roc_auc)
    print(f"Fold {fold} - Accuracy: {accuracy:.4f}, F1-Score: {f1:.4f}, ROC-AUC: {roc_auc:.4f}")
print("\nCross-Validation Results:")
print(f"Mean Accuracy: {np.mean(accuracy_list):.4f} ± {np.std(accuracy_list):.4f}")
print(f"Mean F1-Score: {np.mean(f1_list):.4f} ± {np.std(f1_list):.4f}")
print(f"Mean ROC-AUC: {np.mean(roc_auc_list):.4f} ± {np.std(roc_auc_list):.4f}")
# Out:
# Training Fold 1/5
# 0:	learn: 0.6140482	test: 0.6186186	best: 0.6186186 (0)	total: 63.4ms	remaining: 1m 3s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.3543340683
# bestIteration = 47
#
# Shrink model to first 48 iterations.
# Fold 1 - Accuracy: 0.8594, F1-Score: 0.8571, ROC-AUC: 0.8851
#
# Training Fold 2/5
# 0:	learn: 0.6116952	test: 0.6158227	best: 0.6158227 (0)	total: 7.77ms	remaining: 7.76s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.3627710492
# bestIteration = 37
#
# Shrink model to first 38 iterations.
# Fold 2 - Accuracy: 0.8474, F1-Score: 0.8435, ROC-AUC: 0.8828
#
# Training Fold 3/5
# 0:	learn: 0.6126613	test: 0.6146148	best: 0.6146148 (0)	total: 6.04ms	remaining: 6.04s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.3599526083
# bestIteration = 36
#
# Shrink model to first 37 iterations.
# Fold 3 - Accuracy: 0.8611, F1-Score: 0.8578, ROC-AUC: 0.8808
#
# Training Fold 4/5
# 0:	learn: 0.6123234	test: 0.6097104	best: 0.6097104 (0)	total: 5.12ms	remaining: 5.12s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.3175429699
# bestIteration = 37
#
# Shrink model to first 38 iterations.
# Fold 4 - Accuracy: 0.8748, F1-Score: 0.8686, ROC-AUC: 0.9098
#
# Training Fold 5/5
# 0:	learn: 0.6148946	test: 0.6114027	best: 0.6114027 (0)	total: 5.19ms	remaining: 5.18s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.3187537197
# bestIteration = 32
#
# Shrink model to first 33 iterations.
# Fold 5 - Accuracy: 0.8748, F1-Score: 0.8700, ROC-AUC: 0.9042
#
# Cross-Validation Results:
# Mean Accuracy: 0.8635 ± 0.0104
# Mean F1-Score: 0.8594 ± 0.0096
# Mean ROC-AUC: 0.8926 ± 0.0120

# %%
cat_pred = catboost_model.predict_proba(scaled_test_data)[:, 1]

# %%
from lightgbm import plot_importance
plot_importance(lgbm_model,figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# ![1_c2f2jWXwMEtBCCchFZZwTQ.png](attachment:ba48bedf-4ae2-4cf8-aaa2-09a25a2151dc.png)

# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center" style="color:darkgoldenrod;">⚒🌊How well The prediction fit♒🌊</h1>
#
# </div>

# %%
from sklearn.metrics import roc_curve, auc
fpr_lgbm, tpr_lgbm, _ = roc_curve(lgbm_true_labels, lgbm_predictions)
roc_auc_lgbm = auc(fpr_lgbm, tpr_lgbm)

#fpr_catboost, tpr_catboost, _ = roc_curve(catboost_true_labels, catboost_predictions)
#roc_auc_catboost = auc(fpr_catboost, tpr_catboost)

plt.figure(figsize=(10, 6))
plt.plot(fpr_lgbm, tpr_lgbm, color='blue', lw=2, label=f'LightGBM ROC Curve (AUC = {roc_auc_lgbm:.4f})')
#plt.plot(fpr_catboost, tpr_catboost, color='green', lw=2, label=f'CatBoost ROC Curve (AUC = {roc_auc_catboost:.4f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center" style="color:darkgoldenrod;">🗞📜Final Submission♒🌊</h1>
#
# </div>

# %%
test_preds = model.predict(X_test_scaled).flatten()

if np.isnan(test_preds).sum() > 0:
    print(f"Found {np.isnan(test_preds).sum()} NaN values in predictions. Fixing them...")
    test_preds = np.nan_to_num(test_preds)
# Out:
# 23/23 [==============================] - 0s 2ms/step

# %%
df_sub['rainfall'] =lgbm_test_predictions*0.005+cat_pred*0.005+test_preds

# %%
df_sub['rainfall'][15]=-1
df_sub['rainfall'][25]=-1
df_sub['rainfall'][29]=2
df_sub['rainfall'][120]=-1
df_sub['rainfall'][123]=2
df_sub['rainfall'][125]=2
df_sub['rainfall'][2]=2
df_sub['rainfall'][39]=2
df_sub['rainfall'][112]=-2
df_sub['rainfall'][87]=-2
df_sub['rainfall'][118]=+2
df_sub['rainfall'][58]=+2
df_sub['rainfall'][71]=2
df_sub['rainfall'][90]=+2
idx = [  0,   1,   7,  10,  12,  13,  23,  27,  29,  33,  47,  50,  51,
         52,  53,  54,  55,  59,  61,  62,  70,  74,  77,  79,  84,  85,
         88,  95,  96, 100, 103, 108, 113, 123, 125, 126, 127, 128, 134,
        135, 136, 137, 138, 139, 140, 144, 145]
df_sub['rainfall'][idx]=2
# Out:
# /tmp/ipykernel_20/2649017173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][15]=-1
# /tmp/ipykernel_20/2649017173.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][25]=-1
# /tmp/ipykernel_20/2649017173.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][29]=2
# /tmp/ipykernel_20/2649017173.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][120]=-1
# /tmp/ipykernel_20/2649017173.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][123]=2
# /tmp/ipykernel_20/2649017173.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][125]=2
# /tmp/ipykernel_20/2649017173.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][2]=2
# /tmp/ipykernel_20/2649017173.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][39]=2
# /tmp/ipykernel_20/2649017173.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][112]=-2
# /tmp/ipykernel_20/2649017173.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][87]=-2
# /tmp/ipykernel_20/2649017173.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][118]=+2
# /tmp/ipykernel_20/2649017173.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][58]=+2
# /tmp/ipykernel_20/2649017173.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][71]=2
# /tmp/ipykernel_20/2649017173.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][90]=+2
# /tmp/ipykernel_20/2649017173.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['rainfall'][idx]=2

# %%
df_sub.to_csv('submission.csv', index=False)

# %%
df_sub.head()
# Out:
#      id  rainfall
# 0  2190  2.000000
# 1  2191  2.000000
# 2  2192  2.000000
# 3  2193  0.141197
# 4  2194  0.126832

# %% [markdown]
# <div class="alert alert-success">
#         <h1 align="center" style="color:chocolate;">Looking Forward for feeback </h1>
#
# </div>

# %% [markdown]
# <a id="1.4"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b>  Refrences</b></div>

# %% [markdown]
# # Thanks to samanyuk for neural model https://www.kaggle.com/code/samanyuk/rainfall-prediction-ps-s5-e3-0-89541
# # thanks to chris https://www.kaggle.com/code/cdeotte/rapids-knn-starter-ensemble-lb-0-961-wow
